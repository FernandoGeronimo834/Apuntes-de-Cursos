# %% [markdown]
# <h1 style='background:#000000; color:#FFFFFF;height: 65px;padding-top: 8px;font-size: 45px;border-style: double;border-color: #838931;'><center>SQL PARA ANÁLISIS DE DATOS</center></h1>
#
# <h1 style='background:#000000; color:#FFFFFF;height: 55px;width: 200px; padding-top: 13px;font-size: 25px;border-style: double; border-color: #838931;'><center>ÍNDICE</center></h1>
#
# 1. [Comprender la visualización de datos](#Comprenderlavisualizacióndedatos)
# 2. [Introducción a la Estadística](#IntroducciónalaEstadística)
# 3. [Introducción a SQL](#IntroducciónaSQL)
# 4. [SQL Intermedio](#SQLIntermedio)
# 5. [Unión de datos en SQL](#UnióndedatosenSQL)

# %% [markdown]
# <h1 style='background:#000000; color:#FFFFFF;height: 55px;padding-top: 13px;font-size: 25px;border-style: double; border-color: #838931;'><center>Curso: Comprender la visualización de datos</center></h1><a name="Comprenderlavisualizacióndedatos"></a>

# %% [markdown]
# ## Tres formas de obtener información
#
# Hay tres formas principales de obtener información de un conjunto de datos.
#
# En primer lugar, puede calcular estadísticas de resumen. Eso incluye medidas de cantidad como la media o la mediana, y medidas de variación como la desviación estándar.
#
# En segunod lugar, puede ejecturar modelos estadísticos como regresión linea y regresión logística para modelar relaciones entre variables.
#
# En tercer lugar, puede visualizar datos dibujando gráficos como un gráfico de dispesión o un histograma.
#
# Estas tres formas a menudo se usan juntas y tienen diferentes beneficios.
#
# ## La docena de Datasaurus
#
# <img src=".\img\1.png" width="550px" height="350px">
#
# La docena de Datasaurus es una colección de 12 conjuntos de datos, con nombres como away y bullseye. Cada conjunto de datos tiene dos variables: las coordenadas X e Y.
#
# "Variables" es solo jerga estadística para una columna de datos.
#
#
# ## Media de x para cada conjunto de datos
#
# Si calcula la media de los valores de x en cada conjunto de datos, puede ver que es más o menos el mismo valor.
#
# Es la misma situación para las medias de las coordenadas Y. El valor es el mismo en cada conjunto de datos.
#
# <img src=".\img\2.png" width="550px" height="350px">
#
#
# ## Desviacione estándar de cada conjunto de datos
#
#
# De manera similar, podemos ver la variación de los valores de X e Y calculando la desviación estándar para cada conjunto de datos.
#
# La variación describe cuán dispersos son los valores. Cada conjunto de datos tiene la misma desviación estándar para X e Y.
#
# <img src=".\img\3.png" width="550px" height="350px">
#
#
# ---
#
#
# Aquí hay un diagrama de dispesión de cada conjunto de datos, e incluso un vistazo rápido muestra en qué fallaron los calculos.
#
# Es decir, cada conjunto de datos es completamente diferente. Hasta que mire físicamente los conjuntos de datos, es díficil ver que tienes líneas y círculos y una estrella y un dinosaurio.
#
# Los conjuntos de datos son artificiales, pero espero que este ejemplo lo haya convencido de la importancia de graficar sus conjuntos de datos.
#
# <img src=".\img\4.png" width="550px" height="350px">
#
#
# ## Variables Categoricas y Continuas
#
#
# La elección de un tipo de gráfico depende de si sus variables son continuas o categóricas.
#
# Las variables continuas son números, como alturas, temperaturas o ingresos. Puede hacer operaciones aritméticas con variables continuas, como sumar dos temperaturas.
#
#
# Las variables categoricas son cosas que se puede clasificar y, por lo general, se escriben como texto. Incluyen el color de ojos, que toma las categorías azul, marrón, y algunas otras. Otros ejemplos incluyen país e industria, que tienen una lista más larga de categorías.
#
#
# Finalmente, algunas cosas pueden ser continuas o categóricas. La edad es un número, por lo que por defecto es una variable continua. Sin embargo, muchas encuestas usan grupos de edad como 25 a 30. Esos grupos de edad son categorías.
#
# De manera similar, el tiempo es naturalmente una variable continua, pero si tiene que producir un informe sobre cómo los precios cambian cada mes, es posible que desee pensar en el mes del año como una variable categórica.
#
# En este caso, tiene la libertas de tratar el tiempo como continuo o categórico. Depende de la pregunta que se deba responder.

# %% [markdown]
# # Histogramas
#
# Los histogramas son un tipo de gráfico que tomoa una variable continua como entrada. Le permite responder preguntas sobre la forma de la distribución de esa variable. Por ejemplo, es posible que desee conocer los valores más bajos y más altos, y qué valores son los más comunes.
#
# ## Reyes y reinas de Inglaterra y Gran Bretaña
#
# Aquí hay un conjunto de datos sobre los reyes y reinas de Inglaterra y Gran Bretaña, más recientemente.
#
# Se extiende desde la monarca actual hasta el primer rey de Inglaterra, Aethelstan.
#
# Echemos un vistazo a la distribución de las edades cuando ascendieron al trono.
#
# <img src=".\img\5.png" width="550px" height="350px">
#
#
# ## Histograma de edad al inicio de la regla
#
# <img src=".\img\6.png" width="300px" height="350px">
#
# El eje x es la variable que nos interesa: las edades. Estas edades se agrupan en `bins`, es decir, intervalos. En este caso, los intervalos son de cero a cinco años, de cinco a diez años y así sucesivamente hasta sesenta a sensa y cinco años.
#
# El eje y es el conteo de monarcas que comenzaron a gobernar cuando estaban en cada intervalo de edad.
#
# ## Elección de la anchura del intervalo: 1 año
#
# <img src=".\img\7.png" width="300px" height="350px">
#
# La apariencia de un histograma está fuertemente influenciada por la elección del ancho del `bin`.
#
# Estes es el mismo histograma que antes, pero con el ancho de intervalo cambiado de cinco años a un año.
#
# Es dificil obtener mucha información sobre la distribución, porque los conteos son muy ruidosos. Elegir un acho de `bin` que sea demasiado ancho también causa problemas.
#
# ## Elección de la anchura del intervalo: 25 años
#
#
# <img src=".\img\8.png" width="300px" height="350px">
#
#
# Al cambiar el ancho del contenedor a 25 años, no verá ningún detalle en la distribución, y de nuevo es díficil obtener mucha información.
#
# ## Modalidad: ¿cuántos picos?
#
# <img src=".\img\9.png" width="400px" height="350px">
#
# Al interpretar histogramas, lo primero que debe observarse es la modalidad de la distribución. Es decir, cuántos picos hay.
#
# Una distribución con un pico se llama "unimodal"; una distribución con dos picos se denomina "bimodal", y así sucesivamente.
#
#
# ---
#
# <img src=".\img\10.png" width="600px" height="350px">
#
# Aquí, la distribución de edades es unimodal porque hay un poco de 25 a 35 años.
#
#
# ## Sesgo: ¿es simétrico?
#
#
# <img src=".\img\11.png" width="500px" height="350px">
#
# La segunda cosas a tener en cuenta es la asimetría de la distribución.
#
# Esa es la jerga estadística sobre si es simétrica o no.
#
# Una distribución **asimétrica izquierda** tiene valores atípicos a la izquierda, es decir, los valores extremos, y una distribución **sesgada a la derecha** tiene valores atípicos a la derecha.
#
#
# Los valores atípicos se ven un poco puntiagudos, así que me gusta recordar en qué dirección alrededor de estos son imaginando que los valores atípicos son una brocheta  de shish-kebab.
#
# En una distribución sesgada a la izquierda, el sesgo apunta hacia la izquierda, y en una distribución sesgada a la derecha, el pincho apunta hacia la derecha.
#
# ---
#
# <img src=".\img\12.png" width="500px" height="350px">
#
# Aquí, la distribución es más o menos simétrica.
#
#
# ## Curtosis: ¿cuántos valores extremos?
#
# Una cosa más avanzada que puede observar es la curtosis de la distribución, que afecta la cantidad de valores atípicos.
#
# Una distribución mesocúrtida es algo que se parece a la curva de campana de una distribución normal.
#
# Una distribución leptocúrtica tiene un pico estrecho y mucho valores extremos.
#
# Las distribuciónes leptocúrticas son importantes en las finanzas, porque las cosas extrañas ocurren en los mercados bursátiles con más frecuencia de lo que predeciría la distribución normal.
#
#
# Una distribución platicúrtica tiene un pico amplio y pocos valores extremos.
#
#
# <img src=".\img\13.png" width="500px" height="350px">
#
#
# ---
#
#
# <img src=".\img\14.png" width="500px" height="350px">
#
# Aquí, la distribución de edades es ligeramente platicúrtica.

# %% [markdown]
# # Diagramas de caja
#
# Los histogramas individuales son genials, pero hay un problema si quieres dibujar muchos de ellos.
#
#
# ## No se pueden colorear los histogramas
#
# Revisemos el conjutno de datos de reyes y reinas. Supongamos que queremos ver las distribución de edades de cada casa real.
#
# Una solución ingenua podría ser dibujar el mismo histograma, pero usando diferentes colores para cada casa.
#
# <img src=".\img\15.png" width="500px" height="350px">
#
# Lamentablemente, este es un horrible lío confuso.
#
#
# ## Dibujar cada histograma en su propio panel
#
# En mucho  casos, la única forma sensata de dibujar mucho histogramas es dibujaros en su propio panel. Aquí puedes ver trece histogramas, uno para cada casa. Este enforque todavía tiene problemas.
#
# Es bastante fácil comparar distribuciones para panles que están en la misma columna. Puede ver que los monarcas de la familia Wessex eran típicamente mucho más jóvenes cuando comenzaron a gobernar que los de la familia Windsor, ya que puede mirar hacia abajo en la columna y ver que la distribución de Wessex está a la izquierda de la e Windsor. Por el contrario, es más dificil comparar distribuciones entre paneles que están en columnas diferentes.
#
# Para comparar las edades de los monarcas en las casa rivales de York y Lancaster, tienes que mirar mucho hacua adelante y hacia atrás y mire fijamente los números en el eje x, lo cual no es lo ideal.
#
# <img src=".\img\16.png" width="400px" height="350px">
#
#
# ---
#
#
# Podria alinear todos los paneles en una sola columna, pero eso a menudo significa quedarse sin espacio. Aquí, el texto de la trama es casi ilegible. Afortunadamente, los digramas de caja pueden resolver este problema.
#
# <img src=".\img\17.png" width="100px" height="350px">
#
#
# ## ¿Cuándo utilizar un diagrama de cajas?
#
# Los diagramas de caja dividen una variable continua, como la edad, por una variable categórica, como casa real, y permirtirnos comparar las distribuciones resultantes de una manera eficiente en el espacio.
#
#
# ## Histograma vs Diagrama de caja
#
#
# Aquí hay una comparación del histograma que viste antes con un diagrama de caja. La linea del medio muestra la mediana de la distribución. Es decir, la mitad de los monarcas comenzaron a gobernar antes de esta edad y la otra mitad después de esta edad.
#
# La caja en el diagrama de caja se extiende desde el cuartil inferior hasta el cuartil superior. El cuartil inferior es el punto donde una cuarta parte de los valores están por debajo de el. Es decir, una cuarta parte de los monarcas comenzaron a gobernar antes de esta edad y tres cuartas partes después. Asi mismo, el cuartil superior es la edad en la que tres cuartas partes de los monarcas comenzaron a gobernar por debajo de esta edad.
#
# La diferencia entre el cuartil superior y el cuartil inferior se denomina rango intercuartílico.
#
# Las lines horizontales, conocidas como "bigotes", tiene una definición más complicada. Cada barra se extiende a una vez y media el rango intercuartil, pero luego se limita a alcanzar puntos de datos reales.
#
# La definición tecnica se muestra en la diapositiva, pero en la práctica, puede pensar en que los bigotes se extienden los suficiente como para cualquier cosa fuera de ellos sea un valor extremo.
#
# <img src=".\img\18.png" width="700px" height="350px">
#
#
# ## Monarcas por casa
#
#
# Como se mencionó anteriormente, el poder de los diagramas de caja es que puede comparar muchas distribuciones a la vez. Aquí, las casas reales están ordenadas de la más antigua en la parte superior a la más nueva en la parte inferior.
#
# Se nota la tendencia: desde los Plantagenets en el signo XIV, las cajas poco a poco se mueven a la derecha mostrando que las edades en las que los nuevos monarcas ascienden al trono han ido en aumento.
#
# Godwin y Blois aparecen como una sola linea porque solo había un rey de cada casa.
#
# La casa de Anjou solo tuve tres reyes, y forma una caja con un bigote, no dos.
#
# Observa que el diagrama de caja de la casa de Denmark muestra un punto. Los puntos son valores extremos, es decir, valores que están fuera del rango de los bigotes. El valor atípico más a la derecha de Denmark es Sweyn, quienascendió a la edad de 53 años, lo que fue exceptionalmente alto para el siglo XI.
#
#
# <img src=".\img\19.png" width="400px" height="350px">

# %% [markdown]
# # Gráfico de dispersión
#
#
# ## ¿Cuándo utilizar un diagrama de dispersión?
#
# Los diagramas de dispersión deben usarse cuando tiene dos variables continuas y desea conocer si relación.
#
# Por ejemplo, si una variable aumenta, ¿la otra también aumenta o disminuye?
#
#
# ## Precios de la vivienda en Los Ángeles
#
# Aquí hay un conjunto de datos sobre los precios de las viviendas en cuatro ciudades del condado de los Ángeles en 2012.
#
# El conjunto de datos incluye la cantidad de dormitorios, el precio de venta en millones de dólares y el área en pies cuadrados.
#
# <img src=".\img\20.png" width="300px" height="350px">
#
#
# ## Precio vs Área
#
# Aquí hay un diagrama de dispersión con el precio en el eje Y y el área en el eje X.
#
# Para describrir verbalmente este diagrama, diría que es un diagrama de dispersión de "Precio vs área". Está bien, pero todos los puntos están agrupados en la parte inferior izquierda, lo que dificulta su lectura.
#
# <img src=".\img\21.png" width="300px" height="350px">
#
# Usemos una escala logarítmica para cada eje.
#
# En el gráfico logarítmico, observe que al moverse a la derecha una línea de cuadrícula se duplica el área, o subir una línea de cuadrícula multiplica el precio por un factor de diez. Ahora los puntos están más uniformemente repartidos por toda la trama.
#
# <img src=".\img\22.png" width="300px" height="350px">
#
#
# ## Correlación
#
# Un concepto importante al interpretas diagramas de dispesión es la idea de correlación. En términos generales, la correlación es una medida de qué tan bien puede dibujar una línea recta a través de los puntos.
#
# Si la línea recta va hacia arriba a media que te mueves hacia la derecha, se llama correlación positiva.
#
# Si la línea desciende a medida que avanza hacia la derecha, se llama correlación negativa.
#
# Aquí hay cinco conjuntos de datos teóricos. La línea roja en cada panel muestra cómo sería una correlación negativa perfecta. Las líneas verdes muestran una correlación positiva perfecta.
#
# En el panel más a la izquierda, puede ver un ejemplo de fuerte correlción negativa. Eso significa que a medida que aumentan los valores de X, los valores de Y disminuyen.
#
# En el panel más a la derecha, puede ver una fuerte correlación positiva, lo que significa que a medida que aumenta X, también lo hace Y.
#
# Los paneles centrales muestran estados intermedios. En el tercer panel, que no muestra correlación, los valores de Y no tienen ninguna relación con los valores de X.
#
# <img src=".\img\23.png" width="600px" height="350px">
#
#
# ## A veces la correlación no ayuda
#
# Aquí está el Datasaurus de nuevo.
#
# Recuerde que cada conjunto de datos tenía la misma correlación, a pesar de verse muy diferente.
#
# <img src=".\img\4.png" width="350px" height="350px">
#
# La correlación tiene más sentido si existe una relación de línea recta entre los valores X e Y. Si tiene una forma más complicada, deberá ser más creativo en la forma en que describe la relación. Por ejemplo, "X e Y tienen una ligera correlación negativa" no es una descripción tan buena como "la trama parece un dinosaurio".
#
#
# ## Añadir líneas de tendencia
#
# Agregar una línea recta a un diagrama de dispesión es una excelente manera de ver si realmente tiene una relación lineal entre las variables X e Y.
#
# Aquí, con las escalas logaritmicas, la línea de tendencia tiene un ajuste cercano a los puntos, los que sugiere que a medida que aumenta el logaritmo del área, se obtiene un aumento lineal e el logaritmo del precio.
#
# <img src=".\img\24.png" width="350px" height="350px">
#
#
# ## Añadir líneas de tendencia suaves
#
#
# A veces, una línea recta puede ser un ajuste terrible.
#
# Aquí, en el gráfico de precio VS área utilizando una escala linea, la línea pasa por alto por completo las casas más caras.
#
# Cuando una línea de tendencia recta no se ajusta bien, una alternativa es usar una curva. Tener una curva como esta puede ayudarte a encontrar una manera de describir la relación.
#
# Aquí, al ver la curva de la línea de tendencia hacia arriba, puede decir "a medida que aumenta el área, el precio aumenta más rapido que linealmente".
#
# <img src=".\img\25.png" width="600px" height="350px">

# %% [markdown]
# # Gráficos de línea
#
#
# ## Casos mundiales de coronavirus COVID-19
#
# Aquí hay un gráfico de dispesión ligeramente aterrador del número acumulativo de casos de coronavirus COVID-19 en todo el mundo a principios de 2020. Está bien, pero podemos hacer una trama mejor.
#
# Dado que el eje X consta de fechas, los puntos de datos consecutivos están conectados. Eso significa que la trama es más fácil de entender si conectamos esos puntos de datos. Es decir, aquí es preferible usar una línea de puntos.
#
# <img src=".\img\26.png" width="300px" height="350px">
#
#
#
# ## ¿Cuándo se debe utilizar un gráfico lineal?
#
# Entonces, el caso de uso para los diagrama de línea es el mismo que para los diagramas de dispersión, con una condición adicional: los puntos de datos consecutivos están conectados de alguna manera.
#
# El caso más común es que el eje X represente fechas u horas, como acabas de ver con los casos de coronaviruz, pero no siempre es así.
#
#
# ## Comparación de múltiples líneas
#
# Una cosa realmente útil de los diagramas de líneas es que puede dibujar vairas líneas en el mismo diagrama y compararlas.
#
# Aquí puede ver que en febrero, la mayoria de los casos de COVID-19 se informaron en China, luego en marzo el resto del mundo lo superó.
#
# <img src=".\img\27.png" width="300px" height="350px">
#
#
# ## Líneas de tendencia
#
# Una cosa útil que puede hacer es comparar gráficos de líneas con una línea de tendencia generada a partir de una regresión lineal.
#
# Este gráfico muestra los casos notificados en China en marzo, después de que se implementaron las cuarentenas y otras restricciones.
#
# Las líneas de datos siguen de cerca la línea de tendencia recta, lo que indica que el número de casos crece linealmente.
#
# <img src=".\img\28.png" width="300px" height="350px">
#
#
# ## Líneas de tendencia + Escala logaritmica
#
# Por el contrario, si observamos los casos fuerda de china, una tendencia lineal no encaja muy bien.
#
# El número de casos está creciendo mucho más rápido que eso.
#
# El transformar la gráfica para usar una escala logarítmica en el eje y antes de ajustar la línea de tendencia, vera un ajuste mucho mejor.
#
# Eso significa que a nivel mundial, el número de casos está creciendo exponencialmente.
#
# <img src=".\img\29.png" width="600px" height="350px">
#
#
# ## El eje X del tiempo no siempre implica un trazado lineal
#
# Solo porque tiene un conjunto de datos en el que desea ver la relación entre una variable númerica y el tiempo, no significa que un gráfica de líneas sea la mejor opción.
#
# Aquí puedes ver el resultado de una encuesta de la BBC, en la que pedía a los críticos que puntuaran las mejores canciones de hip-hop. En la trama, cada punto representa una canción. La fecha está en el eje X y la puntuación del crítico está en el eje Y.
#
# Debido a que cada canción no está conectada a la siguiente canción, no se puede trazar una línea entre ellos, y un diagrama de dispersión tiene más sentido.
#
# Para reiterar: los diagrama de líneas necesitan valores de datos consecutivos para estar conectados conceptualmente.
#
# <img src=".\img\30.png" width="300px" height="350px">
#
# ---
#
#
# Por el contrario, no siempre necesita fecha u horas en el eje X. Aquí puede ver un gráfico de delincuentes juveniles en Suiza.
#
# En el eje X es el tiempo y el eje Y es el número de delincuentes, y cada línea representa un grupo de edad.
#
# <img src=".\img\31.png" width="350px" height="350px">
#
# De alguna manera, encuentro que esta trama es muy insatisfactoria para obtener información.

# %% [markdown]
# # Gráfica de Barras
#
#
# Los diagramas de barras son un pariente cercano de los diagramas de caja.
#
#
# ## ¿Cuándo utilizar un diagrama de barras?
#
# Por lo general, se utilizan cuando desea recuentos o porcentajes de una variables categórica.
#
# Aunque es menos común, es posible calcular un números diferente para cada categoría. Una restricción es que el valor cero debería ser importante de alguna manera, ya que las barras se extienden hasta cero.
#
# En 1988, la badna de pop Bros hizo la pregunta, "¿Cuándo seré, seré famoso?". Usemos la ciencia de datos para averiguarlo.
#
#
# ## Los 100 deportistas más famosos de ESPN de 2017
#
#
# Echemos un vistazo a un conjunto de datos de los atrletas más famosos del mundo de 2017m según lo juzgado por ESPN, un canal de televisión estadounidense. Los atletas clasificados de acuerdo a cosas como cuántos seguidores en las redes sociales tienen, cuánto dinero ganan promocionando productos y popularidad en las búsquedas en Internet.
#
# <img src=".\img\32.png" width="450px" height="350px">
#
#
# ## Gráfico de barras de los recuentos por país
#
# Aquí hay un diagrama de barras del número de atletas en la lista de cada país.
#
# Las categorías, es decir, los países, están en el eje Y, y el eje X muestra los recuentos.
#
# <img src=".\img\33.png" width="550px" height="350px">
#
#
# ## Barras verticales
#
# Es posible intercambiar los ejes para mostrar categorías en el eje X y recuentos en el eje Y.
#
# Eso hace que los países sean más difíciles de leer porque tienes que inclinar tu cabeza para leer la escritura, por lo que las barras horizontales son preferibles aquí.
#
# <img src=".\img\34.png" width="550px" height="350px">
#
#
# ## Ordenar por recuento
#
# Por lo general, querrá ordenar las barras por conteo.
#
# Esto hace más fácil ver que, por ejemplo, España e India están empatados en el quinto lugar, con cuatro atletas cada uno.
#
# <img src=".\img\35.png" width="450px" height="350px">
#
#
# ## Consumo infantil de fruta y verdura
#
# Aquí hay un conjunto de datos de la Encuesta de Salud de Inglaterra en 2018.
#
# La encuesta hace muchas preguntas relacionadas con la salud y este conjunto de datos en particular se centra en una pregunta sobre cuántas porciones de frutas y verduras comen los niños por día.
#
# Tenemos dos variables categóricas; el npumero de porcionaes consumidas y el año. La métricaes un porcentajes en lugar de un conteo.
#
# <img src=".\img\36.png" width="250px" height="350px">
#
#
# ## Barras apilables
#
# Dado que los porcentajes de niños para cada año siempre suman hasta el 100%, es útil apilar las barras una encima de la otra.
#
# En 2001, por ejemplo, puede ver que los dos bloques inferiores alcanzan el  25%, lo que significa que el 25% de los niños comieron al menos cuatro piezas de frutas y verduras por día en este año. En 2003, el gobierno del Reino Unido inició una campaña para alentar a las personas a comer cinco porciones de frutas y verduras al día.
#
#
# Mire los bloques inferiores y observe que el porcentaje de niños que comen las cinco porciones aumentaron cada año de 2003 a 2006 y se mantuvieron más o menos constantes hasta 2014. De manera similar, los bloques pálidos en la parte superior de la gráfica muestran que el porcentaje de los niños que comían cero porciones al día disminuyeron de 2003 a 2006 y luego se mantuvieron constantes. Parece que la campaño fue un exito.
#
# <img src=".\img\37.png" width="450px" height="350px">
#
#
# ## Diagrama de barras VS. Diagrama de caja
#
#
# Consideremos la relación entre diagrama de caja y diagrama de barras.
#
# Estos son los diagramas de caja de la época en que los monarcas ingleses y británicos comenzaron a gobernar, dividos por casa real.
#
# Un gráfico de barras de conteos por cada tiene una forma similar: las categorías están en el eje Y, y el eje X es numérico.
#
#
# <img src=".\img\38.png" width="650px" height="350px">
#
#
# La diferencia es que el diagrama de caja está diseñado para responder preguntas sobre la dispersión de una variable, y el gráfico de barras está diseñado para responder preguntas sobre una única métrica relativa a cero, en este caso, contar.
#
#
# ## Otras métricas distintas de los recuentos
#
# Como se mencióno anteriormente, el conteo no es la única métrica que puede mostrar en un gráfica de barras.
#
# Aquí, en su lugar, se muestra la edad media al comienzo de la regla.
#
# Es una trama perfectamente válida, pero dado que solo muestra un valor por barra, se siente menos emocionante que el diagrama de caja de la izquierda.
#
# <img src=".\img\39.png" width="650px" height="350px">

# %% [markdown]
# # Diagramas de puntos
#
# ## ¿Cuándo utilizar un diagrama de puntos?
#
# Los diagramas de puntos funcionan en las mismas situaciones que los diagramas de barras, pero tienen dos ventajas.
#
# Puede usar una escala logarítmica con ellos y puede trazar múltiples métricas con ellos.
#
#
# ## Estrellas cercanas y enanas marrones
#
# Aquí hay un conjunto de datos sobre las estrellas más cercanas a la Tierra.
#
# La distancia a la Tierra se mide en años luz, y la masa se mide en masas solares, es decir, múltiplos de la masa del Sol.
#
#
# <img src=".\img\40.png" width="250px" height="350px">
#
#
# ## Diagrama de barras VS. Diagrama de puntos
#
#
# Aquí hay un gráfico de barras de las masas estelares, ordenadas desde la estrella más cercana en la parte superior hasta la estrella más lejana en la parte inferior.
#
# Hay una grana variedad en la longitud de las barras, y algunas de las barras son apenas visibles. Esto se vería mejor en una escala logarítmica. Desafortunadamente, el logaritmo de cero es menos infinito, y las barras en un gráfico de barras siempre deben comenzar en cero. Esto significa que una escala logarítmica no es posible para un gráfico de barras.
#
# La solución es mostrar un punto en su lugar. Esto se llama diagrama de puntos.
#
# Aquí, la escala es lineal, por lo que puede ver que cada punto se encuentra donde habría esta la parte superior de la barra.
#
# <img src=".\img\41.png" width="850px" height="350px">
#
# ## Escala logarítmica
#
#
# El uso de una escala logarítmica ayuda a responder preguntas sobre cuántas veces es más pesada una estrella en comparación con otra.
#
# <img src=".\img\42.png" width="350px" height="350px">
#
#
# ## Ordenar Filas
#
# Al igual que con los diagramas de barras, el orden de las filas importa. Al ordenar las filas de la estrellas más pesas a las más ligera, es más fácil responder preguntas sobre cuál es la estrella más pesas o la más ligera más cercana a la Tierra.
#
#
#
# <img src=".\img\43.png" width="350px" height="350px">

# %% [markdown]
# # Dimensiones superiores
#
#
# ## Gráficos de dispersión de la esperanza de vida de la ONU
#
# Aquí están los gráficos de esperanza de vida utilizando el conjunto de datos de la ONU.
#
# Visualizó la esperanza de vida frente a la duración de la eduación y el INB por cápita por separado.
#
# ¿Qué pasaría si quisieras ver el efecto de ambas variables en la esperanza de vida juntas?
#
# <img src=".\img\44.png" width="350px" height="350px">
#
# ## Diagrama de dipersion 3D
#
# La respuesta obvia es dibujar un diagrama de dipersión en 3D. Desafortunadamente, esa es una idea terrible. Con un objeto tridimensional en una pantalla bidimensional, pierdes todo sentido de la perspectiva, y es difícil de interpretar.
#
# A veces, dibujar la trama en diferentes ángulos puede ayudar a la interpretación, pero la mayoría de los ángulos no son útiles.
#
#
# <img src=".\img\45.png" width="350px" height="350px">
#
#
# ## x e y no son las únicas dimensiones
#
#
# Afortunadamente, existen otras formas de dibujar más de dos dimensiones en una pantalla plana.
#
# Para puntos en un gráfico de dispersión, puede representar valores usando diferentes colores, tamaños, niveles de transparencia y forma.
#
#
#
# ## Color
#
# Aquí, la duración de la educación y el INB se muestran en los eje X e Y, luego la esperanza de vida se representa en un eje de color.
#
# Las esperanzas de vida más cortas se muestran en azul, moviéndose de verde a amarillo para las esperanzas de vida más largas. Los puntos amarillos están en la parte superior derecha, lo que significa que los países con las esperanzas de vida más largas tienen tiempos de escolarización prolongados y un INB alto.
#
# Como beneficio adicional, puede ver la correlación positiva entre la educación y el INB.
#
# Una desventaja es que no puede ver los valores precisos de la esperanza de vida. Puede estimar más o menos cinco años, pero no podrías definir si un color corresponder a 64 años o 65 años.
#
# <img src=".\img\46.png" width="350px" height="350px">
#
#
# ## Tamaño
#
# Una segunda opción es cambiar el tamaño de los puntos, donde los puntos más grandes representan números más grandes. Esto está bien, pero tiene más problemas.
#
# En primer lugar, los puntos más grandes pueden parecer más importantes. A veces eso puede ser aceptable, pero si quieres que la gente se concentre en países con una esperanza de vida baja, es una mala elección.
#
# En segundo lugar, es más dificil juzgar las expectativas de vida precisas que con el color.
#
# En tercer lugar, los puntos grandes tienden a superponerse, lo que dificulta la distinción de países individuales.
#
# <img src=".\img\47.png" width="350px" height="350px">

# %% [markdown]
# # Colores
#
# ## Elegir una paleta de trazado
#
# Aquí está el gráfico de los precios de las casa de Los Ángeles. Hay algunos problemas con la elección de los colores.
#
# En primer lugar, los puntos amarillos son más dicíciles de ver que los rojos, lo que significa que los espectadores podrían pasar menos tiempo mirando los amarillos y perder información importante.
#
# En segundo lugar, los colores azul y púrpura son perceptualmente muy parecidos, es decir, parecen bastantes similares.
#
# Por el contrario, el amarillos parece muy diferente a los otros colores. Esto podría llevar a los espectadores de la trama a pensar, posiblemente subconscientemente, que los puntos amarillos son diferentes a los demás.
#
# <img src=".\img\48.png" width="350px" height="350px">
#
#
# ## Espacios de color: Tono-Croma-Luminancia
#
#
# El espacio de color diseñado para la visualización de datos se denomina tono-croma-luminecia o HCL. Está diseñado para tratar problemas de percepción del color.
#
# El tono (`Hue`) es como el color del arcoíris, desde el rojo, pasando por el naranja, el verde y el azul, hasta el púrpuray de nuevo el rojo.
#
# Croma es la intensidad de color, de gris a un color brillante. Puede pasar de gris a verde brillante, de gris a magenta brillante o de gris acualquier tono.
#
# La luminancia es el brillo del color, de negro a blanco. Por ejemplo, puede psar del negro al cian y al blanco, o del negro al rojo y al blanco.
#
#
#
# <img src=".\img\49.png" width="450px" height="350px">
#
#
# ## Tres tipos de escala de colores: cualitativa
#
# Al elegir los colores para su gráfico, puede elegir uno de los tres tipos de escala de colores.
#
# Las escalas de color cuantitativas se utilizan para distinguir categórias no ordenadas, y generalmente implican cambiar el tono, manteniendo fijos el croma y la luminancia.
#
# <img src=".\img\50.png" width="550px" height="350px">
#
#
#
# ## Ejemplo de paleta cualitativa
#
# Este es el gráfico de líneasde adopción de tecnología.
#
# Las tecnologías están desordendas, ya que no es útil pensar que los refrigeradores son más grandes que las estufas. Cada línea tiene un tono diferente, pero croma y luminancia constante.
#
# <img src=".\img\51.png" width="450px" height="350px">
#
#
#
# ## Tres tipos de escala de colores: secuencial
#
# Para enfatizar en el orden de sus datos, es decir, para mostrar que los valores son mayor que o menor que el otro, necesita una escala de color secuencial. La mayoría de las escalas secuenciales cambian el croma o la luminancia, manteniendo fijo el tono.
#
# <img src=".\img\52.png" width="550px" height="350px">
#
#
#
# ## Ejemplo de paleta secuencial
#
# Aquí está el gráfico de barra de consuma de frutas y verduras. La categorías están ordenadas de cero a más de cinco, por lo que una escala de colores secuencial tiene más sentido.
#
# <img src=".\img\53.png" width="450px" height="350px">
#
# ## Otro ejemplo de paleta secuencial
#
# También puede utilizar escalas secuenciales con variables continuas. Este es el gráfico de dispesión de la esperanzade vida. Esto e sun poco engañozo porque usa una escala secuencial que cambia el tono. La escala de colores se llama `viridis` y está diseñada para ser fácilmente visible para personas daltónicas y para imprimir bien en blanco y negro.
#
# Esta escala de colores tuvo mucha ciencia utilizada en su desarrollo; Si hace su propia escala secuencia, es mejor ceñirse a cambiar solo el croma o la luminancia.
#
# <img src=".\img\54.png" width="350px" height="350px">
#
#
# ## Tres tipos de escala de color: divergente
#
# Para enfatizar si los valores son mayores o menores que un valor medio, use una escala divergente. Son similares a las escalas secuenciales, pero tienen un color netro como el blanco o el gris en el medio, y colores cada vez más atrevidos con diferentes matices en cada borde.
#
# <img src=".\img\55.png" width="550px" height="350px">
#
#
# ## Fechas de la encuesta Green Tech en Malasia
#
# Aquí hay otro conjunto de datos de encuestas sobre tecnologías verde y reciclaje en Malasia.
#
# Cada pregunta tiene una opción de cinco respuestas, desde "Totalmente endesacuerdo" hasta "Totalmente de acuerdo". Las respuestas "Neutrales" forman un punto medio, lo que hace útil una escala divergente.
#
# <img src=".\img\56.png" width="400px" height="350px">
#
#
# ## Ejemplo de paleta divergente
#
#
# Aquí puede ver cada pregunta en su propía fila, y los colores se vuelven más llamativos a medida que los opiniones se fortalecen.
#
# <img src=".\img\57.png" width="450px" height="350px">

# %% [markdown]
# # Trazar muchas variables a la vez
#
# Para visualizar muchas varibales, necesitará usar tipos de gráficos más avanzados. Aquí veremos gráficos de pares, mapas de calor de correlación y gráficos de coordendas paralelas.
#
#
# ## ¿Cuándo se debe utilizar un gráfico de pares?
#
# Los diagramas de pares funcionan con hasta unas diez variables a la vez y le muestran la distribución de cada variables, y la relación entre cada par de variables.
#
# <img src=".\img\58.png" width="450px" height="350px">
#
# Aquí hay un par de gráficos de los precios de las casa en los Ángeles. Hay cuatro variables en el conjunto de datos, dando cuatro filas de panelas y cuatro columnas. Exploremos esto pieza por pieza.
#
# ---
#
# * Los paneles en la diagonal (`(1,1)`) muestran distribuciones de vairbles. La ciudad es una variables categórica, por lo que su distribución se representa como un gráfico de barras de conteos para cada ciudad.
#
#
# * Las otra tre variables (`(2,2),(3,3),(4,4)`) - número de camas, precio y área son continuas, por lo que sus distribuciones se representan mediante un histograma.
#
# * Los paneles fuera de la diagonal muestran relaciones entre pares de variables. Cuando ambas variables son continuas, verá diagrama de dispersión de cada par de variables y su correlación. Por ejemplo, en la segunda columna, cuarta fila, verá un gráfico de dispesión del número de cama frente al área. En la cuarta columna, segunda fila, ves ese número de camas y el área tiene una correlación positiva de 0.782
#
# <img src=".\img\59.png" width="450px" height="350px">
#
#
# * Al comparar una variable categórica con una variable continua, obtiene un grafico de caja y un histrograma de la variable dividida por la variable categórica. Por ejemplo, en la tercera columna, primera fila, verá un diagrama de caja de precios para cada ciudad. En la primera columna, tecera fila, ves un histograma de lo mismo. El histograma es vertical, por lo que las posiciones coinciden con las del panel de la ciudad en la diagonal.
#
#
# <img src=".\img\60.png" width="450px" height="350px">
#
#
# ---
#
#
# Los diagrama de pares pueden ser tremendamente útiles para explorar rápidamente un nuevo conjunto de datos. Para el caso especial en el que tiene muchas variables continuas, un pariente cercano del diagrama de par, llamado mapa de calor de correlación es más simple y escala para visualizar incluso más variables a la vez.
#
# La idea es que dibujes un diagrama de pares, solo incluye los paneles de correlaciones, pero en lugar de mostrar núnmeros, muestra un color.
#
#
# ## ¿Cuándo utilizar un mapa de correlación?
#
# Los mapas de calor de correlación están diselados para mostrar relaciones entre pares de variables continuas. Son compactos, por lo que pueden comparar fácilmente decenas de variables a la vez.
#
# <img src=".\img\61.png" width="450px" height="350px">
#
# Aquí hay un mapa de calor de correlación de una encuesta de satisfacción del cliente para un producto publicitario de las Páginas Amarillas.
#
# Los clientes calificaron la importancia de las características del producto de una escala del 1 al 10. Donde dos características recibieron consistentemente puntajes similares por cliente, están positivamente correlacionados y coloreados en un rojo más vibrante. Esos rojos brillantes en la parte inferior izquierda muestran que los espectos del producto relacionados con el precio están fuertemente correlacionados entre sí.
#
# ## De nuevo el conjunto de datos de las Naciones Unidas
#
# Aquí hay una gráfica de los datos de los países de las Naciones Unidas nuevamente. Mostro que puede usar el color en un diagrama de dispesión para mostrar tres variables a la vez.
#
# Sin embargo, con cuatro o más variables, los diagramas de dispersión pueden volverse complicados de interpretar rápidamente
#
# <img src=".\img\54.png" width="350px" height="350px">
#
#
# ## ¿Cuándo se debe utilizar un gráfico de coordenadas paralelas?
#
#
# Los gráficos de coordenadas paralelas brindan una solución a esto cuando tiene muchas variables continuas y desea comprender su relación o agruparlas en grupos.
#
# ## Un gráfico de coordenadas paralelas
#
# Aquí hay una gráfica de coordenadas paralelas de las tres variables que vio antes, más el puntajes del índice de desarrollo humano. Cada línea representa un país y cada variables continua aparece en el eje x, como un gráfico de barras. Para hacer que cada varible sea comparable, el eje Y simplemente va desde el valor más bajo en el conjunto de datos para esa variable al valor más alto.
#
# <img src=".\img\62.png" width="650px" height="350px">
#
#
# Desafortunadamente, esta trama es un desastre porque el mundo es complicado.
#
# Intentemos dividir el conjunto de datos por contiente.
#
# <img src=".\img\63.png" width="750px" height="350px">
#
# Ahora surgen algunos patrones. Los países sudamericanos son bastante consistentes. Sus INB son bajos y su índice de desarrollo humano, esperanza de vida y los valores de escolaridad se encuentran mayoritariamente entre la mediana y el percentil 75.
#
# En Europa, se ve una amplia gama de GNI, pero las demás métricas son todas altas.
#
# En Africa, los INB son todos bajos, pero las otras métricas muestran un amplio rango.
#
# Lo maravilloso de este gráfico es que se pueden agregar más métricas al eje X. Puede compara fácilmente diez o viente variables a la vez.

# %% [markdown]
# # Coordenadas Polares
#
#
# ## Gráficos circulares
#
# Es un tipo de trama muy popular, pero lo hemos estado evitando por una buena razón.
#
# <img src=".\img\64.png" width="350px" height="350px">
#
#
#
# ## Atletas famosos de la ESPN, por deporte
#
#
# Aquí está el diagrama de barras de atletas famosos por deporte.
#
# <img src=".\img\65.png" width="350px" height="350px">
#
# ## Diagrama de barras + Coordenadas polares = Gráfico circular
#
# Si convierte el sistema de coordenadas para el gráfico de coordenadas cartesiano, es decir, ejes X e Y estándar, a coordenadas polares, se obtiene un gráfico circular.
#
# Un diagrama circular es solo un diagrama de barras donde las longitudes de las barras se convierten en ángulos. Desafortunadamente, este gráfico es mucho más difícil de interpretar que el gráfico de barras. Por ejemplo, es realmente difícil responder preguntar que fueron fácil con el gráfico de barra, como "¿Cuántos jugadores de críquet había en la lista?". La investigación de visualización de datos sugiere que los gráficos de barras casi siempre son más fáciles de interpretar que los gráficos circulares.
#
# <img src=".\img\66.png" width="350px" height="350px">
#
#
# ## ¿Cuándo hay que utilizar coordenadas polares?
#
# Entonces, la respuesta a la pregunta de cuándo debe usar coordendas polares es que casi nunca son una nuena idea.
#
# Hay una excepción, aunque es bastante específica. Si tiene datos que tienen alguna circulatidad natural, como la hora del día o una dirección, entonces las coordenadas polares pueden ser aceptables.
#
#
# ## Histograma de actividad animal
#
# <img src=".\img\67.png" width="450px" height="350px">
#
#
# Aquí hay un histograma de actividad animal del conjunto de datos de cámaras trampa de Panamá. Es una gran trama con un problema: la actividad de la paca nocturna parece estar dividida en dos, porque el grafico no reconoce que la medianoche a la izquierda del eje X es la misma que la medianoche de la derecha del eje X.
#
#
# ## Histograma + coordenadas polares = Gráfico de rosas
#
# Una posible solución es convertir los histogramas a coordenadas polaes, formando un diagrama de rosas. Esto es ligeramente diferente al gráfico circular porque es el eje X eso se convierte en ángulos, y las alturas de las barras aún permanecen como longitudes.
#
# Ahora si miras la actividad de la distribución de la paca, es más claro que se trata de un estallido de actividad que dura toda la noche, en lugar de dos estallidos separados.
#
# <img src=".\img\68.png" width="450px" height="350px">

# %% [markdown]
# # Sobrecarga sensorial
#
# Hay dos medidas básicas de qué tan buena es su visualización de dato.
#
# La primera medida es cuánta ideas puede obtener el lector de su trama. Para demasiadas parcelas, la respuesta es cero.
#
# La segunda medida es qué tan rápido el lector obtendrá esas ideas. Si su trama se presenta en una reunión, podría razonablemente esperar que la audiencia se concentre en la trama durante veinte segundos. A menudo, necesita transmitir su mensaje rápidamente.
#
#
# ## Chartjunk
#
# Chartjunk se refiere a cualquier cosa en la trama que dificulta que el lector obtenga una idea de los datos.
#
# Un término que es menos conocido es `skeuomorphism`. Eso significa agregar cosas que suceden en el mundo real a los objetos virtuales. Por ejemplo, podría agregar sombras en las barras en un gráfico de barras.
#
#
# ## Fotos
#
# Aquí hay un ejemplo de la cadena de televisión BBc, que se encuentra en el blog Junk Charts.
#
# Esto probablemente debería ser un gráfico de barras, pero dado que el eje Y no comienza en cero, sugiere que tal vez la BBC estaba buscando un diagrama de puntos. En cuyo caso, ¿La altura está representada por la parte superior de la cabeza del centro de la cabeza?
#
# Usar una imagen de un hombre en lugar de una barra hacer que las cosas sean más dificiles de entender, no más fáciles.
#
# <img src=".\img\69.png" width="550px" height="350px">
#
#
#
# ## Skeuomorphism
#
# Este ejemplo fue creado por el canal Fox News TV y encontrado por Media Matters for America.
#
# Puede ver algunos problemas familiares con el gráfico de barras, como el eje Y sin incluir el cero, disporsionando las alturas relativas de las barras. Observe también que los períodos de tiempo se han limitado arbitrariamente a octubre a abril, omitiendo lo ocurrido entre mayo y septiembre de cada año.
#
# Centrémonos en los elementos esqueomórficos de la trama. Hay una sombra en el panel de la trama, que no agrega valor, pero dado que viaja hacia arriba y hacia la derecha, da una señal subconsciente de que los números están aumentando.
#
# A las barras también se les ha dado una ligera profundidad. El aspecto 3D hace que sea más difícil juzgar con precisión dónde se encuentran contra el eje Y, por lo que las alturas de las barras deben escribirse en texto para compensar.
#
# Al eliminar toda la basura, los datos son más fáciles de ver.
#
# <img src=".\img\70.png" width="650px" height="350px">
#
#
# ##  Dimensiones Extras
#
# Este gráfico se encontró en el subreddit dataisuglyy tiene muchos problemas.
#
# Concentrémonos en el uso innecesario de la perspectiva 3D. Los diagrama de barras son inherentemente bidimensionales. Tiene categorías en un eje y una variable continua en el otro eje. Al hacer que las barrass ean tridimensionales, no proporciona información adicional, sino simplemente hace que sea más dificil juzgar la longitud de las barras.
#
#
# Un gráfico de barras 2D es más fácil de leer, aunque falta una etiqueta de categoría y los porcentajes no suman 100, por lo que no esta claro qué representa el eje Y.
#
# <img src=".\img\71.png" width="650px" height="350px">
#
#
# ## Colores y líneas ostentosas
#
# Aquí hay otro gráfico, que muestra asientos en el Consejo Federal Alemán. Hay dieciséis estados y siete partidos políticos.
#
# Los partidos normalemente tienen que entrar en una coalición de poder compartido para obtener escaños en cada estado. Cada partido político tiene un color asociado a su marca: CDU es negro, SPD es rojo, Grüne es verde, etc.
#
# Cada estado en el mapa o gráfico de rebanda de pastel tiene el color del partido que obtuvo la mayor cantiad de votos y galones coloreados por los otros partidos que comparten el poder.
#
# El problema es que la trama es demasiado fea para mirarla, por lo que nadie puede obtener información de ella. En general, las rayas u otras formas de eclosión se deben evitar en las tramas porque son simplemente difíciles de mirar.
#
#
# Se intento mejorar la trama, como se muestra a la derecha. Al eliminar la eclosión, es mucho más agradable ver la trama.
#
# <img src=".\img\72.png" width="650px" height="350px">

# %% [markdown]
# <h1 style='background:#000000; color:#FFFFFF;height: 55px;padding-top: 13px;font-size: 25px;border-style: double; border-color: #838931;'><center>Curso: Introducción a la Estadística</center></h1><a name="IntroducciónalaEstadística"></a>

# %% [markdown]
# # ¿Qué es la estadística?
#
#
# El campo de la estadística es la práctica y el estudio de la recopilación y el análisis de datos. La estadística tiene dos ramas principales.
#
# La estadísticas descriptiva o resumidas se utilizan para describir o resumir nuestros datos, mientras que las estadísticas inferenciales implican el uso de muestras para sacar conclusiones sobre la población que representan.
#
#
# ## ¿Qué pueden hacer las estadísticas?
#
# Las estadísticas nos permiten responder preguntas prácticas, tales como:
#
# Cual es el promedio del salario en los EE. UU., o cuántas consultas de clientes es probable que reciba una empresa por semana?. También tiene aplicacione en toda la sociedad.
#
# Podemos usar estadísticas para mejorar la seguridad de los productors o para ayudar a un gobierno a comprender las necesitades de una población.
#
# Los avances científicos se validan mediante el uso de estadísticas, incluida la conclusión de que las vacunas contra el covid-19 tuvieron una eficacia del 89% en la prevención de enfermedades graves en adultos mayores en el Reino Unido.
#
#
# ## Limitaciones de la Estadística
#
# Hasta aquí todo bien, pero las estadísticas tiene sus limitaciones.
#
# Las estadísticas requieren preguntas específicas y medibles, en lugar de preguntas amplias y abiertas. Por ejemplo, las estadísticas pueden decirnos si la músca rock es más popular que el jazz, basado en las ventas totales, o si las mujeres viven más que los hombres. Sin embargo, no podemos usar estadísticas para averiguar por qué existen relaciones, como por qué a la gente le gusta diferentes tipos de música, o por qué las mujeres viven más que los hombre.
#
#
#
# ## Tipos de datos: Númericos
#
# Ahora que sabemos lo que las estadísticas pueden y no pueden hacer, definamos los tipos de datos común, lo cual es importante para determinar cómo podemos analizar nuestros datos.
#
# Primero, tenemos datos numéricos o cuantitativos. Esto se puede dividir en dos subtipos.
#
# Los datos continuos se miden en una escala continua, tomando cualquier valor, como el precio de las acciones.
#
# También tenemos datos de intervalo o conteo. Estos se mide en números enteros, como contar cuántas tazas de café beben las personas por día.
#
# <img src=".\img\73.png" width="650px" height="350px">
#
#
# ## Visualización de datos numéricos
#
# Una forma común de visualizar la relación entre datos numéricos es usar un diagrama de dispersión.
#
#
# ## Tipos de datos: Categóricos
#
#
# Otro tipo de datos son los datos categóricos o cualitativos. Hay dos subtipos:
#
#
# Primero están los datos nominales, que describen categóricas desordenadas como el color de los ojos.
#
# El segundo tipo de datos categóricos son los datos ordinales, donde se ordenan las categorías. Por ejemplo, una encuesta puede pedir la opinión de la gente sobre si el baloncesto es el mejor deporte, con respuesta van desde muy en desacuerdo hasta muy de acuerdo.
#
#
# <img src=".\img\74.png" width="650px" height="350px">
#
#
# ## Visualización de datos categóricos
#
#
# Podemos visualizar la relación entre datos categórico y numérico agrupando los valores y luego realizando algún tipo de agregación.
#
# Podemos agrupar nuestro datos de delito por distrito de Londre, que son datos nominales y mostrar el número de robos, que son datos de intervalo, para cada municipio. Esta es una gran manera de comparar diferentes categorías.
#
#
#
# <img src=".\img\75.png" width="450px" height="350px">
#
#
# ## Descriptiva / Resumen estadistico
#
#
# Las estadística descriptivas o de resumen se utilizan para describir o resumir datos.
#
# Usando nuestro datos sobre el crimen en Londres como ejemplo, podemos describir que los robos en Wstminster representa alrededor del 36% de todos los robos en los cinco distritos que se muestran aquí.
#
# <img src=".\img\76.png" width="450px" height="350px">
#
#
# ## Estadistica inferencial
#
# Por el contrario, la estadística inferencial es el proceso de usar una muestra para sacar conclusiones sobre una población.
#
# Por ejemplo, podemos encuestar a 100 personas sobre si compran ropa después de ver publicidad en las redes sociales, y use esta muestra para inferir qué porcentaje de todas las personas compran ropa como resultado de la publicidad en las redes sociales.

# %% [markdown]
# # Medidas del centro
#
#
# ## ¿Por qué son útiles las medidas de centro?
#
# Es posible que nos pregunten cuál es el número promedio de pedidos de venta por mes en el trabajo, escuche sobre el costo típico de una casa, o pregúntese cuál es el color de cabello más común. Terminología como promedio, más común y valor típico son todos ejemplos de cómo las medidas del centro se expresan en la vida codifiana.
#
#
# ## Datos de Crimen
#
# Cada fila contieen un distrito londinense y los valores de conteo para cada tipo de delito en los últimos dos años.
#
#
# <img src=".\img\77.png" width="450px" height="350px">
#
# Podemos ver que hubo 5067 robos en el distrito londinense de Barnet.
#
#
# ## Histograma
#
# Exploremos otra forma de visualizar datos numéricos. Un histograma toma puntos de datos y los separa en contenedores o rangos de valores.
#
# Aquí hay un histograma de infracciones de vehiculos con ocho contenedores, cada uno con una altura separada correspondiente al número de distritos londinenses con un recuento de delitos vehiculares que cabe dentro del contenedor respectivo.
#
# El pico en el medio muestra que nueve distritos londinenses tuvieron entre 6000 y 7300 delitos contra vehículos en los últimos dos años.
#
# <img src=".\img\78.png" width="400px" height="300px">
#
#
# Los histograma son una excelente manera de resumir datos numéricos, pero también podemos usar estadísticas descriptivas.
#
#
# ## ¿Podríamos resumir los datos encontrando la cantidad típica de delitos contra vehículos en un distrito de Londres?
#
#
# Para responder esto, necesitamos determinar cuál es el valor típico o central de los datos.
#
# Desafortunadamente, esto puede seri difícil de determinar a través de la visualización de datos como nuestro histograma.
#
# Analizaremos tres forma de calcular el centro: la media, la mediana y la moda.
#
#
#
# ## Medidas de centro: Media
#
#
# La media, a menudo llamada promedio, es una de las formas más comunes de describir el centro de los datos. Calculamos la media sumando todos los valores y dividiendo por el número de valores. Por ejemplo, para calcular el número medio de robos por Municipio de Londres sumamos todos los valores y dividimos por el número de municipios, que es 32, esto nos da aproximadamente 3463 robos.
#
#
# Aquí podemos ver el valor medio para cada tipo de delito y en general, siendo el robo el que tiene la media más alta.
#
# <img src=".\img\79.png" width="250px" height="150px">
#
#
# ## Medidas de centro: Mediana
#
#
# Otra medida de centro es la mediana. Este es el valor medio de nuestros datos. Por lo danto, si ordenamos nuestro dados de menor a mayor, como se muestra aquí para robos según el distrito de Londres, el 50% de los valores deben ser inferior a la mediana y el 50% debe ser superior.
#
# <img src=".\img\80.png" width="450px" height="350px">
#
#
# Tenemos un número par de valores, ya que hay 32 distritos, por lo que tomamos los dos valores más cercanos a la mitad.
#
# <img src=".\img\81.png" width="450px" height="350px">
#
# Sumamos los dos valores y luego dividimos por dos. En este caso el resultado es 3416.5 ligeramente inferior a la media.
#
#
# ## Medidas de centro: Moda
#
# La tecera medida de centro es la moda, o valor más frecuente. Si contamos las ocurrenca de cada delito en todos los distritos de Londres, podemos ver que el valor más frecuente es el robo. Si buscamos el valor esperado de los datos categóricos, la moda generalmente es la medida más adecuada, ya que las categórias pueden no tener una representación numérica inherente.
#
# <img src=".\img\82.png" width="250px" height="350px">
#
#
# ## ¿Qué medida utilizar?
#
# La medida a utilizar depente de la situación.
#
# Tome este histograma de infracciones de vehículos, por  ejemplo.
#
# <img src=".\img\83.png" width="450px" height="350px">
#
# La forma de la trama es bastante simétrica, con un conteo que alcanza su punto máximo en el medio y desciente hacia cada lado.
#
# Cuando los datos son simétricos, la media y la mediana funcionan bien.
#
#
# Comparando esto con los robos, los datos no son simétricos: se acumulan la izquierda y terminando con un distrito que tiene una gran cantidad de robos.
#
# Cuando un valor es sustancialmente diferente a otro, lo llamamos un valor atípico. Este valor atípico atrae la media hacia él, mientras que la mediana se ve menos afectada. Esto se debe a que el cálculo de la media implica sumar todos los valores, por lo que los valore más grandes afectan el resultado, mienstras que la mediana solo mira el valor medio.
#
# Por lo tanto, cuando los datos no son simétricos, es mejor usar la mediana para describir el valor típico de los datos.
#
# <img src=".\img\84.png" width="450px" height="350px">

# %% [markdown]
# # Medidas de dispersión
#
# ## ¿Qué es Dispersión?
#
#
# Dispersión describe qué tan separados están los puntos de datos.
#
# ## Varianza
#
# Otra medida es la varianza, que calculoa la distancia promedio desde cada punto de datos hasta la media.
#
#
# Este gráfico muestra la distribución de delitos por distrito londinense, con la media mostrada como una línea vertical.
#
#
# <img src=".\img\85.png" width="450px" height="350px">
#
# Podemos ver que un distrito está mucho más lejos de la media. Para calcular la varianza, primero medimos la distancia desde cada punto de datos hasta el valor medio.
#
# Por ejemplo, el número total de delito en el distrito londinense de Westminster es 94923 y la media de delitos en todos los distritos es 47672. Para calcular la distancia, restamos la media del número de delitos en Westminster, 94923 menos 47672.
#
# <img src=".\img\86.png" width="450px" height="350px">
#
#
#
# Repetimos esto calculando las distancias para cada municipio y sumándolas.
#
# Desafortunadamente, si sumamos todas las distancias, entonces los valores negativos cancelamos los positivos, por lo que en este caso terminamos con una distancia total de cero. Par evitar esto, elevamos al cuadrado cada distancia y las sumamos. Esto da un total de más de siete mil millones.
#
# <img src=".\img\87.png" width="550px" height="350px">
#
#
# Como los datos representan todos los delitos en Londre, la varianza es la suma de las distancias al cuadrado divididas por el número de distritos, que es 32.
#
# Es importante tener en cuenta que la varianza está en unidades al cuadrado. En este caso, el conteo del crimen total al cuadrado.
#
# $variance (total crime) = 7509750824 / 32$
#
# $variance (total crime) = 234679713$
#
#
# ## Desviación Estándar
#
# Es difícil entender la cuenta del crimen total al cuadrado. Por lo tanto, podemos convertirlo a las unidades de nuestros datos tomando la raíz cuadrada de la varianza, una medida conocida como desviación estándar.
#
#
# $Desviación Estándar = \sqrt(variance(total crime))$
#
#
# $Desviación Estándar = \sqrt(234679713)$
#
# $Desviación Estándar = 15319.26$
#
# En general, cuanto más cerca esté la desviación estándar de cero, más agrupados estarán los datos alrededor de la media.
#
#
# ## Desviación estándar en un histograma
#
# <img src=".\img\88.png" width="350px" height="350px">
#
# Aquí podemos ver cuán dispersos están los datos al mostrar una distancia de una y dos desviaciones estándar de la media.
#
#
# ## Cuartiles
#
# También podemos medir la dispersión usando cuartiles, que son una forma de dividir los datos en cuatro partes iguales.
#
# Aquí vemos el valor mínimo para varios delitos en Londre y los cuatro cuartiles: 25%, 50%, 75% y 100%.
#
# Para cada cuartil, el valor representa el porcentaje de valores que son menores o iguales a ese número.
#
# Podemos ver que el 75% de los distritos de Londre tuvieron menos de 4392 robos en los últimos dos años. Tenga en cuenta que el segundo cuartil es el valor medio, por lo que es igual a la mediana.
#
# <img src=".\img\89.png" width="550px" height="350px">
#
#
# ## Diagrama de caja
#
# Podemos visualizar cuartiles usando un diagrama de caja.
#
# El borde izquierdo de la caja es el primer cuartil, la línea media es la mediana, y borde derecho de la caja es el tercer cuartil. Los valores extremos se muestran más allá de las  líneas horizontales, como el punto por encima de 4000.
#
#
# <img src=".\img\90.png" width="450px" height="350px">
#
#
# ## Rango Intercuartílico o IQR
#
# Otra medida de dispersión es el Rango Intercuartílico o IQR. Es la distancia entre el primer y tercer cuartil.
#
# Para los robos en Londre, el IQR es de alrededir de 1080, lo que significa que el 50% medio de los distritos todavía difieren en 1080 robos.
#
# El beneficio del IQR es que se ve menos afectao por valores extremos que otras medidas de dispersión como la desviación estándar.
#
# <img src=".\img\91.png" width="750px" height="350px">

# %% [markdown]
# # Distribuciones discretas
#
# Consideremos lanzar un dado estándar de seis caras. Hay seis resultados posibles y cada uno tiene una sexta parte de posibilidades de ocurrir. Este es un ejemplo de una distribución e probabilidad.
#
#
# ## Elegir a los vendedores
#
# Esto es similar a nuestro escenario anteior, excepto que teníamos nombre en lugar de números.
#
# Al igual que tirar un dado, cada resultado o nombre tenía la misma probabilidad de ocurrir.
#
# <img src=".\img\92.png" width="550px" height="350px">
#
#
# ## Distribución de probabilidad
#
# Una distribución de probabilidad describe la probabilidad de cada resultado posible en un escenario. También podemos encontrar el valor esperado de una distribución, que es la media. Calculamos esto multiplicando cada valor por su probabilidad, un sexto en este caso, y sumando todo junto. Entonces, el valor esperado de lanzar un dado justo es 3.5.
#
# <img src=".\img\93.png" width="550px" height="350px">
#
#
# ## ¿Por qué es importante entender las distribuciones de probabilidad?
#
#
# Nos ayudan a cuantificar el riesto e informar la toma de decisiones. Además, se utilizan distribuciones de probabilidad en la prueba de hipótesis para comprender si los resultados pueden haber ocurrido por casualidad.
#
#
# ## Visualizar una distribución de probabilidad
#
# Podemos visualizar una distribución de probabilidad usando un histograma, donde cada barra representa el resultado, y la altura de cada barra representa la probabilidad de ese resultado.
#
# <img src=".\img\94.png" width="450px" height="350px">
#
#
# ## Probabilidad = Area
#
# Podemos calcular las probabilidades de diferentes resultados tomando áreas de la distribución de probabilidad.
#
# Por ejemplo, ¿Cuál es la probabilidad de que nuestra tirada sea menor o igual a dos?. Para resolver esto, tomaremos el área de cada barra que representa un resuldado de dos o menos.
#
# Cada barra tiene un ancho de uno y una altura de un sexto, por lo que el área de cada barra es un sexto. Sumando las áreas de uno y dos, obtenemos una probabilidad de un tercio.
#
#
# <img src=".\img\95.png" width="450px" height="350px">
#
#
# ## Dado desigual
#
#
# Ahora digamos que tenemos un dado donde los dos se convirtieron en tres.
#
# <img src=".\img\96.png" width="450px" height="350px">
#
# Esto significa que ahora tenemos un cero por ciento de posibilidades de obtener un dos y un 33% de posibilidades de obtener un tres.
#
# Para calcular el valor esperado de este dado, ahora multiplicamos dos por cero, ya que es imposible obtener un dos y un tres por su nueva probabilidad, un tercio. Esto nos da un valor esperado de 3.67.
#
# $(1 * 1/6)+(2*0)+(3*1/3)+(4*1/6)+(5*1/6)+(6*1/6) = 3.67$
#
#
# ## Visualización de probabilidades desiguales
#
# Cuando visualizamos estas nuevas probabilidades, las barras ya no son pares.
#
#
# <img src=".\img\97.png" width="450px" height="350px">
#
#
# ## Agregar zonas
#
# Con este dado, ¿cuál es la probabilidad de obtener algo menor o igual a dos?
#
# Hay un sexto de probabilidad de obtener uno y cero probabilidad de obtener dos, que suma un sexto.
#
#
#
# <img src=".\img\98.png" width="450px" height="350px">
#
#
# ## Distribuciones de probabilidad discretas
#
#
# Las distribuciones de probabilidad que hemos visto hasta ahora son discretas, ya que representan situaciones con resultados discretos. Por lo tanto, representan datos de conteo o de intervalo.
#
# En este caso de un dado, estamos contando puntos, por lo que no podemos sacar 1.5 o 4.3. Cuando todos los resultados tiene la misma probabilidad, como un dado justo, esto se denomina distribución uniforme discreta.
#
#
# ## Muestreo de una distribución discreta
#
# Al igual que tomamos muestras de nombres de una caja, podemos hacer lo mismo con las tiradas de dados.
#
# Estos son los posibles resultados de una tirada (roll -> tirada). Su valor esperado es 3.5.
#
# Si lanzamos un dado 10 vecesm estamos muestreando con reemplazo, ya que podemos obtener el mismo resultado más de una vez. Aquí cuatro tiros produjeron un 2.
#
#
# <img src=".\img\99.png" width="450px" height="350px">
#
#
# ## Visualizar una muestra
#
# Podemos visualizar los resultados de los 10 lanzamientos usando un histograma.
#
#
# <img src=".\img\100.png" width="450px" height="350px">
#
#
# ## Distribucion de muestras vs. Distribucion teórica
#
# Como la muestra fue aleatoria tenemos números diferentes, a pesar de que existe la misma probabilidad de que salga cada número.
#
# La media de nuestra muestras es 3.0, que no está muy cerca de los 3.5 que esperábamos.
#
# <img src=".\img\101.png" width="750px" height="350px">
#
#
# ## Una muestra mayor
#
# Si tiramos el dado 100 veces, la distribución de los tiros se ve un poco más parejos y la media está más cerca de 3.5.
#
# <img src=".\img\102.png" width="300px" height="350px">
#
#
# ## Una muestra aún mayor
#
#
# Si tiramos 1000 veces, se parece aún más a la distribución de probabilidad teórica y la media se acerca mucho a 3.5.
#
#
# <img src=".\img\103.png" width="300px" height="350px">
#
#
# ## Ley de los grandes números
#
# Esto se llama ley de los grandes números.
#
# Si aumentamos el tamaño de la muestra, su media se aproximará a la media teórica.
#
# <img src=".\img\104.png" width="150px" height="350px">

# %% [markdown]
# # Distribuciones continuas
#
#
# Podemos usar distribuciones discretas para modelar situaciones que involucran datos en conteo o de intervalo, pero ¿Cómo podemos modelar datos continuos?
#
#
# ## Esperando el autobús
#
# El autobús urbano llega cada 12 minutos, por lo que si nos presentamos a una hora aleatoria, podríamos esperar en cualquier lugar, desde 0 minutos si llegamos justo cuando llega el autobús, hasta 12 minutos si llegamos cuando sale el autobús.
#
# <img src=".\img\105.png" width="450px" height="350px">
#
#
# ## Distribución uniforme continua
#
# Modelemos este escenario con una distribución de probabilidad. Hay una cantidad infinita de minutos que podríamos esperar ya que podríamos esperar 5 minutos, 1.5 minutos, 1.3 minutos, y asi sucesivamente. Por lo tanto, no podemos crear bloques individuales como podríamos hacerlo con datos de conteo o intervalor. En cambio, usaremos una línea continua para representar la probabilidad.
#
# La linea es plana ya que existe la misma probabilidad de esperar cualquier tiempo de 0 a 12 minutos.
#
# Esto se llama la distribución uniforme continua.
#
# <img src=".\img\106.png" width="500px" height="350px">
#
#
# ## Probabilidad = Área
#
#
# Ahora que tenemos nuestra distribución, calculamos la probabilidad de que esperemos entre 4 y 7 minutos.
#
# Al igual que con las distribuciones discretas, podemos tomar el área de 4 a 7 para calcular la probabilidad.
#
# El ancho de este rectángulo es de 7 menos 4, que da 3. La altura es de doceavo.
#
# Multiplicandolos juntos para obtener el área, obtenemos 3/12 o 25%.
#
# <img src=".\img\107.png" width="500px" height="350px">
#
#
#
# ## Esperar siete minutos o menos
#
#
# ¿Qué pasa con la probabilidad de esperar 7 minutos o menos?
#
#
# Podemos pensar en esto como un espacio dentro del área total donde el límite superior es 7 minutos y el limite inferior es 0 minutos.
#
# Para calcular la probabilidad restamos el límite inferior, en este caso, 0 de 12 minutos posibles, desde el límite superior, que es 7 de 12 minutos posibles. 7 menos 0 es 7. Dividimos el resultado de esto por el área total debajo de la línea, que es el tiempo máximo posible que podemos esperar, que son 12 minutos . Así que la probabilidad de esperar 7 minutos o menos por el bus es 7/12, o aproximadamente 58.3%.
#
#
# <img src=".\img\108.png" width="450px" height="350px">
#
#
# ## Área total = 1
#
# Para encontrar la probabilidad de esperar en cualquier lugar entre 0 y 12 minutos, multiplicamos 12 por 1/12, que es 1, o 100%.
#
# Esto tiene sentido ya que estamos seguros de que esperaremos entre 0 y 12 minutos
#
# <img src=".\img\109.png" width="450px" height="350px">
#
#
#
# ## Probabilidad de esperar más de siete minutos
#
#
# Entonces, si sabemos que la probabilidad total es 1, y la probabilidad de esperar 7 minutos o menos es 58.3 %, entonces podemos usar esto para encontrar la probabilidad de esperar más de 7 minutos.
#
# Simplemente restamos la probabilidad de esperar 7 minutos o menos de la probabilidad total. Entonces, 1 menos 7/12 es igual a 5/12, o alrededor del 42%.
#
#
# <img src=".\img\110.png" width="450px" height="350px">
#
#
# ## Distribución Bimodal
#
#
# Las distribuciones continuas pueden tomar formas distintas a las uniformes, donde algunos valores tiene una mayor probabilidad que otros.
#
# Por ejemplo, aquí podemos ver una distribución con dos valores que ocurren con mayor frecuencia.
#
# Esto se conoce como distribución bimodal, ya que hay dos modas.
#
# Un ejemplo de la distribución bimodal son los precios de los libros, con diferentes valores típicos que ocurren dependiendo de si el libro es de bolsillo o de tapa dura.
#
#
# <img src=".\img\111.png" width="350px" height="350px">
#
#
# ## La Distribución Normal
#
#
# Otra distribución continua tiene un pico en el medio, con pendientes simétricas a meida que los valores se alejan del centro en cualquier dirección.
#
# Esto a menudo se describe como una curva en forma de campana y se denomina distribución normal.
#
# Es muy común observar esta distribución, como ocurre con la presión arterial o la edad de jubilación.
#
# <img src=".\img\112.png" width="350px" height="350px">
#
#
#
# ## Área Total = 1
#
#
# Independientemente de la forma  de la distribución, el área debajo de ella siempre debe ser igual a uno, ya que el ´rea cubre el 100% de los resultados posibles.
#
#
# <img src=".\img\113.png" width="650px" height="350px">

# %% [markdown]
# # La distribución binomial
#
#
# ## Lanzamiento de monedas
#
# Empezaremos lanzando una moneda, que tiene dos posibles resultados, cara o cruz, cada uno con una probabilidad del cincuenta por ciento.
#
#
#
# <img src=".\img\114.png" width="150px" height="350px">
#
#
# ## Resultados binarios
#
# Este es un ejemplo de resultado binario, donde puede ocurrir dos valores posibles.
#
# También podríamos representar estos valores como un `1` o `0`, un éxito o un fracasp, y una victoria o una derrota.
#
# <img src=".\img\115.png" width="150px" height="350px">
#
#
# ## Una moneda lanzada muchas veces
#
#
# Podemos realizar múltiples lanzamientos de una sola moneda y registrar los resultados, como aquí, donde las caras se representan como uno y las cruces como cero.
#
#
# <img src=".\img\116.png" width="150px" height="350px">
#
#
# ## Distribución Binomial
#
# La distribución binomial describe la probabilidad del número de éxitos en una secuencia de eventos independientes.
#
# Por ejemplo, puede decirnos la probabilidad de obtener cierto números de caras en una secuencia de lanzamientos de monedas. Tenga en cuenta que esta es una distribución discreta ya que estamos trabajando con un resultado contable.
#
# La distribución binomial se puede describir usando dos parámetros, **`n`** y **`p`**.
#
# **`n`** representa el número total de eventos que se está realizando y **`p`** es la probabilidad de éxito, en este caso, cara.
#
# ---
#
# Así es como se ve la distribución para 10 lanzamientos de monedas.
#
# <img src=".\img\117.png" width="350px" height="350px">
#
# Tenemos la mayor posibilidad de obtener cinco caras y una posibilidad mucho menor de obtener 0 o 10 caras.
#
#
# ## Probabilidad de 7 o menos caras
#
#
# Al igual que con otras distribuciones, podemos calcular la probabilidad de los resultados sumando el área.
#
#
# Si queremos la probabilidad de obtener 7 caras o menos en 10 lanzamientos, sumamos la probabilidad de sacar 0 caras, 1 cara, 2 caras y así sucesivamente hasta 7 caras inclusive.
#
# <img src=".\img\118.png" width="350px" height="350px">
#
# Hay una probabilidad del 94.5 % de sacar 7 caras o menos.
#
#
# ## Probabilidad de 8 o más caras
#
#
# Asi mismo, para calcular la probabilidad de 8 o más caras, podemos restar la probabilidad de 7 o menos caras de la probabilidad total, o 1.
#
# Esto da un resultado de alrededor de 5.55% de probabilidad.
#
# <img src=".\img\119.png" width="350px" height="350px">
#
#
#
# ## Valor esperado
#
# El valor esperado de una distribucipon binomial se puede calcular multiplicando **`n`** por **`p`**.
#
#
# $Valor \ esperado = n * p$
#
# Y en una grafica de Distribución Binomial el valor esperado está representado por la barra con **`el valor esperado está representado por la barra con el pico más alto`**, donde el valor esperado es igual al valor que toma **`n`** donde se encuentra esa barra más alta.
#
# El número esperado de caras al lanzar 10 monedas es 10 veces 0.5, que es 5.
#
# Si no conocemos **`p`**, pero conocemos **`n`** y el valore esperado, podemos calcular **`p`** dividiendo el valor esperado por n.
#
# $p = valor \ esperado \div n$
#
#
#
# ## Independencia
#
# Para que se aplique la distribución binomial, cada evento deben ser independientes, por lo que el resultado de un evento no debería afectar al siguiente.
#
#
# Por ejemplo, si elegimos al azar de estas tarjetas con ceros y unos, tenemos una probabilidad de 50-50 de obtener un cero o un uno.
#
# Si las probabilidades cambian según el resultado de un evento anterior, la distribución binomial no se aplica.
#
# <img src=".\img\120.png" width="250px" height="350px">
#
#
# Pero si estamos muestreando sin reemplazo, las probabilidades de el segundo evento son diferentes debido al resultado del primer evento. Como estos eventos no son independientes, no podemos calcular probabilidades precisas para esta situación utilizando la distribucion binomial.
#
# <img src=".\img\121.png" width="250px" height="350px">
#
#
#
# ## Aplicaciones generales
#
# La distribución binomial se puede utilizar en cualquier escenario en el que eventos independientes producen resultados binarios y no requiere la misma probabilidad para cara resultado.
#
#
# Los ejemplos incluye ensayos clínicos que miden la efectividad de un fármaco, donde el resultado es si la droga trabaja o no, o no apostar por el resultado de un partido deportivo, donde el apostante puede ganar o perder.

# %% [markdown]
# # La distribución normal
#
#
# Es una distribución de probabilidad continua. Es una de las distribuciones de probabilidad más importantes que aprenderemos desde varias estadísticas los métodos se basan en él y se aplica a más situaciones del mundo real que las distribuciones que hemos cubierto hasta ahora.
#
#
# ## ¿Qué es la distribución Normal?
#
# La distribución Normal de ve así.
#
# <img src=".\img\122.png" width="350px" height="350px">
#
#
# Su forma se conoce comúnmente como una curva de campana. Esta distribución tiene algunas propiedades importantes.
#
# ## Simetrica
#
#
# Primero, es simétrico, por lo que el  lado izquierdo es una imagen especular del lado derecho.
#
# ## Área = 1
#
# En segundo lugar, al igual que cualquier distribución de probabilidad, el área debajo de la curva es igual a 1.
#
#
# ## La curva nunca llega a 0
#
# En tercer lugar, la probabilidad nunca llega a cero, incluso si lo parece en los extremos de la cola.
#
# Por ejemplo, las probabilidades de obtener un valor superior a 10 es inferior al 0.5%, pero es posible.
#
#
#
# ## Descrita por la media y la desviación típica
#
#
# La distribución normal se describe por su media y la desviación estándar.
#
#
# Aquí hay una distribución normal con una media de 20 y una desviación estándar de 3, y la derecha una distribución normal con una media de cero y una desviación estandar de uno.
#
# <img src=".\img\123.png" width="650px" height="350px">
#
# Observe cómo ambas distribuciones tienen la misma forma, pero sus ejes tienen escalas diferentes.
#
#
# ## Área bajo la distribución normal
#
# Para la distribución normal, el 68% del área está dentro de una desviación estándar de la media.
#
#
# <img src=".\img\124.png" width="350px" height="350px">
#
#
# El 95% del área cae dentro de dos desviaciones estándar de la media.
#
# <img src=".\img\125.png" width="350px" height="350px">
#
# Y el 99.7% del área cae dentro de tres desviaciones estándar.
#
# <img src=".\img\126.png" width="350px" height="350px">
#
# Esto aveces se llama la regla 68-95-99.7.
#
#
# ## ¿Por qué es importante la distribución normal?
#
#
# En primer lugar, muchos datos del mundo real se parecen mucho a la distribución normal.
#
# Por ejemplo, aquí hay un histograma que muestra el porcentaje de escuelas en cada región del Reino Unido logrando calificaciones aprobatorias para los exámentes de fin de escuela secundaria.
#
# Dibujar una línea sobre la forma del histograma se parece mucho a la distribución normal.
#
# <img src=".\img\127.png" width="650px" height="350px">
#
#
# En segundo lugar, en la prueba de hipótesis, nuestros datos deben seguir una distribución normal para realizar muchas pruebas estadísticas, como comparar la media de una muestra con la población que representa.
#
#
# ## Asimetría
#
# Cuando interpretamos la distribución de datos, a menudo usamos la asimetría, que describe la dirección en la que los datos se reducen.
#
# Por ejemplo, la gráfica de la izquierda tiene un pico a la izquierda y una cola a la derecha, por lo que describimos la distribución como sesgada positiva o sesgada a la derecha, ya que la cola está a la derecha donde están los valores positivos más grandes.
#
# Por el contrario, una distribución sesgada negativamente o sesgada a la izquierda alcanza su punto máximo a al derecha y disminuye a la izquierda.
#
#
# <img src=".\img\128.png" width="650px" height="350px">
#
# Es muy común observar asimetría en los datos del mundo real, como los ingresos de los hogares, que suelen tener un sesgo postivo debido a que algunos hogares ganan mucho más que el ingresos típico.
#
#
# ## Curtosis
#
#
# También podemos interpretar una distribución por su curtosis, que es una manera de describir la ocurrencia de valores extremos en una distribución.
#
# Hay tres tipos de curtosis.
#
# La primera es la curtosis positiva, también conocida como leptocúrtica, que es caracterizado por un gran pico alrededor de la desviación estándar media y más pequeña, que se muestra aquí en rojo.
#
# Una distribución mesocúrtica es el término usado para describir la distribución normal, que se muestra como la curva azul en el gráfico.
#
# Por ultimo, la curtosis negativa, también conocida como platicúrtica, describe una distribución con un pico más bajo y una desviación estándar más grande, como se resalta aquí en verde.
#
#
# <img src=".\img\129.png" width="450px" height="350px">

# %% [markdown]
# # El
#
# ## Tirar un dado cinco veces
#
# Volvamos a nuestro ejemplo de lanzamiento de dados.
#
# Podemos lanzar un dado justo de 6 caras 5 veces y registrar los resultados.
#
# <img src=".\img\130.png" width="450px" height="350px">
#
# Ahora, tomaremos la media de los cinco lanzamientos, lo que nos da 2.
#
#
# Si tiramos otra 5 veces y sacamos la media, obtenemos una media diferente. Y si lo hacemos de nuevo, obtenemos otra media.
#
# <img src=".\img\131.png" width="450px" height="350px">
#
#
# ## 10 juegos de cinco dados
#
# Podemos repetir esto 10 veces: tiraremos un dado cinco veces, tome la media de ese conjunto de 5 lanzamientos y repitra 10 veces.
#
# Estos son los resultados, que muestran la media de cada conjunto de 5 lanzamientos.
#
# <img src=".\img\132.png" width="100px" height="350px">
#
#
#
# ## Distribuciones de muestreo
#
# También podemos trazar estas medias.
#
# Una distribución de una estadística de resumen como la media se denomina distribución de muestreo. Esta distribución, especificamente, es una distribución muestral de la media muestral.
#
#
# <img src=".\img\133.png" width="350px" height="350px">
#
#
# ## 100 medias muestrales
#
# Podemos repetir este proceso para tomar 100 medias muestrales.
#
# <img src=".\img\134.png" width="350px" height="350px">
#
# Si observamos la nueva distribución de muestreo, su forma se aprece un poco a la distribución normal, a pesar de que la distribución de resultados para cada tirada de dados es uniforme.
#
#
# ## 1000 medias muestrales
#
#
# Tomemos 1000 medias muestrales. Esta distribución de muestre se parece más a la distribución normal.
#
# <img src=".\img\135.png" width="350px" height="350px">
#
#
# ## 10000 medias muestrales
#
# La forma se mantiene constante en 10000 medias muestrales.
#
# <img src=".\img\136.png" width="350px" height="350px">
#
#
# ## 100000 medias muestrales
#
# 100000 medias muestrales:
#
# <img src=".\img\137.png" width="350px" height="350px">
#
# ## 1000000 medias muestrales
#
#
# <img src=".\img\138.png" width="350px" height="350px">
#
#
# ## Teorema del límite central
#
# Este fenómeno se conoce como el teorema del límite central, que establece que una distribución muestral se aproximará a una distribución normal a medida que aumente el tamaño de la muestra.
#
#
# En nuestro ejemplo, la distribución muestral se acercó más a la distribución normal a medida que tomamos más y más medidas muestrales.
#
# <img src=".\img\139.png" width="550px" height="350px">
#
# Es importante tener en cuenta que el teorema del limite central solo se aplica cuando las muestras son tomados aleatoriamente y son independientes, por ejemplo, seleccionando aleatoriamente acuerdos de venta con reemplazo.
#
# En general, se requiere un tamaño de muestra de al menos 30 para que se aplique el teorema del límite central.
#
#
#
# ## Desviación Estandar y el CLT
#
#
# El teorema del límite central, o CLT, también se aplica a otra estadísticas de resumen.
#
# Si tomamos la desviación estándar de 5 lanzamientos 1000000 veces, las desviaciones estándar de la muestra son distribuida normalmente, centrada alrededor de 1.9, que es la desviación estándar de la distribución.
#
#
# <img src=".\img\140.png" width="350px" height="350px">
#
#
#
# ## Proporcion y el CLT
#
# Otra estadística al que se le aplica el teorema del límite central es la proporción.
#
# Tomemos una muestra de un dado 5 veces con reemplazo y veamos cuántas veces sacamos un 4.
#
#
# En este caso, el 20% de los lanzamientos eran 4.
#
# Si volvemos a muestrear, el 60% de los lanzamientos son 4. (el cuatro deberia decir roll y result)
#
# <img src=".\img\141.png" width="550px" height="350px">
#
#
#
# ## Distribución muestral de la proporción
#
# Si repetimos esto 1000 veces y graficamos la distribución de cuatros en cada muestra, se asemeja a una distribución normal, centrada alderededor de 0.16, ya que hay una posibilidad entre seis de sacar un 4.
#
# <img src=".\img\142.png" width="350px" height="350px">
#
#
# ## Media de la distribución muestral
#
# Dado que estas distribuciónes de muestreo son normales, podemos tomar su media para obtener una estimación de la media, la desvicación estándar o la proporción de una distribución.
#
#
# Aquí podemos ver nuestra distribución de mil medias muestrales, con una linea de puntos roja que muestra le media teórica para una tirada de dados de 3.5. También hemos incluido la media de la muestra como una línea de puntos verde, que es 3.53.
#
# <img src=".\img\143.png" width="450px" height="350px">
#
# Este es un ejemplo de la ley de los grande números en acción. Con nuestros ejemplo de lanzamientos de dados, sabemos cómo se ven las distribución subyacentes, como la media, la desviación estándar y las proporciones, pero si no lo hacemos, esto puede ser un método útil para estimar las caracteristicas de una distribución subyacente.
#
#
# ## Ventajas del teorema central del límite
#
#
# El teorema del límite central también es útil cuando tenemos una gran población y no tienen el tiempo o los recursos para recopilar datos sobre todos.
#
# En cambio, podemos recolectar muestras más pequeñas y crear una distribución de muestreo para estimar estadísticas de resumen.
#
#
# <img src=".\img\144.png" width="550px" height="350px">

# %% [markdown]
# # La distribución de Poisson
#
# ## Proceso de Poisson
#
# Antes de hablar de probabilidad, definamos un proceso de Poisson.
#
# Un proceso de Poisson es un proceso donde se conoce el número promedio de evento en un período de tiempo dado, pero el tiempo o espacio entre eventos es aleatorio.
#
# Los procesos de Poisson son muy comunes en nuestro día a día. Por ejemplo, el número de animales adoptados de un refugio de animales cada semana es un proceso de Poisson; podemos saber que en promedio hay ocho adopciones por semana, pero el tiempo entre adopciones puede diferir aleatoriamente.
#
# Otros ejemplos serían el número de personas que llegan a un restaurante cada hora, o el número de visitas al sitio web de una empresa en un día.
#
# Comprender los procesos de Poisson puede ser extremadamente valioso en una variedad de entornos.
#
#
#
# ## Distribución de Poisson
#
#
# La distribución de Poisson describe la probabilidad de que ocurra una cierta cantidad de eventos durante un período fijo de tiempo.
#
# Podemos usar la distribución de Poisson para calcular la probabilidad de al menos 5 animales adoptados en una semana, la probabilidad de que 20 personas lleguen a un restaurante en una hora, o la probabilidad de menos de 200 visitas al sitio web de una empresa en un día.
#
#
# ## Lambda ($\lambda$)
#
#
# La distribución de Poisson se describe mediante un valor llamado `lambda`, que representa el número promedio de evento por período de tiempo.
#
# En el ejemplo del restaurante, este sería el número promedio de clientes por hora, que es 20 ($\lambda = 20$). Este valor es también **el valor esperado de la distribución**.
#
#
# Una distribución de Poisson de tamaño de muestra 200 y lambda igual a 20 se ve así.
#
#
# <img src=".\img\145.png" width="350px" height="350px">
#
#
# Note que es una distribución discreta ya que estamos contando eventos, y 20 es el número más probable de visitantes en una hora.
#
#
# ## Lambda es el pico de la distribución
#
#
# Lambda cambia la forma de la distribución.
#
# Usando nuestro ejemplo de client de restaurantes por hora, podemos ver una distribución de Poisson con lambda igual a 10, en verde, representa un valor típico de 10 usuarios por hora. Esto se ve bastante diferente a una distribución de Poisson con lambda igual a 20, en azul, o lambda igual a 50, en rojo, pero pase lo que pase, el pico de la distribución siempre está en su valor lambda.
#
#
# <img src=".\img\146.png" width="350px" height="350px">
#
#
#
# ## El teorema central del límite sigue siendo aplicable
#
#
# Al igual que otras distribuciónes, si tenemos un gran número de muestras y calculamos la media para cada uno, entonces la distribución de las medias muestrales de una distribución de Poisson se parece a la distribución normal.
#
# <img src=".\img\147.png" width="350px" height="350px">
#
#
#
# ## Probabilidad de 13 clientes en una hora
#
#
# Podemos calcular la probabilidad de un número especifico de clientes en un restaurante midiendo la altura de la barra que representa ese valor.
#
# Por ejemplo, la probabilidad de que exactamente 13 clientes visiten el restaurante en una hora, dado que el promedio es de 20 clientes, es 2.71%
#
# <img src=".\img\148.png" width="350px" height="350px">
#
#
# ## Probabilidad de 25 o más clientes
#
# Asi mismo, para calcular la probabilidad de almenos 25 clientes visiten el restaurante en una hora podemos sumar las alturas de todos las barras a partir del 25. En este caso, la probabilidad es de poco más de 11%.
#
# <img src=".\img\149.png" width="350px" height="350px">

# %% [markdown]
# # Test de Hipotesis
#
#
# ## ¿Por qué es necesario conocer las pruebas de hipótesis?
#
# La prueba de hipótesis es un grupo de teorías, métodos y técnicas para comparar poblaciones. Entonces, ¿por qué necesitamos saber sobre la prueba de hipótesis?
#
# En primer lugar, se utiliza de forma rutinaria en muchas industrias. Por ejemplo, una empresa puede tener la teoría de que aumentar el precio de sus productos aumentará los ingresos, o cambiar el nombre de un sitio web podría aumentar el tráfico. Incluso podemos usar pruebas de hipótesis para analizar si un medicamente es efectivo en el tratamiento de condiciones de salud específicas.
#
#
# ## La historia de las pruebas de hipótesis
#
#
# No solo nos rodea la prueba de hipótesis, sino que también es una disciplina bien establecida.
#
# Los primeros orígenes se remontan al siglo XVIII cuando el análisis del nacimiento, los registros mostraron que cada nacimiento tiene una probabilidad ligeramente mayor de ser hombre que mujer.
#
#
# ## No suponga nada
#
#
# En la prueba de hipótesis, siempre comenzamos con la suposición de que no existe diferencia entre las poblaciones. Hacemos esto para reducir el riesgo de introducir cualquier sesgo en nuestras pruebas. Esto se llama  la **hipótesis nula  (`Ho`)**.
#
# Podemos ampliar el ejemplo de la proporción de nacimientos de hombre y mujeres para observar los suplementos de vitamina C.
#
# Nuestra hipótesis nula podría ser que (**Ho**):
#
#  - No hay diferencias en la proporción de nacimientos por genero entre las mujeres que consumen vitamina C y las que no.
#
# Luego creamos una **hipótesis alternativa**, que típicamente puede tomar una de dos formas, nacimientos entre mujeres que toman suplementes de vitamina C VS. aquellas que no los toman O podemos establecer la dirección de la diferencia, por ejemplo (**H1**):
#
#  - Existe una diferencia en la proporción de nacimientos por sexo entre las dos poblaciones.
#  - Se producen más nacimientos femeninos entre las mujeres que toman suplementos de vitamina C.
#
#
# ## Flujo de trabajo de las pruebas de hipótesis
#
#
# Hay muchas formas de realizar pruebas de hipótesis, pero el flujo de trabajo general es:
#
# Primero, decidimos las diferencias entre poblaciones que queremos analizar, en este caso, mujeres adultar que usan o no suplementes de vitamina C.
#
# Luego, desarrollamos hipótesis nulas y alternativas, que los nacimientos tienen la misma probabilidad de ser masculinos o femeninos en ambas poblaciones, o que es más probable que los bebés sean mujeres en mujeres que toman suplementos de vitamina C.
#
#
# Ahora recopilamos nuestros datos de muestra. Específicamente, recopilamos el estado de género de los bebés nacidos en ambas poblaciones.
#
# Luego realizamos pruebas estadísticas en los datos de la muestra.
#
# Finalmente, usamos los resultados para sacar conclusiones sobre la población que representa la muestra.
#
#
# ## ¿Cuántos datos necesitamos?
#
# Entonces, ¿de cuántos nacimientos necesitamos registrar el género?
#
# Aplicando el teorema del límite central, con un tamaño de muestra mayor el número medio de nacimientos de hombre y mujeres se acerca a la media de la población.
#
# Sin embargo, recolectar muestras grandes puede requerir mucho tiempo y recursos. Un enfoque común es mirar la investigación revisada por pares sobre prueba de hipótesis similares para averiguar el tamaño de las muestras. Esto puede servir como punto de referencia.
#
#
# ## Variables independientes y dependientes
#
#
# Una nota sobre la terminología.
#
# En la prueba de hipótesis, definimos los datos en términos de diferencia que esperamos observar en la hipótesis alternativa.
#
#
# **La variable independiente** describe los datos que esperamos que no se vean afectados por otros datos.
#
# Para nuestra prueba de hipótesis de proporción de natalidad de género y vitamina C, esto sería suplementos de vitamina C, lo que significa que es independiente de la proporción de nacimientos de hombre y mujeres.
#
#
# **La variable dependiente** son los datos que esperamos que se vean afectados por otros valores.
#
# En la hipótesis alternativa, proponemos que la proporción de género al nacer puede verse afectado por la suplementación con vitamina C, por lo que depende de la vitamina C.
#
#
# Estos términos se usan comúnmente cuando se describe los resultados de las pruebas de hipótesis, así como al visualizar resultados como en un diagrama de dispersión, donde la variable independiente siempre está en el eje X y la variable dependiente está en el eje Y.

# %% [markdown]
# # Experimentos
#
#
# ## Experimentos, tratamiento y control
#
#
# Los experimentos son un subconjunto de la prueba de hipótesis que implica realizar pruebas estadísticas en datos de muestra para sacar conclusiones sobre una población.
#
# Esto no solo se aplica a la academia y la investigación; Los experimentos también ocurren en la industria, particularmente para obtener información sobre productos e impulsar mejoras en el rendimiento comercial.
#
# Los experimentos generalmente tienen como objetivo responder una pregunta en la forma "¿Cuál es el efecto del tratamiento en la respuesta?", donde el tratamiento se refiere a la variable independiente, y la respuesta a la variable dependiente.
#
#
# ## La publicidad como tratamiento
#
# Como ejemplo de un experimento, podemos desear saber qué efecto tiene un anuncio sobre el número de productos comprados.
#
# En este caso, el tratamiento es un anuncio y la respuesta es la cantidad de productos comprados.
#
# La visualización de los resultados mediante un gráfico de barras sugiere que el tratamiento puede haber sido eficaz para aumentar el número de productos comprados.
#
# <img src=".\img\150.png" width="650px" height="350px">
#
#
# ## Experimentos controlados
#
# Un tipo común de experimentos es un experimento controlado, donde los participantes se asignan aleatoriamente al grupo de tratamiento o al grupo de control.
#
# En nuestro ejemplo, el grupo de tratamiento verá un anuncion y el grupo de control no.
#
# Aparte de esta diferencia, los grupos deben ser comparables para que podamos determinar si ver un anuncio hace que la gente compre más.
#
# Si los grupos no son comparables, podemo sacar conclusiones incorrectas en función de los resultados.
#
# Si la edad promedio de los participante en el grupo de tratamiento es de 25 años y la edad promedio de los participantes en el grupo de control tiene 50 años, la edad podría influir potencialmente en los resultados, donde es más probable que las personas más jóvenes compren más, lo que hace que el experimento sesgue hacia el tratamiento.
#
# <img src=".\img\151.png" width="350px" height="350px">
#
#
#
# ## El estándar de oro de los experimentos
#
# El estandar de oro, o experimento ideal, eliminará la mayor cantidad de sesgos posibles.
#
# **El primer método** para ayudar a eliminar el sesgo en los experimentos controlados es utilizar la aleatorización.
#
#
# **Aleatorización:**
#
# En este protocolo de experimentos, los participantes son asignados al grupo de tratamiento o control al azar, no debido a algunas características.
#
# La aleatorización ayuda a garantizar que los grupos sean comparables.
#
# Esto se llama un ensayo controlado aleatorio.
#
# ---
#
# **El segundo método** es utilizar el cegamiento.
#
# **Cegador:**
#
# En un ensayo ciego, los participantes no saben si están en el grupo de tratamiento o de control.
#
# Esto asegura que el efecto del tratamiento se deba al tratamiento mismo, no a la idea de recibir el tratamiento.
#
# Esto puede implicar el uso de un placebo, que es algo que se parece al tratamiento pero no tiene ningún efecto.
#
# Esto es común en los ensayos clínicos que prueban la efectividad de un fármaco, donde al grupo de control se le dará una pastilla de azúzar que tiene efectos mínimos sobre la respuesta.
#
#
# ---
#
# En un ensayo controlado aleatorio doble ciego, la persona que administra el tratamiento o ejectura el experimento tampoco sabe si están administrando el tratamiento real o un placebo.
#
# Esto protege contra el sesgo en la respuesta, así como el análisis de los resultados.
#
#
#
# Todas estas diferentes herramientas se reducen al mismo principio: cuantas menos oportunidades de sesgo en nuestro experimento, más confiable podremos concluir si el tratamiento afecta la respuesta.
#
#
# ## Ensayos controlados aleatorios VS. pruebas A/B
#
#
# Los ensayos controlados aleatorios pueden tene múltiples grupos de tratamientos si el objetivo es probar la diferencia entre múltiples tratamientos, como diferentes dosis de un medicamento.
#
# Son populares en el mundo académico, particularmente en la investigación científica y clínica. Sin embargo, los ensayos controlados aleatorios también se denominan puebas A/B, a menudo cuando se utilizan en industrias como marketing e ingeniería.
#
# La diferentecia es que las pruebas A/B solo dividen a los participantes en dos grupos: **Tratamiento** y **Control**.

# %% [markdown]
# # Correlación
#
#
# ## Relaciones entre dos variables
#
#
# Recuerde que podemos usar un diagrama de dispersión para visualizar las relaciones.
#
# Aquí graficamos los costos de agua vs, membresías de gimnasio en diferentes ciudades.
#
# Es difícil determinar si existe una relación clara entre estas dos varibles.
#
# <img src=".\img\152.png" width="350px" height="350px">
#
#
# ## Coeficiente de correlación de Pearson
#
#
# Aquí es donde el coeficiente de correlación de Pearson, a menudo denominado coeficiente de correlación, resulta útil.
#
# Cuantifica la fuerza de una relación entre dos variables, produciendo un valor entre -1 y 1.
#
# Este número corresponde a la fuerza de la relación entre las variables, y el signo, positivo o negativo, corresponder a la dirección de la relación.
#
#
# ## Relaciones lineales
#
# Tenga en cuenta que el coeficiente de correlación de Pearson solo se puede utilizar para relaciones lineas, lo que significa que los cambios entre las variables son proporcionales.
#
# Por ejemplo, digamos que una botella de agua cuesta un dólar, y el precio mensual de la membresía de un gimnasio es de veinte dólares en Londres.
#
# Si el agua cuesta el doble en París, la membresía de un gimnaso debería costar 40 dólares.
#
# <img src=".\img\153.png" width="400px" height="350px">
#
#
#
# ## Valores = Fuerza de la relación
#
#
# Aquí hay un diagrama de dipersión de dos variables, X e Y, que tienen un coeficiente de correlación de 0.99.
#
# Los datos están estrechamente agrupado alrededor de una línea diagonal, por lo que describimos esto como una relación casi perfecta o muy fuerte.
#
# <img src=".\img\154.png" width="300px" height="350px">
#
# Si conocemos el valor de X, tendremos una buena idea de cuál podria ser el valor de Y.
#
# ---
#
# Comparando esto con un coeficiente de correlación de 0.75, los puntos de datos aún tienden hacia arriba y hacia la derecha, pero están más dispersos.
#
# <img src=".\img\155.png" width="700px" height="350px">
#
#
# ---
#
#
# Este gráfico (gráfico izquierdo) muestra una correlación de 0.56, que se consideraría una relación moderada.
#
# Un coeficiente de correlación alrededor de 0.21 se consideraría una relación débil.
#
#
# <img src=".\img\156.png" width="600px" height="350px">
#
#
# ---
#
# Cuando el coeficiente de correlación es cercano a 0, X e Y no tiene ninguna relación y el diagrama de dispersión parece completamente aleatorio.
#
# Esto significa que conocer el valor de X no nos dice nada sobre el valor de Y.
#
# <img src=".\img\157.png" width="300px" height="350px">
#
#
#
# ## Signo = Dirección
#
# El signo del coeficiente de correlación corresponder a la dirección de la relación.
#
#
# Un coeficiente de correlación positivo indica que a medida que X aumenta, Y también aumenta.
#
# Un coeficiente de correlación negativo indica que medida que X aumenta, Y disminuye.
#
# <img src=".\img\158.png" width="600px" height="350px">
#
#
# ## Costo de GYM vs. costo del agua
#
# Dado lo que sabemos ahora sobre la correlación, ¿cúal es el coeficiente de correlación entre dos costos de agua y los costos del gimnasio?
#
#
# <img src=".\img\159.png" width="350px" height="350px">
#
#
# Bueno, no hay una línea clara, lo que sugiere que no es muy fuerta la relación, pero los valores tienden a aumentar juntos. Entonces, quizás haya una correlación positiva de débil a moderada.
#
#
# ## Añadir una línea de tendencia
#
#
# Una línea de tendencia facilita la visualización de la relación.
#
# El coeficiente de correlación de Pearson es 0.35, lo que confirma una débil a moderada relación positiva entre el costo de la membresía de un gimnasio y el costo de una botellas de agua.
#
# <img src=".\img\160.png" width="350px" height="350px">
#
#
# ## Esperanza de vida frente al coste de una botella de agua
#
#
# Tenga cuidado al interpretar la relación entre variables utilizndo el coeficiente de correlación.
#
#
# Aquí hay una gráfica de la esperanza de vida y el costo de una botella de agua.
#
#
# Hay un coeficiente de correlación de 0.61, lo que sugiere una relación positiva moderada.
#
# <img src=".\img\161.png" width="350px" height="350px">
#
#
# ## Correlación no es sinónimo de causalidad
#
#
# ¿Significa esto que aumentar el costo del agua aumentará la esperanza de vida?
#
# Bueno, es importante distinguir que solo porque existe una relación, no significa que los cambios en los costos de agua resulten en un cambio en la expectativa de vida.
#
# Una frace popular entre los estadísticos es que la correlación no es igual a la causalidad.
#
#
#
# ## Variables de confusión
#
#
# Al observar las relaciones entre los datos, es importante preguntarse qué más podría estar afectando los valores.
#
# El costo de una botella de agua suele ser más alto en lugares con economías más fuertes, y pueden ofrecer un mejor acceso a atención médica de alta calidad.
#
# Así que quizás la esperanza de vida no se vea afectada por el costo de una botella de agua, en realidad se ve afectada por la fortaleza de la economía.
#
# Esto se conoce como una variable de confusión, que es algo que afecta los datos que están analizando, pero no se tuvo en cuenta al evaluar la relación entre las variables.

# %% [markdown]
# # Interpretación de los resultados de las pruebas de hipótesis
#
#
# ## Expectativa de vida en Chicago vs. Bangkok
#
#
# Supongamos que queremos probar si hay una diferencia en la esperanza de vida en Chicaco y Bangkok.
#
# Nuestra hipótesis nula es que no existe diferencia, y nuestra hipótesis alternativa podría ser que los residentes de Chicago tengan una esperanza de vida más larga que los residentes de Bangkok.
#
#
#
# ## Distribución de la muestra
#
# Podemos recopilar datos sobre la edad de muerte de 100 residentes en Chicago y Bangkok.
#
# Este histograma muestra las distribuciónes de muestras de esperanza de vida para cada ciudad.
#
# La esperanza de vida media de la muestra de Chicago es de 79.3 y la de Bangkok es de 73.9.
#
# <img src=".\img\162.png" width="350px" height="350px">
#
# Pero, ¿cómo sabemos que estos son los valores medios reales para cada población?
#
#
# ## Diferentes muestras
#
#
# Podríamos recopilar datos sobre la edad de la muerte de 100 residentes más en cada ciudad.
#
#
# <img src=".\img\163.png" width="350px" height="350px">
#
# Esta vez obtenemos resultados diferentes.
#
# Entonces, ¿estamos seguros de que realmente existe una diferencia en la esperanza de vida, o los resultados se deben al azar?. Dicho de otra manera, ¿las muestras realmente representan a estas poblaciones?
#
#
# ## Distribución muestral de la esperanza de vida media
#
#
# No podemos recopilar datos de toa la población, por lo que un enfoque es realizar un muestreo con reemplazo en nuestros datos originales de cada ciudad y calcule la esperanza de vida media para cada muestra.
#
# Repitiendo esto 10000 veces, visualizando los resultados, podemos ver distribuciones normales para la esperanza de vida media de Bangkok y Chicago, y Chicago tiene un valor esperado mayor.
#
# <img src=".\img\164.png" width="350px" height="350px">
#
#
# Entonces, ¿podemos ahora concluir que realmente existe una diferencia en la esperanza de vida?
#
#
# ## p-valor
#
#
# Cuando sacamos conclusiones en la prueba de hipótesis, usamos una métrica llamada **valor p**.
#
# Esta es la probabilidad de lograr un resultado al menos como extremo como el que hemos observado, asumiendo que la hipótesis nula es verdadera.
#
# Supongamos que queremos saber la probabilidad de una media muestral para la expectativa de vida de Chicago es mayor o igual a 82, dada una media poblacional de 79.3.
#
# Podemos visualizar la distribución de las medias de la muestra y mirar el área total desde 82 en adelante para determinar el valor p de 0.037, lo que significa que hay una probabilidad de 3.7% de observar una esperanza de vida media de 82 años o más.
#
# <img src=".\img\165.png" width="350px" height="350px">
#
# ***
#
# Podemos visualizar el valor p para nuestras dos distribuciones medias de muestras como el área total que se superpone entre ellas.
#
# <img src=".\img\166.png" width="350px" height="350px">
#
# Entonces, ¿qué tan pequeña es la superposición necesaria para tener confianza en nuestra conclusión?
#
#
# ## Nivel de significación ($\alpha$)
#
#
# Para reducir el riesgo de sacar una conclusión falsa, establecemos un umbral de probabilidad para rechazar falsamente la hipotesis nula.
#
# Este umbral de probabilidad se conoce como alfa ($\alpha$) o nivel de significación.
#
# Se decide antes de recopilar datos para minimizar el sesgo, ya que un investigador puede elegir un umbral después de haber visto los datos para que puedan sacar una conclusión que sirva a sus intereses.
#
# Un valor típico para esto es **0.05**, lo que significa que hay un 5% de posibilidad de concluir erróneamente que los residentes de Chicago viven más que los residentes de Bangkok.
#
# Después de la recopilación de datos, observamos si el valor p es menor o igual que alfa (**$p <= \alpha$**).
#
# Si el valor de p cumple con este criterio, podemos estar seguros de rechazar la hipótesis nula. Si esto ocurre, describimos los resultados como estadísticamente significativos.
#
#
#
# ## Error de tipo I/II
#
#
# En la prueba de hipótesis, hay cuatro conclusiones potenciales que podemos hacer con base en la hipótesis nula:
#
# * Podemos rechazar erróneamente nuestra hipótesis nula cuando en realidad era cierta. Esto se conoce como **error de tipo 1**.
#
# * Podemos aceptar erróneamente nuestra hipótesis nula cuando es falsa. Esto se conoce como un **error de tipo 2**.
#
# * Podemos aceptar correctamente la hipótesis nula cuando es verdadero.
#
# * y podemos rechazar correctamente la hipótesis nula cuando es falsa.
#
# <img src=".\img\167.png" width="550px" height="350px">
#
#
#
# ##  Sacar una conclusión
#
# Habiendo establecido alfa, ahora podemos sacar una conclusión basada en nuestras distribuciónes medias de muestra.
#
#
# La superposición de las distribuciones representa menos que nuestro umbral para alfa, 0.05, lo que significa que la probabilidad de la diferencia en la esperanza de vida media entre las dos ciudades que ocurren por casualidad es inferior al 5%.
#
#
# Por lo tanto, podemos rechazar la hipótesis nula y razonablemente concluir que la expectativa de vida promedio en Chicago es más alta que en Bangkok.
#
# <img src=".\img\168.png" width="350px" height="350px">

# %% [markdown]
# <h1 style='background:#000000; color:#FFFFFF;height: 55px;padding-top: 13px;font-size: 25px;border-style: double; border-color: #838931;'><center>Curso: Introducción a SQL</center></h1><a name="IntroducciónaSQL"></a>

# %% [markdown]
# ## Tips:
#
# - Las filas se conocen como registros y las columnas como campos.
#
# - Los nombres de los campos deben esta en minusculas y en singular, ademas no debo usar espacios, en lugar de los espacio debo usar _.
#
# - El nombre de una tabla debe esta en minuscula.
#
# - El nombre de un campo no debe ser igual al nombre de la tabla que la contiene.
#
# - Una clave unica, es un campo que identifica un registro con respecto a los demas.
#
# - Es mejor tener multiples tablas con diferentes tematicas, que una sola con diferentes temas, ya que sino se repiten filas (registros).
#
#
# # Datos
#
#
#
# ## Tipos de datos SQL
#
# Cuando se crea una tabla, se debe indicar un tipo de datos para cada campo.
#
# El tipo de datos se elige en función del tipo de datos que contendrá el campo: un número, texto o una fecha, por ejemplo.
#
# <img src=".\img\169.png" width="450px" height="350px">
#
# Usamos tipos de datos por varias razones.
#
# Primero, los diferentes tipos de datos se almacenan de manera diferente y ocupan diferentes cantidades de espacio de almacenamiento.
#
# En segundo lugar, algunas operaciones solo se aplican a ciertos tipos de datos. Tiene sentido multiplicar un número por otro número, pero no tiene sentido multiplicar texto por otro texto por ejemplo.
#
#
# ## Cadena
#
#
#
# En programación, una "cadena" se refiere a una secuencia de caracteres como letras o puntuación.
#
# En la tabla de usuario, los datos en el campo de nombre se componen de cadenas, como "Maham" y "James".
#
#
# <img src=".\img\170.png" width="450px" height="350px">
#
# SQL tiene varios tipos de datos diferentes que pueden contener cadenas. Algunos tipos de datos de cadena solo pueden contener cadenas cortas, como una cadena de  hasta 250 caracteres.
#
# Almacenar cadenas cortas en un tipo de datos pequeños como este ahorra espacio de almacenamiento.
#
# El tipo de datos **VARCHAR** de SQL es más flexible y puede almacenar cadenas pequeñas o grandes: Hasta descenas de miles de caracteres.
#
# Debido a su flexibilidad, VARCHAR se usa muy comúnmente para almacenar cadenas.
#
#
# ## Enteros
#
#
# Los tipos de datos enteros almacenan números enteros, como los años de la columna member_year de la tabla de usuarios.
#
# <img src=".\img\171.png" width="450px" height="350px">
#
# Al igual que con las cadenas, SQL ofrece algunos tipos de datos diferentes para almacenar números enteros, dependiendo de qué tan grandes sean los números que nos gustaría almacenar.
#
#
# **INT**, es un tipo de datos enteros común de SQL, puede almacenar números de menos de 2 mil millones negativos a más de 2 mil millones positivos.
#
#
# ## Flotantes
#
#
# Los tipos de datos flotantes almacenan números que incluyen una parte fraccionaria, como los 2.05 dolares que un clientes, Jasmin, debe en multas.
#
# <img src=".\img\172.png" width="450px" height="350px">
#
# Tal como cabría esperar, SQL también ofrece varios tipos de datos flotantes dependiendo de cuántos digitos se espera que tengan los números en el campo.
#
#
# El tipo de datos **NUMERIC** puede almacenar flotantes que tienen hasta 38 digitos en total, incluidos los anteriores y posteriores al punto decimal.
#
#
# ## Esquemas
#
# Ahora que estamos familiarizados con los tipos de datos, podemos ver un esquema de base de datos.
#
#
# <img src=".\img\173.png" width="450px" height="350px">
#
# Los esquemas a menudo se denominan "planos" de base de datos. Un esquema muestra el diseño de una base de datos, como qué tablas son incluidos en la base de datos y cualquier relación entre sus tablas.
#
#
# Un esquema también le permite al lector saber qué tipo de datos puede contener cada campo.
#
# El esquema de la base de datos de nuestra biblioteca muestra que el tipo de datos VARCHAR se usa para cadenas como el título del libro, el autor y el genero.
#
# También podemos ver que la tabla de usuarios está relacionada con la tabla de cajas, pero no con la tabla de libros.
#
#
# ## Almacenamiento de bases de datos
#
# Finalmente, hablemos del almacenamiento.
#
# La información que encontramos en una tabla de base de datos se almacena físicamente en el disco duro de un servidor.
#
# Los servidores son computadoras centralizadas que realizan servicios a través de las solicitudes realizadas a través de una red.
#
# En nuestro caso, el servicio que se realiza es el acceso de datos, pero los servidores también se utilizan para acceder a sitios web o archivos almacenados en el servidor.
#
# Cualquier computadora puede ser un servidor si está configurada para brindar un servicio, incluso una computadora portatil. Sin embargo, los servidores son generalmente máquinas muy poderodas y grandes, porque están mejor equipados para manejar un gran volumen de solicitudes y datos.
#
#
# <img src=".\img\174.png" width="350px" height="350px">

# %% [markdown]
# # Introdución a consultas
#
# ## ¿Para qué sirve SQL?
#
#
# SQL se usa para responder preguntas tanto dentro como entre tablas de bases de datos relacionales.
#
# En la base de datos de la biblioteca, podríamos usar SQL para encontrar qué libros sacó James de la biblioteca en 2022.
#
# En una base de datos de recursos humanos, podríamos consultar los salarios de los empleados en Marketing y Contabilidad para determinar si el pago entre departamentos es comparable.
#
#
# ## Lo mejor para grandes conjuntos de datos
#
# En muchas organizaciones, SQL se utiliza como complemente de otras herramientas, como las aplicaciones de hojas de cálculo.
#
# Si los datos que nos interesan caben en una hoja de cálculo y no tienen muchas relaciones con otros datos de interés, podemos analizarlo en una hoja de cálculo. Pero para datos extensos y diversos, como los datos relacionados a una plataforma minorista, lo mejor es organizar los datos en una base de datos.
#
# Luego, usamos consultas SQL para descrubir tendencias en el tráfico del sitio web, reseñas de clientes y ventas de productos.
#
# ¿Qué productos tuvieron las ventas más altas la semana pasada?.¿Qupe productos obtienen las peores puntuaciones de reseña de los clientes?. ¿Cómo cambió el tráfico del sitio web cuando se introdujo una función?. SQL brilla cuando una organización tiene muchos datos con relaciones complejas.
#
#
# ## Palabras clave
#
#
# Las palabras clave son palabras reservadas que se utilizan para indicar qué operación nos gustaría que realizara nuestro código.
#
# Las dos palabras clave más comunes sin **`SELECT`** y **`FROM`**.
#
# Tal vez nos gustariá una lista de todos los usuarios que tiene nuestra biblioteca.
#
#
# La palabra **`SELECT`** indica qué campos deben seleccionarse, en este caso, el campo de **name**.
#
# La palabra clave **`FROM`** indica la tabla en la que se encuentran estos campos, en este caso, la tabla de **patrons**.
#
# <img src=".\img\175.png" width="750px" height="350px">
#
#
# ## Nuestra primera consulta
#
# Juntemos estas partes.
#
#
# **`SELECT name
#  FROM patrons;`**
#
# Así es como se debe escribir la consulta. La instrucción SELECT aparece primero, seguida en la siguiente línea por la instrucción FROM. Se recomienda finalizar la consulta con un punto y coma **(;)** para indicar que la consulta está completa.
#
# También usamos mayúsculas en las palabras clave mientras mantenemos los nombres de las tablas y los campos en minúsculas.
#
# Ahora echemos un vistazo a los resultados de nuestra consulta, a menudo llamado conjunto de resultados.
#
#
# <img src=".\img\176.png" width="350px" height="350px">
#
# El conjunto de resultados enumera todos los nombre de los usuarios, tal como esperábamos. Tenga en cuenta que no hemos cambiado nuestra base de datos al escribir esta consulta. Las tablas, incluida la tabla de usuarios, son exactamente las mismas que antes de escribir la consulta.
#
#
# Para compartir nuestros resultados, podemos guardar el código SQL que tenemos escrito para que nuestros colaboradores puedan usarlo para consultar la base de datos ellos mismos.
#
#
# ## Seleccionar varios campos
#
#
# Para selecciónar varios campos, podemos enumerar varios nombre de campos después de la palabra clave **`SELECT`**, separados por comas. Por ejemplo, para seleccionar el número y el nombre de la tarjeta, enumeraríamos ambos nombre de campo en el orden en que nos gustaría que aparecieran en nuestro conjunto de resultados.
#
# <img src=".\img\177.png" width="450px" height="350px">
#
#
# Tenga en cuenta que esto no tiene que coincidir con el orden en que se presentan los campos en la tabla: enumerar el nombre antes de car_num significa que el nombre aparece primero en los resultados.
#
#
# ---
#
# Como era de esperar, podemos selecionar tres campos, como **name**,**card_num** y **total_fine** enumerado los tres nombre de campo después de la palabra clave **`SELECT`** y separándolos por comas.
#
# <img src=".\img\178.png" width="250px" height="350px">
#
#
# ## Seleccionar todos los campos
#
#
# ¿Qué sucede si deseamos seleccionar los cuatro campos de la tabla de usuarios?
#
# Podríamos enumerar los cuatro nombre de campo después de la instrucción **`SELECT`**, pero hay una forma más fácil: podemos decirle a SQL que selecciones todos los campos usando un asterisco **`(*)`** en lugar de los cuatro nombres de campo.
#
#
# <img src=".\img\179.png" width="350px" height="350px">

# %% [markdown]
# # Escribir consultas
#
#
# ## Alias
#
# A veces puede ser útil cambiar el nombre de las columnas en nuestro conjunto de resultados, ya sea por claridad o brevedad. Podemos hacer esto usando Alias.
#
# Tal vez nos gustaría seleccionar el nombre y el año de contratación para cada registri en la tabla de empleados. Podríamos alias la columna de nombre como first_name en la consulta agregando la palabra clave **`AS`** para indicar un alias de **first_name** después de seleccionar el campo de **name**.
#
#
# <img src=".\img\180.png" width="350px" height="350px">
#
#
# El conjunto de resultados ahora tiene **first_name** en lugar de **name** como encabezado de columna.
#
#
# El alias solo se aplica al resultado de esta consulta en particular; en otras palabras, el nombre del campo en la tabla de empleados sigue siendo **name** en lugar de **first_name**.
#
#
# ## Seleccionar registros distintos
#
# Algunas preguntas de SQL requieren una forma de devolver una lista de valores únicos.
#
# Imaginemos que nos interesa obtener una lista de años en los que contratamos a nuestros empleados actuales. Si seleccionamos el campo **year_hired** de la tabla de empleados, el resultado muestra varios años enumerados dos veces, que no es lo que estamos buscando.
#
# <img src=".\img\181.png" width="150px" height="350px">
#
#
# Para obtener una lista de años sin valores repetidos, podemos agregar la palabra clave **`DISTINCT`** antes del nombre del campo **year_hired** en la instrucción **`SELECT`**.
#
# <img src=".\img\182.png" width="200px" height="350px">
#
# Ahora, podemos ver que todos nuestros empleados fueron contratados en solo cuatro años diferentes.
#
#
# ## **`DISTINCT `**con varios campos
#
# Es posible devolver las combinaciones únicas de múltiples valores de campo enumerando varios campos después de la palabra clave **`DISTINCT`**.
#
#
# Tal vez nos gustaría saber los años que diferentes departamentos contrataron empleados. Podríamos usar esta consulta SQL para ver esta información, seleccionando **dept_id** y **year_hired** de la tabla de empleados.
#
#
# <img src=".\img\183.png" width="650px" height="350px">
#
# Al observar los resultados, vemos que el departamento tres contrató a dos empleados en 2021.
#
# Para evitar repetir esta información, podríamos agregar la palabra clave **`DISTINCT`** antes de los campos a seleccionar.
#
# <img src=".\img\184.png" width="250px" height="350px">
#
# Observe que los campos **dept_id** y **year_hired** todavía tiene valores repetidos individualmente, pero ninguno de los registros es igual: todos son combinaciónes únicas de los dos campos.
#
#
# ## Vistas
#
# Analicemos cómo guardar conjuntos de resultados de SQL.
#
# En SQL, una vista se refiere a una tabla que es el resultado de una intrucción SQL **`SELECT`** guardada.
#
# Las vistas se consideran tablas virtuales, lo que significa que los datos que contienen una vista generlamente no se almacenan en la base de datos. Más bien, es el código de consulta que se almacena para uso futuro.
#
# Un beneficio de esto es que cada vez que se accede a la vista, automáticamente actualiza los resultados de la consulta para tener en cuenta cualquier actualización de la base de datos subyacente.
#
#
# Para crear una vista, agregamos una línea de código antes de la declaración **`SELECT`**: **`CREATE VIEW`**, luego el nombre que nos gustaría para la nueva vista, luego la palabra **`AS`** para asignar los resultados de la consulta al nuevo nombre de vista.
#
#
# Aquí, creamos una vista llamada **employee_hire_years** asignando el resultado de una consulta seleccionando tres campos de la tabla de empleados a una nueva vista.
#
# <img src=".\img\185.png" width="350px" height="350px">
#
# No hay un conjunto de resultados al crear una vista.
#
#
# ## Utilizar vistas
#
#
# Sin embargo, una vez que se crea una vista, podemos consultarla como lo haríamos con una tabla normal seleccionando **`FROM`** la vista.
#
# <img src=".\img\186.png" width="200px" height="350px">

# %% [markdown]
# <h1 style='background:#000000; color:#FFFFFF;height: 55px;padding-top: 13px;font-size: 25px;border-style: double; border-color: #838931;'><center>Curso: SQL Intermedio</center></h1><a name="SQLIntermedio"></a>

# %% [markdown]
# # Consultar una base de datos
#
#
# ## Nuestra base de datos de películas
#
# Trabajaremos con una base de datos de películas que contiene cuatro tablas: películas, reseñas, personas y roles.
#
#
# <img src=".\img\187.png" width="750px" height="350px">
#
# El esquema de nuestra base de datos, que se muestra arriba, muestra los nombres de las tablas, los nombres de los campos y los tipos de datos.
#
#
# ## **`COUNT()`**
#
# Digamos que queremos contar algo de nuestra tabla de personas.
#
# La función **`COUNT()`** nos permite hacer esto devolviendo el número de registros con un valor en un campo. Por ejemplo, para contar el número de fecha de nacimientos presentes en la tabla de personas, usaremos **`SELECT COUNT(birthdate) AS count_birthdates FROM people;`**
#
#
# <img src=".\img\188.png" width="350px" height="350px">
#
# El resultado es 6152 nacimientos.
#
# Hemos usado el alias **count_birthdates** para el nombre del campo en este ejemplo para que los resultados sean más legibles.
#
#
# ## **`COUNT()`** múltiples campos
#
#
# Si queremos contar más de un campo, debemos usar **`COUNT()`** varias veces.
#
# Aquí contamos tanto el número de nombres como las fechas de nacimiento presentes en la tabla de personas.
#
#
# <img src=".\img\189.png" width="500px" height="350px">
#
#
# ## Uso de * con **`COUNT()`**
#
#
# Usar **`COUNT()`** con un nombre de campo nos dice cuántos valores hay en un campo. Sin embargo, si queremos contar la cantidad de registros en una tabla, podemos llamar a **`COUNT()`** con un asterisco (**`*`**). --> **`COUNT(*)`**.
#
# Por ejemplo, este código proporciona el número total de registros en una tabla de personas.
#
#
# <img src=".\img\190.png" width="250px" height="350px">
#
# El asterisco representa todos los campos.
#
# Pasar el asterisco a **`COUNT()`** es un atajo para contar el número total de registros.
#
#
#
# ## **`DISTINCT`**
#
# A menudo, nuestros resultados incluirán duplicados.
#
# <img src=".\img\191.png" width="150px" height="350px">
#
# Podemos usar la palabra clave **`DISTINCT`** para seleccionar todos los valores únicos de un campo.
#
# Esto puede ser útil si, por ejemplo, estamos interesados en saber qué idiomas están representados en la tabla de películas.
#
# Agregar **`DISTINCT`** a nuestra consulta eliminará todos los duplicados, como podemos ver a continuacion.
#
# <img src=".\img\192.png" width="200px" height="350px">
#
#
# ## **`COUNT()`** con **`DISTINCT`**
#
#
# Combinar **`COUNT()`** con **`DISTINCT`** también es común para contar la cantidad de valores únicos en un campo.
#
# Esta consulta cuenta el número de fechas de nacimiento distintas en la tabla de personas.
#
# <img src=".\img\193.png" width="550px" height="350px">
#
#
# Tomemos un momento para considera por qué este número es diferente del conteo de fechas de nacimiento de 6152 que obtuvimos antes.
#
# Es probable que algunas personas en nuestra mesa compartan el mismo cumpleaños; **`COUNT()`** incluiría todos los duplicados, mientras que **`DISTINCT`** cuenta todas las fechas únicas, sin importar cuántas veces aparezcan.

# %% [markdown]
# # Ejecución de consultas
#
# ## Orden de ejecución
#
# A diferencia de muchos lenguajes de programación, el código SQL no se procesa en el orden en que se escribe.
#
# Considere que queremos tomar un abrigo de un armario: primero, necesitamos saber qué armario contiene los abrigos.
#
# Esto es similar a la instrucción **`FROM`**, que es la primera línea que se procesará. Antes de que se pueda seleccionar cualquier dato, se debe indicar la tabla desde la cual se seleccionarán los datos.
#
# A continuación, se realiza nuestro **`SELECT`**. Finalmente, los resultados son refinados.
#
# Aquí usamos la palabra clave **`LIMIT`** que limita los resultados a un número específico de registros.
#
# En este caso, solo queremos devolver los primer 10 nombre de la tabla de personas.
#
# Conocer el orden de procesamiento es especialmente útil al depurar y crear alias de campos y tablas.
#
# Supongamos que necesitamos referirnos a un alias más adelante en nuestro código. En este caso, ese alias solo tendrá sentido para un procesador cuando en la declaración **`SELECT`** se procesa antes de que se haga la referencia de alias en otra parte de la consulta.
#
#
# ## Depuración de SQL
#
# Antes de comenzar a trabajar con consultas más avanzadas, el útil obtener más información sobre la depuración de código SQL y cómo leer los mensajes de error.
#
# Algunos mensajes son extremadamente útiles, señalando e incluso sugiriendo una solución para el error, como lo hace este mensaje cuando escribimos mal el campo **name** que nos gustaría seleccionar.
#
# <img src=".\img\194.png" width="550px" height="350px">
#
# Otros errore comunes pueden implicar mayúsculas o puntuación incorrectas.
#
#
# ## Errores de coma
#
# Otros mensajes de error son menos útiles y requieren que revisemos nuestro código más de cerca.
#
# Olvidar una com es un error muy común. Digamos que hemos redactado este código para encontrar todos los títulos, el país de origen y la duración de las películas.
#
#
# <img src=".\img\195.png" width="350px" height="350px">
#
# El mensaje de error nos alertará sobre la ubicación general del error mediante un signo de intercalación debajo de la línea de código, que en este caso apunta al nombre de campo **country**.
#
# Sin embargo, debemos examinar el código un poco más para descubrir que la como que falta esta entre **country** y **duration**.
#
#
#
# ## Errores de palabras clave
#
# SQL muestra un mensaje de error similar cuando una palabra clave está mal escrita, pero esta vez, el indicador de intercalación debajo de la línea ofensiva es perfecto.
#
#
# <img src=".\img\196.png" width="350px" height="350px">
#
#
# ## Nota final sobre los errores
#
#
#
# Hay algunos errores de SQL más, pero los tres mencionados anteriormente serán los más comunes que encontraremos.

# %% [markdown]
# # Estilo SQL
#
# ## Formato SQL
#
# SQL es un lenguaje generoso cuando se trata de formato. No se requieren líneas nuevas, mayúsculas ni sangría en SQL como lo son a veces en otros lenguajes de programación. Por ejemplo, el código de esta diapositiva se ejecutará correctamente y devolvera los primeros tres titulos, años de estreno, países de la tabla de peliculas.
#
# <img src=".\img\197.png" width="650px" height="350px">
#
#
# Sin emgargo, escribir consultas como esta no nos hará amigos en el mundo SQL porque la falta de formato hace que el código sea dificil de leer, especialmente cuando las consultas se vuelven más complejas.
#
#
# ## Buenas prácticas
#
# Con el tiempo, los usuarios de SQL han desarrollado estándares de estilo que generalmente se aceptan en todas las industrias.
#
# Este código devuelve los mismos resultados que el código anterior, pero es mucho más fácil de leer debido a la adición de palarbas clave en mayúsculas y nuevas líneas entre ellas.
#
# <img src=".\img\198.png" width="550px" height="350px">
#
#
# ## Guías de estilo
#
# Si bien las mayúsculas y las nuevas límeas de palabras clave son una práctica estándar, muchos de los detalles más finos del estilo SQL no lo son.
#
# Por ejemplo, algunos usuarios de SQL prefieren crear una nueva línea y sangrar cada campo seleccionado cuando una consulta selecciona varios campos, como lo hace la consulta en esta imagen.
#
# <img src=".\img\199.png" width="550px" height="350px">
#
#
# Debido a los diferentes estilos de formato, es útil seguir una guia de estilo SQL, como la de Holywell, que describe un estándar de mejores prácticas para sangría, uso de mayúsculas y convenciones de nomenclatura para tablas, campos y alias. Recuerde, sin embargo, que no hay un solo formato requerido en SQL: el principio rector es escribir código claro y legible.
#
#
# ## Punto y coma
#
#
#
#
# Al igual que las mayúsculas y las líneas nuevas, este punto y coma no es necesario en PostgreSQL; podríamos dejarlo fuera de la consulta y seguir esperando los mismos resultado sin errores.
#
# Sin embargo, incluir el punto y coma al final de la consulta se considera una buena práctica por varias razones:
#
# Primero, algunos tipos de SQL lo requieren, por lo que es un buen hábito.
#
# Incluir un punto y coma en una consulta de PostgreSQL significa que la consulta se traduce más fácilmente a otro tipo (sql server quizas) si es necesario.
#
# Además, al igual que un punto final de una oración, un punto y coma al final de una consulta indica su final, lo cual es útil en un archivo que contiene varias consultas.
#
#
# ## Nombres de campo no estándar
#
# Una última nota sobre el estilo SQL: aunque podemos asegurarnos de que nuestro código este bellamente formateado, no tenemos control sobre el estilo SQL de otras personas.
#
# Al crear una tabla, un error de SQL es incluir espacios en un nombre de campo.
#
# Para consultar esa tabla, necesitaremos encerrar el nombre del campo entre comillas dobles para indicar que, a pesar de ser dos palabras, el nombre hace referencia a un solo campo.
#
# Por ejemplo, si un codificador SQL hubiera nombrado un campo **release-space-year** como dos palabras, necesitariamos actualizar la consulta que hemos visto a lo largo de este capítulo a la que se muetra aquí.
#
#
# <img src=".\img\200.png" width="350px" height="350px">
#
#
# ## ¿Por qué damos formato?
#
# La adhesión a las guias de estilo de SQL permite una colaboración más sencila entre pares. Tener un código limpio y legible es muy valorado en la comunidad y una configuración profesional y hará las cosas más fáciles para cualquiera que quiera entender o depurar nuestras consultas.

# %% [markdown]
# # Filtrado de números
#
#
# ## **`WHERE`**
#
# Para filtrar, necesitamos usar una nueva cláusula llamada **`WHERE`**, que nos permite centrarnos solo en los datos relevantes para nuestras preguntas comerciales.
#
# Volviendo a nuestra analogía del abrigo, tal vez queramos seleccionar un abrigo del armario, donde el color es verde. La clausula **`WHERE`** puede ayudarnos con eso.
#
#
#
# ## **`WHERE`** con operadores de comparación
#
#
# Nos centraremos en filtrar números. Para hacer esto, usaremos operadores de comparación como mayor que.
#
# Este es un ejemplo de una consulta en la que filtramos para ver solo peliculas estrenadas despues el año 1960 usando operador mayor que.
#
#
# <img src=".\img\201.png" width="250px" height="350px">
#
#
# ## Operadores de comparación
#
#
# Exploremos algunos de los otros operadores.
#
# Usaríamos el operador menor que, para ver películas estrendas antes del año 1960.
#
#
# <img src=".\img\202.png" width="350px" height="350px">
#
# ---
#
#
# Usaríamos el operador menor o igual que, para ver peliculas estrenadas durante y antes del año 1960.
#
# <img src=".\img\203.png" width="350px" height="350px">
#
# ---
#
# Si queremos ver películas estrendas en un año especifico, podemo usar igual (=).
#
#
# <img src=".\img\204.png" width="250px" height="350px">
#
# ---
#
# Aquí un ejemplo final que no es tan intuitivo como los demás.
#
# Si quisieramos filtrar películas para ver todos los estrenos EXCEPTO los del año 1960, conbinariamos los simbolos < y >, como se muestra aquí.
#
#
# <img src=".\img\205.png" width="450px" height="350px">
#
# Este es el simbolo estándar de SQL que significa **no igual a**.
#
# ---
#
# **RECAPITULANDO:**
#
# <img src=".\img\206.png" width="250px" height="350px">
#
#
# ## **`WHERE`** con cadenas
#
# **`WHERE`** y el operador de comparación, =, también se pueden usar con cadenas.
#
# En esto casos, tendremos que usar comillas simples alrededor de las cadenas que queremos filtrar.
#
# Por ejemplo, aquí queremos filtrar títulos cuyo país sea Japón.
#
# <img src=".\img\207.png" width="250px" height="350px">
#
#
# ## Orden de ejecución
#
# Una nota final sobre el uso de **`WHERE`**.
#
# Similar a **`LIMIT`**, esta cláusula viene despues de las intrucción **`FROM`** al escribir una consulta.
#
# Si usamos **`WHERE`** y **`LIMIT`**, la orden escrita sera **`SELECT`**, **`FROM`**, **`WHERE`**, **`LIMIT`**; sin embargo, el orden de ejecución ahora será **`FROM`**, **`WHERE`**, **`SELECT`**, **`LIMIT`**.
#
# <img src=".\img\208.png" width="250px" height="350px">

# %% [markdown]
# # Múltiples criterios
#
# Aprenderemos sobre tres palabras clave adicionales que nos permitirán mejorar nuestro filtros al usar **`WHERE`** agregando múltiples criterios.
#
# Estos son **`OR`**, **`AND`** y **`BETWEEN`**.
#
# En el contexto de nuestros contexto de nuestro abrigos, podríamos mirar abrigos donde el color es amarillo, o el largo es corto, o podríamos filtrar por abrigs donde ambos criterios son verdaderos. También podemos buscar abrigos que tengan entre uno y cinco botones.
#
# <img src=".\img\209.png" width="350px" height="350px">
#
#
# ## Operador **`OR`**
#
#
# La primera palabra clave que veremos es el operador **`OR`**.
#
# **`OR`** se usa cuando queremos filtrar múltiples criterios y solo necesitamos satisfacer al menos una condición.
#
# Tal vez queramos seleccionar opciones de abrigo verder o morado como ejemplo.
#
#
# En SQL, combinamos **`OR`** con **`WHERE`** para lograr este tipo de filtrado.
#
# Aquí hay un ejemplo usando la base de datos de peliculas.
#
#
# La consulta de la izquierda devuelve todas las películas estrenadas en 1994 o 2000. Tenga en cuenta que debemos especificar el campo para cada condición **`OR`**, por lo que la consulta de la derecha no es valida. Esa consulta no ha especificado qué campo u operador debe asociarse con el año 2000.
#
#
# <img src=".\img\210.png" width="650px" height="350px">
#
#
# ## Operador **`AND`**
#
#
# Si queremos satisfacer todos los criterios en nuestro filtro, necesitamos usar **`AND`** con **`WHERE`**.
#
# Por ejemplo, esta consulta nos da los titulos de películas estrenadas en 1994 y 2000. Necesitamos especificar el nombe del campo por separado para cada condición **`AND`** como con **`OR`**.
#
#
# <img src=".\img\210.png" width="650px" height="350px">
#
#
#
# ## **`AND`**, **`OR`**
#
#
# Ahora queremos filtrar películas estrenadas en 1994 o 1995, Y con una certificación de PG o R.
#
# Afortundamente, podemos combinar **`AND`** y **`OR`** para responder esta preguntas. Si la consulta tiene múltiples condiciones de filtrado, necesitaremos encerar las cláusulas individuales en párentesis para asegurar el correcto orden de ejecución; de lo contrario, es posible que no tengamos los resultados esperados.
#
# <img src=".\img\212.png" width="450px" height="350px">
#
#
# ## **`BETWEEN`**, **`AND`**
#
# Como hemos aprendido, podemos usar esta consulta para obtener los títulos de todas las películas entre 1994 y 2000.
#
# Verificar rangos como este es muy común, por lo que en SQL la palabra clave **`BETWEEN`** proporciona una forma abreviada valiosa para filtrar valores dentro de un rango específico.
#
# La consulta de la derecha es equivalente a la de la izquierda.
#
# <img src=".\img\213.png" width="550px" height="350px">
#
#
# Es importante recordar que **`BETWEEN`** es inclusivo, lo que significa que los resultados contienen los valores inicial y final.
#
#
# ## **`BETWEEN`**, **`AND`**, **`OR`**
#
#
# Al igual que la cláusula **`WHERE`**, la cláusula **`BETWEEN`** puede ser usada con múltiples operadores **`AND`** y **`OR`**, por lo que podemos construir nuestras consultas y hacerla aún más poderosas.
#
#
# Por ejemplo, podemos obtener los títulos de todas las peliculas estrenadas entre 1994 y 2000 del Reino Unido.
#
# <img src=".\img\214.png" width="350px" height="350px">

# %% [markdown]
# # Filtrado de texto
#
# Como hemos visto brevemente, podemos usar la clausula **`WHERE`** para filtrar datos de texto. Sin embargo, hasta ahora, solo hemos podido filtrar especificando el texto exacto que nos interesa.
#
# A menudo querremos buscar un patrón en lugar de una cadena de texto específica en el mundo real.
#
# Introducideremos tres palabras clave SQL más en nuestro vocabularios para ayudarnos a lograr esto: **`LIKE`**, **`NOT LIKE`** e **`IN`**.
#
#
#
# ## **`LIKE`**
#
# En SQL, podemo usar el operador **`LIKE`** con una cláusula **`WHERE`** para buscar un patrón en un campo.
#
# Usamos un comodín como marcador de posición para algunos otros valores para lograr esto. Hay dos comodines con **`LIKE`**, el porcentaje y el guión bajo.
#
# El comodín del porcentaje coincidirá con cero, uno o varios caracteres del texto.
#
# Por ejemplo, la consulta de abajo coincide con una persona como Adel, Adelaide y Aden.
#
#
# <img src=".\img\215.png" width="200px" height="350px">
#
#
# El comodín del guión bajo coincidirá con un solo carácter (luego de la cadena propuesta).
#
# Por ejemplo, la consulta de abajo coincide solo con nombre de tres letras como Eve.
#
#
# <img src=".\img\216.png" width="350px" height="350px">
#
#
# También veríamos nombre como Eva si estuviera en nuestro conjunto de datos. Eva Mendes, sin embargo, no será visible a menos que los criterios de búsqueda tuvieran este especto ->  **`Ev_ Mendes`**.
#
#
# ## **`NOT LIKE`**
#
# También poemos usar el operador **`NOT LIKE`** para encontrar registros que no coincidan con el patrón especificado.
#
#
# En esta consulta, estamos encontrado registros de personas que no tiene el **A** como parte de su nombre. (**El . luego de la A no deberia ir,**)
#
# <img src=".\img\217.png" width="550px" height="350px">
#
# Es importante tener en cuenta que esta operación distingue entre mayúsculas y minúculas, por lo que debemos tener en cuenta lo que estamos consultando.
#
#
#
# ## Posición de comodín
#
#
# Hemos revisado un ejemplo de dónde colocar cada comodín, pero podemos ponerlos en cualquier lugar y combinarlos.
#
# Podemos encontrar valores que comiencen, terminen o contengan caracteres en cualquier posición, así como también encontrar registros de cierta longitud.
#
# Por ejemplo, este código de la izquierda encontrará a toas las personas cuyo nombre terminen en **r**.
#
# El codigo de la derecha encontrará registros donde el tercer carácter es **t**.
#
# <img src=".\img\218.png" width="550px" height="350px">
#
#
#
# ## **`WHERE`** , **`OR`**
#
#
# ¿Qué pasa si queremos filtrar en función de muchas condiciones o un rango de números?
#
# Podríamos encadenar varios **`OR`** a la cláusula **`WHERE`** en función de lo que sabemos, pero eso puede complicarse.
#
# Podemos ver un ejemplo aquí donde seleccionamos los titulos de películas estrenadas en 192, 1930 o 1940.
#
# <img src=".\img\219.png" width="250px" height="350px">
#
#
#
# ## **`WHERE`**, **`IN`**
#
# Un operador útil aquí es **`IN`**.
#
# El operador **`IN`** nos permite especificar múltiples valores en una cláusula **`WHERE`**, lo que hacer que sea más fácil y rápido establecer numerosas condiciones **`OR`**.
#
# Entonces, el ejemplo de código anterior simplemente se convertiria en: **`WHERE release IN (1920, 1930, 1940)`**, done los años están entre paréntesis.
#
# <img src=".\img\220.png" width="350px" height="350px">
#
#
# Aquí hay otro ejemplo usando un campo de texto, donde queremos encontrar el título DONDE el país asociado es Alemania o Francia.
#
# <img src=".\img\221.png" width="350px" height="350px">

# %% [markdown]
# # Valores NULOS
#
#
# ## Valores perdidos
#
# Cuando estábamos aprendiendo a usar la palabra clave **`COUNT()`**, aprendimos que podríamos incluir o excluir valores no perdidos dependiendo de si usamos o no el asterisco en nuestra consulta.
#
# * **`COUNT(field_name)`** incluye solo valores que no faltan
#
# * **`COUNT(*)`** Incluye valores que faltan
#
#
# Pero, ¿qué es un valor perdido o no perdido?
#
# En SQL, NULL representa un valor faltante o desconocido.
#
# ¿Por qué es útil?
#
# En el mundo real, nuestras bases de datos probablemente tendrán campos vacíos por error humano o porque la información no está disponible o es desconocida.
#
# Saber cómo manejar estos campos es esencial, ya que pueden afectar cualquier análisis que hagamos.
#
#
# ## null
#
# Por ejemplo, usamos **`COUNT all`**  con un asterisco a la izquierda. Supongamos que nuestro objetivo es analizar el éxito póstumo utilizando datos de la tabla de personas. Podríamos hacer la suposición equivocada de que debido a que tenemos un nombre de campo llamado fecha de muerte, esta información está disponible para todos.
#
# La mitad de ellos son, de hecho, NULL, como podemos ver a la derecha, por lo que haríamos un juicio inexacto sobre lo que significan los datos.
#
# <img src=".\img\222.png" width="650px" height="350px">
#
#
# ## **`IS NULL`**
#
#
# Una forma rápida de ver cuántos de nuestros datos faltan es usar **`IS NULL`** con la cláusula **`WHERE`**.
#
# Aquí hay un ejemplo en el que hemos verificado qué nombre no tiene una fecha de nacimiento registrada en nuestra tabla.
#
# <img src=".\img\223.png" width="200px" height="350px">
#
#
#
# ## **`IS NOT NULL`**
#
# A la izquierda hay un ejemplo de contar las fechas de nacimientos que faltan en la tabla de personas.
#
# <img src=".\img\224.png" width="250px" height="350px">
#
# La cuenta es 2245.
#
# A veces, querremos filtrar los valores faltantes, por lo que solo obtendremos resultados que no sean NULL. Para hacer esto, podemos usar el operador **`IS NOT NULL`**.
#
# Por ejemplo, esta consulta proporciona el recuento de todas las personas cuyos las fechas de nacimiento no falta en la tabla de personas, lo que nos da un nuevo conteo de 6152.
#
# <img src=".\img\225.png" width="350px" height="350px">
#
#
# ## **`COUNT()`** vs **`IS NOT NULL`**
#
# Puede hacer una pregunta sobre la diferencia entre usar **`COUNT`** con un nombre de campo y usando el mismo **`COUNT`** con la cláusula **`WHERE`** agregada con **`IS NOT NULL`**.
#
# La respuesta es que no hay diferencia, ya que ambos contarán los valores que no faltan.
#
#
# <img src=".\img\226.png" width="650px" height="350px">
#
#
# ## NULL en pocas palabras
#
#
# Los valores NULL son valores perdidos y son muy comunes en el mundo real. Es una buena práctica saber cuántos valores NULL hay en nuestros datos utilizando el operador **`IS NULL`** o **`IS NOT NULL`** para filtrar.
#
# Estas palabras clave ayudarán a identificar, seleccionar o excluir valores faltantes.

# %% [markdown]
# # Resumiendo datos
#
#
# Cuando analizamos datos, a menudo queremos entender el conjunto de datos como un todo, además de mirar registros individuales.
#
# Una forma de hacer esto es resumir los datos usando las funciones agregadas de SQL.
#
# Una función agregada realiza un cálculo en varios valores y devuelve un solo valor.
#
#
# ## Funciones Agregadas
#
# Una de ellas es la función **`COUNT()`**. Ahora aprenderemos cuatro funciones agregadas nuevas, que nos permitirán encontrar el promedio, la suma, el mínimo y el máximo de un campo específico.
#
#
# **`AVG()`**, **`SUM()`**, **`MIN()`**, **`MAX()`**, **`COUNT()`**.
#
#
# Estas funciones agregadas vienen después de **`SELECT`**, exactamente como **`COUNT()`**.
#
#
# Esta primera consulta nos da el valor promedio del campo de presupuesto de la tabla de películas.
#
# <img src=".\img\227.png" width="200px" height="350px">
#
# Eso es el promedio de más de 39 millones por películas en la tabla de películas.
#
# La función **`SUM()`** devuelve el resultado de sumar los valores en el campo de presupuesto.
#
# <img src=".\img\228.png" width="200px" height="350px">
#
#
# Aquí, el presupuesto total de todas las películas supera los 181 mil millones.
#
#
# La función **`MIN()`** devuelve el presupuesto más bajo y la función **`MAX()`** devuelve el presupuesto más alto.
#
# La película surcoreana de 2006 "The Host" tuvo un presupuesto de más de 12 mil millones. Eso suena enorme, pero nuestros datos están en varias monedas, por lo que una comparación verdadera también requeriría tipos de cambios de divisas.
#
#
# <img src=".\img\229.png" width="550px" height="350px">
#
# Tenga en cuenta que operamos en el campo (o columna) con todas estas funciones agregadas, no en los registros (o filas).
#
#
# ## Datos no numéricos
#
#
# Aunque estas funciones parecen ser matemáticas, podemos usar varios de ellos en campos numéricos y no numéricos.
#
# El promedio y la suma son las dos funciones agregadas que solo podemos usar en campos numéricos, ya que requieren aritmética
#
# **Campos solo numéricos:**
#
#    - **`AVG()`**
#    - **`SUM()`**
#
#
# Podemos usar **contar**, **mínimo** y **máximo** con campos no numéricos como ya vimos con **`COUNT()`**.
#
# **Varios tipos de datos:**
#
#    - **`COUNT()`**
#    - **`MIN()`**
#    - **`MAX()`**
#
#
# **`COUNT()`** puede proporcionar un total de cualquier registro que no falte o que no sean nulo en un campo, independientemente de su tipo.
#
# Del mismo modo, **`MIN()`** y **`MAX()`** darán el registro que figurativamente es el más bajo o el más alto.
#
# La más baja puede significar la letra **A** cuando se trata de cadenas o la fecha más antigua cuando se trata de fechas. Y, po supuesto, con los números, es el número más alto o el más bajo
#
#
# Estos son algunos ejemplos de estas funciones con campos no numéricos.
#
# Podemos seleccionar el país mínimo y máximo de la base de datos de películas y ver que nuestro país mínimo, o país que vendría primero en el alfabeto, es Afganistán. En contraste, Alemania Occidental es el país máximo que vendría último en el alfabeto.
#
#
# <img src=".\img\230.png" width="550px" height="350px">
#
# Nuestra base de datos no contiene películas hechas en Zambia o Zimbabue, pero tiene al menos una película hecha cuando Alemania eran dos países diferentes.
#
#
#
# ## Alias al resumir
#
# Observe cómo todos los resultados de la consulta han actualizado automáticamente el nombre del campo a la función.
#
# En este caso, **`MIN()`**.
#
# Es una buena práctica usar un alias al resumir datos para que nuestros resultados sean claros para cualquiera que lea nuestro código.
#
# <img src=".\img\231.png" width="650px" height="350px">

# %% [markdown]
# # Resumen de subconjuntos
#
#
# ## Utilización de WHERE con funciones agregadas
#
#
# Ahora combinaremos nuestras habilidades de filtrado con nuestras nuevas habilidades de resumen.
#
#
# Podemos combinar funciones agregadas con la cláusula **`WHERE`** para obtener más información de nuestros datos.
#
# Eso es porque la cláusula **`WHERE`** se ejecuta antes de la instrucción **`SELECT`**.
#
# Por ejemplo, para obtener el presupuesto promedio de las películas realizadas en 2010 o después, seleccionaríamos el promedio del campo de presupuesto de la tabla de películas donde el año estreno es mayor o igual a 2010.
#
# <img src=".\img\232.png" width="300px" height="350px">
#
#
# Aquí hay algunos ejemplos más usando las otras funciones: encontramos el presupuesto total de películas realizadas en 2010 usando la función **`SUM()`**, eso es más de 8.9 mil millones.
#
# Luego, obtenemos el presupuesto más pequeño usando la función **`MIN()`**, que es 65000.
#
# <img src=".\img\233.png" width="600px" height="350px">
#
#
# Aquí, consultamos el presupuesto más alto usando la función **`MAX()`**.
#
# <img src=".\img\234.png" width="300px" height="350px">
#
# 600 millones parece mucho para el presupuesto de una película, pero esto en rupias indias para la película "Kites".
#
#
# Finalmente, consultamos el recuento dela cantidad de presupuesto utilizando la función **`COUNT()`**, que nos da la cantidad total de valores no perdidos en el campo de presupuesto, lo que significa que hay 194 presupuestos registraos para el año 2010 en la tabla de películas.
#
# <img src=".\img\235.png" width="300px" height="350px">
#
#
#
# ## **`ROUND()`**
#
#
# Ahora que estamos haciendo todo tipo de cosas con nuestros valores numéricos, probablemente querremos limpiar algunos de los locos decimales que pueden aparecer.
#
# En SQL, podemos usar **`ROUND()`** para redondear nuestro número a un decimal específico. Hay dos parámetros para **`ROUND()`**: el número que queremos redondear y el lugar decimal al que queremos redondear.
#
# Aquí hemos vuelto a calcular el mismo presupuesto medio que antes, pero esta vez hemos incluido **`ROUND()`** y especificamos que queremos redondear a dos decimales porque estamos tratando con moneda.
#
#
# <img src=".\img\236.png" width="700px" height="350px">
#
#
# ##  **`ROUND()`** a un número entero
#
#
# El segundo parámetro en nuestra función **`ROUND()`** es opcional, por lo que podemos omitirlo si queremos redondear a un número entero.
#
# Obtendríamos el mismo resultado si pasamos cero como segundo argumento, ya que es el valor predeterminado cuando no se da ningún número.
#
#
# <img src=".\img\237.png" width="700px" height="350px">
#
#
# ## **`ROUND()`** utilizando un parámetro negativo
#
# Aquí hay algo complicado: también podríamos pasar un número negativo como segundo parámetro y aun así obtener un resultado.
#
#
# Aquí, la función redondea a la izquierda del punto decimal en lugar de a la derecha.
#
# <img src=".\img\238.png" width="350px" height="350px">
#
# El uso de -5 como parámetro de lugar decimal hará que la función redondee a las 100 mil o 5 posiciones a la izquierda.
#
#
# **`ROUND()`** solo se puede usar con campos numéricos.

# %% [markdown]
# # Alias y aritmética
#
#
#
# ## Aritmética
#
# Podemos realizar operaciones aritméticas básicas con símbolos como +, -, * y /. El uso de paréntesis con aritmética le indica al procesador cuándo debe ejecutarse el cálculo.
#
# Aquí hay algunos ejemplos básicos de cómo podemos usar la aritmética en SQL.
#
# Podemos sumar, restar, multiplicar y dividir de la siguiente manera.
#
# <img src=".\img\239.png" width="450px" height="350px">
#
# En estos ejemplos, los paréntesis no son necesarios, ya que solo tiene lugar un cálculo; sin embargo, proporcionan más claridad al código. Pero, la división da un resultado de uno, ¿por qué es eso?
#
# Similar a otros lenguajes de programación, SQL asume que queremos recuperar un número entero si dividimos un número entero por otro número entero.
#
# Al dividir, podemos agregar decimales a nuestros números si queremos más precisión.
#
# Por ejemplo:
#
# <img src=".\img\240.png" width="450px" height="350px">
#
#
#
# ## Funciones Agregadas VS. Aritmética
#
#
# ¿Cuál es la diferencia entre usar funciones agregadas y aritmética?
#
# La diferencia clave es que las funciones agregadas, como **`SUM()`**, realizan sus operaciones en los campos verticalmente, mientras que la aritmética suma los registros horizontalmente.
#
#
# <img src=".\img\241.png" width="550px" height="350px">
#
#
# ## Alias con aritmética
#
# Ejemplo aritmético usando nuestra base de datos:
#
# Aquí hemos seleccionado el bruto, cuánto hizo la película, menos el presupuesto, cuánto costó la película, de nuestra tabla de películas.
#
# El resultado es la cantidad de ganancia.
#
# Tenga en cuenta que el resultado de la consulta no nos proporciona un nombre de campo definido.
#
# <img src=".\img\242.png" width="550px" height="350px">
#
# Siempre necesitaremos usar un alias al resumir datos con funciones agregadas y aritmética.
#
#
# ## Alias con funciones
#
# A medida que avanzamos y aprendemos a manipular nuestros datos, será aún más importante mantener claro los nombres de nuestros campos.
#
# Por ejemplo, si estamos usando múltiples funciones **`MAX()`** en una consulta, tendremos dos campos llamados **max**, lo cual no es muy útil.
#
# <img src=".\img\243.png" width="300px" height="350px">
#
# Esta es una situación en la que es especialmente importante crear alias como lo hacemos aquí.
#
# <img src=".\img\244.png" width="300px" height="350px">
#
#
# ## Orden de Ejecución
#
#
# Exploremos cómo encaja el uso de un ala en el orden de ejecución de SQL.
#
# Aquí hay un recordatorio del orden de ejecución que conocemos hasta ahora:
#
# * **Paso N.º 1: **`FROM`****
# * **Paso N.º 2: **`WHERE`****
# * **Paso N.º 3: **`SELECT`**** (Alias definidos aquí)
# * **Paso N.º 4: **`LIMIT`****
#
# Al agregar un alias para un nombre de campo en la cláusula **`SELECT`**, podría suponer que podríamos usarlo más adelante en nuestra consulta con la cláusula **`WHERE`**.
#
#
# Desafortunadamente, eso no es posible; como podemos ver en el orden de ejecución, la consulta aún no habría creado el alias y nuestro código generaría un error.
#
# <img src=".\img\245.png" width="300px" height="350px">

# %% [markdown]
# # Ordenar Resultados
#
# Ahora aprenderemos a ordenar y agrupar los resultados para obtener más información.
#
# Ordenar los resultados significa que queremos poner nuestros datos en un orden específico. Es otra forma de hacer que nuestros datos sean más fáciles de entender al verlos rápidamente en una secuencia.
#
#
# ## **`ORDER BY`**
#
# En SQL, la palabra clave **`ORDER BY`** se usa para ordenar los resultados de uno o más campos. Cuando se usa solo, se escribe después de la instrucción **`FROM`**, como se muestra en la siguiente consulta.
#
# <img src=".\img\246.png" width="250px" height="350px">
#
# **`ORDER BY`** ordenará en orden ascendente de forma predeterminada. Esto puede significar de menor a mayor o de la A a la Z.
#
# En este caso, tenemos una consulta que ordena el presupuesto de menor a mayor y una segunda consulta ordenando alfabéticamente los títulos.
#
#
# <img src=".\img\247.png" width="350px" height="350px">
#
# Nuestra base de datos contiene títulos de películas que comienzan con símbolos y números; estos vienen antes de la letra A.
#
#
# ## **`ASC`**ending
#
# También podríamos agregar la palabra clave **`ASC`** a nuestra consulta para aclarar que estamos clasificando en orden ascendente.
#
# Los resultados son los mismos y nuestro código es más legible.
#
# <img src=".\img\248.png" width="250px" height="350px">
#
#
# ## **`DESC`**ending
#
#
# Podemos usar la palabra clave **`DESC`** para ordenar los resultados en orden descendente.
#
# Esta consulta nos da los títulos de películas ordenados por presupuesto de mayor a menor.
#
# <img src=".\img\249.png" width="350px" height="350px">
#
# Sin embargo, nuestros datos contiene muchos valores nulos.
#
# Podemos agregar una cláusula **`WHERE`** antes de **`ORDER BY`** para filtrar el campo de presupuesto solo para valores no nulos y mejorar nuestros resultados.
#
# <img src=".\img\250.png" width="300px" height="350px">
#
#
#
# ## Ordenar Campos
#
#
# Tenga en cuenta que no tenemos que seleccionar (**`SELECT`**) el campo que estamos ordenando.
#
# Por ejemplo, aquí hay una consulta en la que ordenamos por año de lanzamiento y solo miramos el título.
#
# <img src=".\img\251.png" width="350px" height="350px">
#
# Sin embargo, es una buena idea incluir el campo que estamos ordenando en la instrucción **`SELECT`** para mayor claridad.
#
# <img src=".\img\252.png" width="350px" height="350px">
#
#
# ## Ordenar múltiples campos
#
# **`ORDER BY`** también se puede usar para ordenar en varios campos.
#
# Ordenará por el primer campo especificado, luego ordenará por el siguiente, etc.
#
# Para especificar varios campos, separamos los nombres de los campos con una coma.
#
# El segundo campo por el que ordenamos se puede considerar como un desempate cuando el primer campo no es decisivo para decidir el orden.
#
# Aquí hay un ejemplo.
#
# Digamos que queríamos encontrar la mejor película. En la consulta de abajo, solo estamos ordenando las películas por el número de premios Oscar y obteniendo un empate.
#
#
# <img src=".\img\253.png" width="350px" height="350px">
#
#
# Podemos romper ese desempate agregando un segundo campo de orden, viendo qué películas tiene más victorias y el imdb_score más alto
#
# <img src=".\img\254.png" width="350px" height="350px">
#
#
# ## Diferentes Orden
#
#
# También podemos seleccionar un orden diferente para cada campo que estemos ordenando.
#
# Por ejemplo, aquí estamos ordenando la fecha de nacimiento en orden ascendente y el nombre en orden descendente.
#
# <img src=".\img\255.png" width="250px" height="350px">
#
#
#
# ## Orden de ejecución
#
#
# **`ORDER BY`** cae hacia el final del orden de ejecución que ya conocemos, llegando justo antes del **`LIMIT`**.
#
# La instruccion **`FROM`** se ejecutará primero, luego **`WHERE`**, seguida de **`SELECT`**, **`ORDER BY`** y finalmente, **`LIMIT`**.

# %% [markdown]
# # Agrupación de datos
#
#
# En el mundo real, a menudo necesitaremos resumir datos para un grupo particular de resultados.
#
# Por ejemplo, podríamos querer ver los datos de la película agrupados por certificación y hacer cálculos sobre esos grupos, como la duración promedio de cada certificación.
#
#
# ## **`GROUP BY`** en un solo campo
#
# SQL nos permite agrupar con la cláusula **`GROUP BY`**.
#
#
# Aquí se utiliza en una consulta donde hemos agrupado por certificación. **`GROUP BY`** se usa comúnmente con funciones agregadas para proporcionar estadísticas de resumen, particularmente al agrupar solo un campo, certificación, y seleccionar múltiples campos, certificación y título.
#
# Esto se debe a que la función agregada reducirá los campos no agrupados a un solo registro, que deberá corresponder a un grupo.
#
# <img src=".\img\256.png" width="350px" height="350px">
#
#
# ## Tratamiento de errores
#
# SQL devolverá un error si intentamos **`SELECT`** un campo que no está en nuestra cláusula **`GROUP BY`** (en este caso title)
#
#
# Tendremos que corregir esto agregando una función agregada alrededor de **title**.
#
# <img src=".\img\257.png" width="650px" height="350px">
#
#
# ## **`GROUP BY`** múltiples campos
#
# Podemos usar **`GROUP BY`** en múltiples campos similares a **`ORDER BY`**.
#
# El orden en que escribimos los campos afectan cómo se agrupan los datos.
#
# La consulta aquí seleccionar y agrupa la certificación y el idioma al agregar el título. El resultado muestra que tenemos 5 películas en las que les faltan valores tanto para la certificación como para el idioma, 2 películas sin clasificación y en japonés, 2 películas con clasificación R y en noruego, etc.
#
#
# <img src=".\img\258.png" width="550px" height="350px">
#
#
#
# ## **`GROUP BY`** con **`ORDER BY`**
#
# Podemos combinar **`GROUP BY`** con **`ORDER BY`** para agrupar nuestros resultados, hacer un cálculo y luego ordenar nuestros resultados.
#
# Por ejemplo, podemos limpiar una de nuestras consultas anteriores ordenando los resultados por el número de títulos en orden descendente.
#
# Aquí está esa consulta sin **`ORDER BY`**, y esta es la misma consulta con **`ORDER BY`** agregado.
#
# <img src=".\img\259.png" width="650px" height="350px">
#
#
#
# **`ORDER BY`** siempre se escribe después de **`GROUP BY`**, y observé que podemos hacer referencia al alias dentro de la consulta. Eso debido al orden de ejecución.
#
# Parece que las películas clasificadas R son las más comunes en nuestra base de datos.
#
#
#
# ## Orden de Ejecución
#
# **`GROUP BY`** encaja en nuestro orden después de **`FROM`** y antes de todas las demás cláusulas.
#
# Nuestra consulta actualizada comenzarán con **`FROM`**, seguido por **`GROUP BY`**, **`SELECT`** los datos y creando el alias, ordenar los resultados y limitarlos al número deseado.

# %% [markdown]
# # Filtrado de datos agrupados
#
#
# ## **`HAVING`**
#
# En SQL, no podemos filtrar funciones agregadas con cláusulas **`WHERE`**.
#
# Por ejemplo, esta consulta que intenta filtrar el recuento de títulos no es válida. Eso significa que si queremos filtrar según el resultado de una función agregada, necesitamos otra forma.
#
# Los grupos tiene su propia palabra de filtrado especial: **`HAVING`**.
#
# Por ejemplo, la consulta de la derecha muestra solo aquellos años en los que se estrenaron más de 10 películas.
#
#
# <img src=".\img\260.png" width="650px" height="350px">
#
#
#
# ## Orden de Ejecución
#
# La razón por la que los grupos tiene su propia palabra clave para filtrar se reduce al orden de ejecución.
#
# Hemos escrito una consulta usando muchas de las palabras clave que hemos cubierto hasta el momento. Donde se puede apreciar el orden escrito:
#
#
# <img src=".\img\261.png" width="250px" height="350px">
#
#
# Por el contrario, el orden de ejecución es:
#
# - **`FROM`**
# - **`WHERE`**
# - **`GROUP BY`**
# - **`HAVING`**
# - **`SELECT`**
# - **`ORDER BY`**
# - **`LIMIT`**
#
# Al revisar este orden, podemos ver que **`WHERE`** se ejecuta antes de **`GROUP BY`** y antes de que ocurra cualquier agregación.
#
# Este pedido también es la razón por la que no podemos usar el alias con **`HAVING`**, pero sí con **`ORDER BY`**.
#
#
# ## **`HAVING`** vs. **`WHERE`**
#
#
# **`WHERE`** filtra registros individuales, mientras que **`HAVING`** filtra registros agrupados.
#
# Analizaremos dos preguntas comerciales aquí para mostrar cómo traducirlas al filtro correcto.
#
# La primera pregunta es, "¿Qué películas se estrenaron en el año 2000?". Esta pregunta no indica ningún tipo de agrupación. Solicita ver solo títulos de un año específico y, por lo tanto, puede escribirse como:
#
# <img src=".\img\262.png" width="250px" height="350px">
#
#
#
# La segunda pregunta es: "¿En qué años la duración promedio de una película superó las dos horas?". Inmediatamente, podemos ver que esta pregunta tiene algunas capas más.
#
# Desglosemos la pregunta y la consulta en pasos más pequeños y fáciles de entender.
#
# Esta pregunta requiere que devolvamos información sobre los años, por lo que seleccionaremos el año de lanzamiento de la tabla de películas.
#
# Luego, solicita la duración promedio de la película, lo que no dice que debemos colocar **`AVG(duration)`** en algún lugar. Dado que no necesitamos proporcionar ninguna información adicional sobre la duración por sí sola, es poco probable que necesitemos realizar la agregación dentro de la cláusula **`SELECT`**, por lo que probaremos la cláusula **`HAVING`** en su lugar.
#
# La última parte de la pregunta indica que necesitamos filtrar por la duración. Dado que no podemos filtrar agregados con **`WHERE`**, esto respalda nuestra teoría sobre el uso de **`HAVING`**.
#
# Finalmente, debemos agregar un **`GROUP BY`** en nuestra consulta, ya que hemos seleccionado una columna que no se ha agregado. Recuerde que la función agregada convertirá los valores de duración en un valor promedio.
#
# Volviendo al comienzo de nuestra pregunta, estamos interesados en conocer la duración media por año, por lo que la agrupamos por año de lanzamiento.
#
# <img src=".\img\263.png" width="250px" height="350px">

# %% [markdown]
# <h1 style='background:#000000; color:#FFFFFF;height: 55px;padding-top: 13px;font-size: 25px;border-style: double; border-color: #838931;'><center>Curso: Unión de datos en SQL</center></h1><a name="UnióndedatosenSQL"></a>

# %% [markdown]
# # Los entresijos de **`INNER JOIN`**
#
#
# Comenzaremos con **`INNER JOIN`**, que junto con **`LEFT JOIN`** constituye una de las dos uniones más comunes.
#
# Se muestran dos tablas denominadas "left_table" y "rigth_table".
#
# Los valores coincidentes de **id** en ambas tablas se muestran en el mismo color. En ambas tablas, el campo id es la clave.
#
# Una clave es una sola columna o grupo de columnas que identifica de forma exclusiva los registros de una tabla.
#
# Ambas tablas también tienen campos llamados **left_val** y **right_val**, que ayudarán a visualizar los registros devueltos después de una combinación.
#
# <img src=".\img\264.png" width="350px" height="350px">
#
# Con las uniones SQL, puede unirse en un campo clave o en cualquier otro campo.
#
#
# El **`INNER JOIN`** que se muestra busca registros en ambas tablas con los mismos valores en el campo clave, **id**.
#
# <img src=".\img\265.png" width="350px" height="350px">
#
#
# Las flechas indican los registros donde coincide la identificación.
#
# En este diagrama, nos centramos en los registros que coinciden con **id** y desvanece cualquier registro que no sea de interés para nuestro **`INNER JOIN`**.
#
# <img src=".\img\266.png" width="350px" height="350px">
#
# El resultado son registros con **ids** 1 y 4.
#
# <img src=".\img\267.png" width="550px" height="350px">
#
#
# ## El esquema de la base de datos de liderazgo
#
# A lo largo de este curso, trabajaremos con una base de datos de líderes mundiales.
#
# Nuestro esquema de base de datos se muestra aquí.
#
# Contiene las tablas de presidentes, primeros ministros y monarcas, así como la tabla de estados, que contiene años de independencia, y la tabla **prime_minister_terms**, que proporciona los años en que los primeros ministros asumieron el cargo.
#
# <img src=".\img\268.png" width="650px" height="350px">
#
#
# ## En la tabla de presidentes
#
#
# Comencemos consultado nuestra base de datos seleccionando todos los campos de la tabla de presidentes. Recuerde el uso del * en SQL para seleccionar todos los campos rápidamente.
#
# <img src=".\img\269.png" width="450px" height="350px">
#
#
#
# ## Conozca a los Primeros Ministros
#
#
# Aquí hay un fragmento de la tabla **prime_ministers** de la misma base de datos.
#
#
#
# <img src=".\img\270.png" width="350px" height="350px">
#
#
# ## Primeros ministros, conozcan a los presidentes
#
#
# Supongamos que estamos interesados en países que tienen un presidente y un primer ministro. En estas pequeñas tablas, podemos notar que Egipto, Portugal, Pakistán e India aparecen en ambas tablas. Sin embargo, para tablas más grandes, no es tan factible identificar estos registros mediantes una inspección visual.
#
#
#
# <img src=".\img\271.png" width="750px" height="350px">
#
#
#
# Aquí es donde las uniones SQL pueden ser útiles.
#
#
# ## Nuestro primer **`INNER JOIN`**
#
#
# La sintaxis para realizar un **`INNER JOIN`** en nuestras tablas se muestra paso a paso.
#
# Es común comenzar a construir la consulta con la unión primero y seleccionar los campos después. Después de **`FROM`**, enumeramos la tabla de la izquierda, seguida de la palabra clave **`INNER JOIN`** y la tabla de la derecha.
#
# A continuación, especificamos el campo para que coincida con las tablas, utilizando la palabra clave **`ON`**.
#
# Aquí, usamos el campo **country**.
#
# Por último, agregamos **`SELECT`** al comienzo de la consulta y elegimos los campos que queremos devolver.
#
# **NOTA:** Al seleccionar columnas que existen en ambas tablas, como **country** y **continent**, se debe usar el formato **`tabla.column_name`** para evitar un error de SQL.
#
#
# <img src=".\img\272.png" width="650px" height="350px">
#
# <img src=".\img\273.png" width="650px" height="350px">
#
# Se muestra el resultado de nuestra consulta: 4 países en nuestra base de datos tienen presidentes y primeros ministros.
#
#
# ## Alias de Tablas
#
# En nuestro **`INNER JOIN`**, tuvimos que escribir **presidents** y **prime_ministers** varias veces. Afortunadamente, podemos crear un alias para los nombres de las tablas usando la misma palabra clave **`AS`** que se usa para crear un alias para los nombres de las columnas.
#
# Aquí, usamos los alias **p1** y **p2** en nuestras cláusulas **`SELECT`** y **`ON`** para acortar nuestra consulta.
#
#
# <img src=".\img\274.png" width="650px" height="350px">
#
#
#
# ## Utilizando **`USING`**
#
# Antes de finalizar, agreguemos un atajo de SQL más para que nuestra consulta sea aún más concisa.
#
# Al unir dos nombres de columna **idénticos**, podemos emplear el comando **`USING`**  seguido del nombre de la columna compartida entre paréntesis.
#
# Aquí, dado que el campo de combinación se denomina **country** en ambas tablas, podemos usar  **`USING`**
#
# <img src=".\img\275.png" width="650px" height="350px">

# %% [markdown]
# # Definición de relaciones
#
#
# ## Relaciones de uno a muchos
#
# El primer tipo de relación del que hablaremos es una relación de uno a muchos. Este es el tipo de relación más común, en el que una sola entidad puede estar asociada con varias entidades.
#
# Piensa en una biblioteca de música. Un artista puede producir muchas canciones a lo largo de su carrera. Esta es una relación de uno a muchos.
#
# Lo mismo se aplica a los autores y sus libros, directores y títulos de películas, etc.
#
# Jane Austen escribió muchos libros, y cada uno de sus libros tenía un solo autor.
#
# En el esquema de la tabla que se muestra, cada una de sus obras se almacenan en los libros, y se puede fusionar con la tabla de autores usando **author_id** de ambas tablas.
#
#
# <img src=".\img\276.png" width="450px" height="350px">
#
#
#
# ## Relaciones uno a uno
#
#
# Un segundo tipo de relación es una relación uno a uno.
#
# Las relaciones uno a uno implican emparejamientos únicos entre entidades y, por lo tanto, son menos comunes.
#
# Una premisa común de la ciencia forense es que no hay dos huellas dactilares idénticas y, por lo tanto, que una determinada huella dactilar soló puede ser generada por una sola persona. Este es un ejemplo de una relación uno a uno: una huella digital para un dedo.
#
#
# Imagine el escaneo de huellas dactilares en el control fronterizo del aeropuerto.
#
# El control fronterizo puede tener dos tablas en una base de datos: una tabla de personas y una tabla de sus huellas.
#
# La huella dactilar de cada persona podría fusionarse con la tabla de individuos usando su número de pasaporte.
#
# <img src=".\img\277.png" width="450px" height="350px">
#
#
# Nótese aquí que aunque un individuo tenga 4 huellas dactilares almacenadas en una tabla de huellas dactilares, esta no es una relación de uno a muchos.
#
# Es una relación de uno a uno, porque un solo individuo, representado como un registro en la tabla de **individuals**, tendrá un juego de huellas dactilares, representado como un registro en la tabla de huellas dactilares.
#
# Las cuatro huellas digitales diferentes son cuatro campos diferentes en cada registro.
#
#
# ## Relaciones muchos a muchos
#
#
# El último tipo de relación que discutiremos es una relación de muchos a muchos.
#
# Un ejemplo de esto son los idiomas y los países.
#
# Aquí mostramos los idiomas oficiales de Alemania, Bélgica y Países Bajos, donde vemos que se puede hablar muchos idiomas en muchos países.
#
#
# <img src=".\img\278.png" width="350px" height="350px">
#
#
# Por ejemplo, Bélgica tiene tres idiomas oficiales: francés, alemán y holandés.
#
# Por el contrario, los idiomas pueden ser oficiales en muchos países: el holandés es un idioma oficial de los Países Bajos y Bélgica, pero no de Alemania.

# %% [markdown]
# # Uniones múltiples
#
#
# ## Unión en Uniones
#
# Una característica poderosa de SQL es que pueden combinar varias uniones y ejecutarlas en una sola consulta.
#
# Echemos un vistazo a la sintaxis para combinaciones múltiples.
#
# Comenzamos con el mismo **`INNER JOIN`** que antes, y luego encadenamos otro **`INNER JOIN`** al resultado de nuestro primer **`INNER JOIN`**.
#
# Tenga en cuenta que usamos **left_table.id** en la última línea de este ejemplo. Si queremos realizar la segunda combinación usando el campo id de **right_table** en lugar de **left_table**, podemos reemplazar **left_table.id** con **right_table.id** en la línea final.
#
#
# <img src=".\img\279.png" width="350px" height="350px">
#
#
# ---
#
# Volviendo a nuestro ejemplo de líderes mundiales, digamos que estamos interesados en identificar países del mundo que tienen un presidente y un primer ministro, y quiere saber el año en que cada primer ministro asumió el cargo.
#
# Echemos un vistazo a la tabla **prime_minister_terms** de nuestra base de datos de líderes mundiales.
#
# Contiene una columna **prime_minister** con los nombres de los primeros ministros, también como una columna **pm_start** que contiene el año de inicio del mandato de un primer ministro.
#
#
# <img src=".\img\280.png" width="200px" height="350px">
#
#
#
# ## ¿A qué afiliarse primero?
#
#
# Apliquemos la nueva sintaxis que hemos aprendido a nuestro ejemplo de líderes mundiales.
#
# Podemos comenzar como antes con un **`INNER JOIN`** de las tablas presidentes y prime_ministers, utilizando nuestras habilidades de creación de alias para acortar la longitud de la consulta.
#
#
#
# <img src=".\img\281.png" width="550px" height="350px">
#
#
# Recuerdo que esta unión nos da como resultado solo aquellos países que cuenta con un presidente y un primer ministro.
#
#
# ## Encadenamiento de uniones
#
# Si ahora unimos el resultado de nuestro primero **`INNER JOIN`** con nuestra tabla **prime_minister_terms** en el campo **prime_minister**, el resultado final será solo aquellos países con ambos primeros ministros y presidentes, junto con los años en que sus primeros ministros asumieron el cargo.
#
# <img src=".\img\282.png" width="650px" height="350px">
#
# Observe que la tabla **prime_minister_terms** tiene 10 registros, mientras que nuestro resultado final solo tiene 4 registros.
#
# Esto se debe a que solo cuatro registros de la tabla **prime_minister_terms** coinciden con el resultado de nuestro primer **`INNER JOIN`**.
#
# ---
#
#
# Aquí hay un vistazo a la consulta SQL final para encadenar un segundo **`INNER JOIN`** a nuestro primer **`INNER JOIN`**.
#
#
#
# Observe que la sintaxis para la segunda unión es exactamente la misma que para la primera unión, pero usamos **prime_minister** como campo para unirse en su lugar.
#
#
# <img src=".\img\283.png" width="350px" height="350px">
#
#
# Podemos continuar la cadena y juntar tantas tablas como necesitemos.
#
#
# ## ¿A qué nos unimos?
#
#
# Ahora retrocedamos del ejemplo de nuestros líderes mundiales.
#
# Una cosa más que debe saber acerca de las uniones es que no siempre ocurre que cada valor en el campo que se está uniendo corresponder exactamente a un registro en el campo de unión de la tabla de la derecha.
#
# En el ejemplo mostrado, si unimos en un campo como hemos hecho antes, la consulta devolverá múltiples registros de **right_table** que coincidan con **left_table** en el campo id.
#
# <img src=".\img\284.png" width="650px" height="350px">
#
#
# ##  Unir varias llaves
#
#
# Podemos limitar los registros devueltos proporcionando un campo adicional para unirse agregando la palabra clave **`AND`** a nuestra cláusula **`ON`**.
#
# En este ejemplo, nos unimos a la fecha, una segunda columna de uso frecuente cuando se une en varios campos.
#
# <img src=".\img\285.png" width="650px" height="350px">
#
#
# El conjunto de resultados ahora contiene registro que coinciden tanto en id como en fechas.

# %% [markdown]
# # UNIONES IZQUIERDA y DERECHA
#
#
#
#
# Ahora compararemos **`INNER JOIN`** con tres tipos de combinaciones externas, comenzando con **`LEFT JOIN`**.
#
# Las uniones externas puede obtener registros de otras tablas, incluso si no se encuentran coincidencias para el campo en el que se unen. Un **`LEFT JOIN`** devolverá todos los registros en la **left_table**, y aquellos registros en la **right_table** que coinciden con el capo de combinación provisto.
#
# En el diagrama que se muestra, los valores de 2 y 3 no parecen en el campo **id** de **right_table**, pero aún se conservara en la combinación.
#
#
# <img src=".\img\286.png" width="350px" height="350px">
#
#
# Los registros que no son de interés para **`LEFT JOIN`** en el campo de identificación se han desvanecido.
#
# Ahora miramos el resultado de **`LEFT JOIN`** en (**`ON`**) **id**.
#
#
# <img src=".\img\287.png" width="550px" height="350px">
#
#
# **`INNER JOIN`** devuelve solo los registros correspondientes a los **ID** 1 y 4, mientras que **`LEFT JOIN`** conserva todos los registros en **left_table**, así como valores nulos para **right_val** donde no hay coincidencia en **right_table**.
#
# Tenga en cuenta que los **ID** 5 y 6 en **right_table** no aparecen en **`LEFT JOIN`** de ninguna manera.
#
# ## Sintaxis **`LEFT JOIN`**
#
# Volvamos al ejemplo de nuestros líderes mundiales.
#
#
# Digamos que queremos que nuestra consulta incluya todos los países con primeros ministros, presidentes, si los tiene, y valores perdidos, si no los tienen. **`LEFT JOIN`** no dará los resultados que necesitamos.
#
# La sintaxis de **`LEFT JOIN`** es muy similar a **`INNER JOIN`**. Solo la palabra **`INNER`** se reemplaza por **`LEFT`**.
#
# Tenga en cuenta que **`LEFT JOIN`** también se puede escribir como **`LEFT OUTER JOIN`** en SQL.
#
#
# <img src=".\img\288.png" width="550px" height="350px">
#
#
# Los primeros tres registros en el resultado son los mismos que estaban con un **`INNER JOIN`**, pero a partir del cuarto registro el resultado empieza a verse diferente.
#
# Dado que el Reino Unido no tiene presidente, se devuelve un valor nulo correspondiente en el campo presidente.
#
#
#
# ## **`RIGHT JOIN`**
#
# **`RIGHT JOIN`** es el segundo tipo de unión externa y es mucho menos común que **`LEFT JOIN`**.
#
#
# En lugar de hacer coincidir las entradas en la columna de identificación de la tabla de la izquierda a la columna id de la tabla de la derecha, un **`RIGHT JOIN`** hace lo contrario.
#
#
# Todos los registros se conservan de **right_table**, incluso cuando **id** no encuentra una coincidencia correspondiente en **left_table**.
#
# <img src=".\img\289.png" width="550px" height="350px">
#
#
# Se devuelven valores nulos para el campo **left_val** en los registros que no encuentran una coincidencia.
#
#
#
# ## Sintaxis de **`RIGHT JOIN`**
#
# Se muestra la sintaxis genérica para **`RIGHT JOIN`**.
#
# Tenga en cuenta que el orden de **left_table** y **right_table** es el mismo que en el **`LEFT JOIN`**.
#
# El único cambio es que llamamos **`RIGHT JOIN`** en lugar de **`LEFT JOIN`**.
#
# **`RIGHT JOIN`** también se puede escribir como **`RIGHT OUTER JOIN`** en SQL.
#
# Ejemplo: Realizamos una unión a la derecha, de la tabla **prime_ministers** a la izquierda, y la tabla **presidents** a la derecha.
#
# El único cambio es la palabra clave **`LEFT JOIN`** a **`RIGHT JOIN`**.
#
# <img src=".\img\290.png" width="550px" height="350px">
#
# El resultado contiene valores nulos donde los países tiene presidentes pero no primeros ministros.
#
#
# ## **`LEFT JOIN`** o **`RIGHT JOIN`**
#
#
# Ahora que está familiarizado con **`LEFT JOIN`** y **`RIGHT JOIN`**, analicemos por qué **`RIGHT JOIN`** se usa con menos frecuencia.
#
#
# Una razón clave para esto es que **`RIGHT JOIN`** siempre se puede reescribir como **`LEFT JOIN`**. Debido a que normalmente escribimos de izquierda a derecha, **`LEFT JOIN`** se siente más intuitivo para la mayoría de los usuarios cuando construye consultas.

# %% [markdown]
# # Uniones Completas
#
#
# **`FULL JOIN`** es una unión externa.
#
# Una **`FULL JOIN`** combina una **`LEFT JOIN`** y una **`RIGHT JOIN`**.
#
# <img src=".\img\291.png" width="300px" height="350px">
#
# Como puede ver en este diagrama, ningún valor se desvanece como en los diagramas anteriores. Esto se debe a que **`FULL JOIN`** devolverá todos los **ID**, independientemente de si tiene una coincidencia en la otra tabla que está uniendo.
#
# ---
#
#
# Echemos un vistazo al resultado después de **`FULL JOIN`**
#
#
# <img src=".\img\292.png" width="450px" height="350px">
#
# Vemos que ha retenido todos los ids, regresando valores faltantes en forma de nulos para campos correspondientes a registros donde id no encontró una coincidencia.
#
# Los 6 **ID**  con los que hemos estado trabajando se incluyen en el resultado después de **`FULL JOIN`**.
#
# Tenga en cuenta que, esta vez, los valores nulos pueden aparecer en los campos **left_val** o **right_val**.
#
#
#
# ## Sintaxis de **`FULL JOIN`**
#
#
# Para producir una **`FULL JOIN`**, el formato general se alinea estrechamente con la sintaxis SQL que hemos estado usando para **`INNER JOIN`**, **`LEFT JOIN`** y  **`RIGHT JOIN`**.
#
# Adaptamos nuestra unión para tener la palabra **`FULL`** antes de **`JOIN`**.
#
# Tenga en cuenta que la palabra clave **`FULL OUTER JOIN`** también se puede usar para devolver el mismo resultado.
#
# <img src=".\img\293.png" width="350px" height="350px">
#
#
# ## Ejemplo de **`FULL JOIN`** usando la base de datos de Líderes
#
# Hagamos que nuestra sintaxis de muestra sea concreta con nuestro ejemplo de la base de datos de líderes.
#
# Supongamos que estamos interesados en todos los países de nuestra base de datos y quería comprobar si tenía un presidente, un primer ministro o ambos.
#
# Recorremos el código línea por línea para hacer esto usando una **`FULL JOIN`**.
#
# Tenga en cuenta que el orden de las tablas importa aquí, y si cambiamos el orden, los registros se ordenarán de manera diferente dependiendo de cómo se ordenen los primeros ministros y presidentes en las tablas.
#
# <img src=".\img\294.png" width="450px" height="350px">
#
# <img src=".\img\295.png" width="450px" height="350px">
#
# Tenga en cuenta que hay valores nulos en los campos **prime_minister** y **president**.
#
# Elegimos **`FULL JOIN`** porque estábamos interesados en todos los países, ya sea que tuvieran un primer ministro, un presidente o ambos.

# %% [markdown]
# # Cruzando a CROSS JOIN
#
#
# ## Diagrama **`CROSS JOIN`**
#
#
# Las **`CROSS JOIN`** son ligeramente diferentes a las uniones que hemos visto anteriormente: crea todas las combinaciones posibles de dos tablas.
#
# Exploremos el diagrama de **`CROSS JOIN`**
#
#
# <img src=".\img\296.png" width="300px" height="350px">
#
# En este diagrama tenemos dos tablas llamadas **table1** y **table2**, con un campo cada una; **id1** e **id2**, respectivamente. El resultado de **`CROSS JOIN`** son las nueve combinaciones del **id**, valores d 1, 2 y 3 en la tabla 1 con los valores de identificación de A, B y C para la tabla 2.
#
#
# ## Sintaxis de **`CROSS JOIN`**
#
# Echemos un vistazo a la sintaxis de **`CROSS JOIN`**.
#
# Tenga en cuenta que la sintaxis es mínima y no especificamos **`ON`** o **`USING`** con **`CROSS JOIN`**.
#
#
# <img src=".\img\297.png" width="250px" height="350px">
#
#
# ## Emparejar a primeros ministros con presidentes
#
# Apliquemos la sintaxis SQL para **`CROSS JOIN`** al siguiente problema que usa nuestra base de datos de líderes globales.
#
# Suponga que todos los primeros ministros de Asia de nuestra base de datos están programados para reuniones individuales con todos los presidentes de Sudamérica de nuestra base de datos, y somos periodistas que deseamos seguir todos los encuentros que van a suceder.
#
# Podemos crear una consulta que devuelva todas estas combinaciones usando **`CROSS JOIN`**.
#
#
# Usamos la cláusula **`WHERE`** para centrarnos solo en los primeros ministros de Asia y los presidentes de América del Sur.
#
#
# <img src=".\img\298.png" width="400px" height="350px">
#
# Los resultados de la consulta nos dan todas las parejas posibles de los cuatro primeros ministros de Asia en la tabla de **prime_ministers**, y los dos presidentes de América del Sur en la tabla de presidentes.

# %% [markdown]
# # Auto Unión
#
#
# Ahora nos sumergiremos en un tipo especial de unión, donde una tabla, se une consigo misma. Estos tipos de uniones se denominan uniones automáticas.
#
# ---
#
#
# Unir una tabla a sí misma puede parecer algo inusual. ¿Por qué querríamos hacer eso?
#
# Las uniones automáticas se utilizan para comparar valores de parte de una tabla con otros valores dentro de la misma tabla.
#
#
# Recuerde la tabla **prime_ministers** de antes.
#
# <img src=".\img\299.png" width="350px" height="350px">
#
# Supongamos que todos los primeros ministros se reúnen en cumbre en sus propios continentes. Queremos crear una nueva tabla que muestro todos los países en el mismo contienen como pares.
#
#
# ## Primer Ministro, conozca al Primer Ministro
#
#
# Las uniones automáticas no tienen una sintaxis dedicada como otras uniones que hemos visto. No podemos simplemente escribir **`SELF JOIN`** en código SQL, por ejemplo. Además, se requiere un alias para una autounión.
#
#
# Veamos una parte del código **`INNER JOIN`** utilizando la tabla **prime_ministers**.
#
#
# <img src=".\img\300.png" width="350px" height="350px">
#
# La columna del país se selecciona dos veces, al igual que la columna del continente. La tabla **prime_ministers** está tanto a la izquierda como a la derecha de **`JOIN`**, lo que hace que sea tanto una autocombinanción como una **`INNER JOIN`**.
#
# El paso vital aquí es establecer los campos de unión que usamos para hacer coincidir la tabla con ella misma.
#
# Para cada país, encontraremos varios países coincidentes en la tabla de la derecha, ya que nos unimos en el continente. Cada uno de estos países emparejados se devolverá como pares.
#
# Dado que esta consulta devolverá varios registros, usamos **`LIMIT`** para devolver solo los primeros 10 registros.
#
#
# <img src=".\img\301.png" width="350px" height="350px">
#
#
# Los resultados son un emparejamiento de cada país con todos los demás países del mismo continente. Sin embargo, tenga en cuenta que nuestra combinación también emparejó países con ellos mismos, ya que ellos también están en el mismo continente que ellos.
#
# No queremos incluirlos, ya que un líder de Portugal no necesita reunirse consigo mismo, por ejemplo.
#
# ---
#
#
# Arreglemos esto.
#
#
# Recuerde el uso de la cláusula **`AND`** para garantizar que se cumpla múltiples condiciones en la cláusula **`ON`**. En nuestra segunda condición, usamos el operador no igual para excluir registros donde los campos p1.country y p2.country son idénticos.
#
#
# <img src=".\img\302.png" width="250px" height="350px">
#
# <img src=".\img\303.png" width="250px" height="350px">
#
# Aquí hay un vistazo a nuestra tabla final, que muestra combinaciones de países en nuestra base de datos que están en el mismo continente, pero excluyendo los registros donde los dos campos de país son iguales.

# %% [markdown]
# # Teoría de conjuntos para uniones SQL
#
#
# ## Diagramas de Venn y teoría de conjuntos
#
#
# SQL tiene tres operaciones de conjuntos principales, **`UNION`**, **`INTERSECT`** Y **`EXCEPT`**.
#
# Los diagramas de Venn mostrados visualizan las diferencias entre ellos.
#
# <img src=".\img\304.png" width="350px" height="350px">
#
# Podemos pensar en cada círculo como si representara una tabla. Las parte verdes representan lo que si incluye después de realizar la operación de conjunto en cada par de tablas.
#
#
# ## Diagrama **`UNION`**
#
# En SQL, el operador **`UNION`** toma dos tablas como entrada y devuelve todos los registros de ambas tablas.
#
# El diagrama muestra dos tablas: izquierda y derecha, y al realizar una **`UNION`** se devuelven todos los registros de cada tabla.
#
# Si dos registros son idénticos, **`UNION`** solo los devuelve una vez. Para ilustrar esto, los dos primeros registros de la tabla de la derecha se han desvanecido.
#
# <img src=".\img\305.png" width="350px" height="350px">
#
# Nuestro resultado tiene siete registros.
#
#
# ## Diagrama **`UNION ALL`**
#
#
# En SQL, hay otro operador para uniones llamado **`UNION ALL`**. A diferencia de **`UNION`**, dadas las mismas dos tablas, **`UNION ALL`** incluirá registros duplicados.
#
# Por lo tanto, realizar **`UNION ALL`** en estos datos devolverá nueve registros, mientras que **`UNION`** solo devolvió siete. No se han desvanecido registros.
#
# <img src=".\img\306.png" width="350px" height="350px">
#
#
#
# ## Sintaxis de **`UNION`** y **`UNION ALL`**
#
# La sintaxis para realizar todas las operaciones de ajuste es muy similar.
#
#
# Realizamos una sentencia **`SELECT`** en nuestra primera tabla, una sentencia **`SELECT`** en nuestra segunda y, especifique una operación de conjunto (en este ejemplo, **`UNION`** o **`UNION ALL`**) entre ellos.
#
#
# <img src=".\img\307.png" width="650px" height="350px">
#
# Tenga en cuenta que las operaciones de configuración no requieren un campo para unirse a **`ON`**. Esto se debe a que no hacen exactamente lo mismo que las operaciones de unión que cubrimos en capítulos anteriores.
#
# En lugar de comparar y fusionar tablas a la izquierda y a la derecha, apilan campos uno encima del otro.
#
# ---
#
#
# Para todas las operaciones de conjuntos, el número de columnas seleccionadas y sus respectivos tipos de datos deben ser idénticos.
#
#
#
# <img src=".\img\308.png" width="350px" height="350px">
#
#
# Por ejemplo, no podemos apilar un campo numérico encima de un campo de caracteres.
#
# El resultado solo usará nombre de campo (o alias, si se usan) de la primera instrucción **`SELECT`** en la consulta.
#
#
# ## A la tabla de los monarcas
#
#
# Ahora volvemos al ejemplo de nuestros líderes mundiales.
#
# En este ejemplo, usamos una tabla más de nuestra base de datos de líderes: la tabla de monarcas.
#
# Por supuesto, esta tabla es solo una muestra de monarcas y no una lista completa de monarcas de todo el mundo.
#
# <img src=".\img\309.png" width="450px" height="350px">
#
#
# ## Primeros ministros, reúnanse con los monarcas
#
#
# Podemos usar **`UNION`** en las tablas de **monarch** y **prime_ministers** para que muestre todos los diferentes primeros ministros y monarcas en estas dos tablas.
#
# Tenga en cuenta que el campo monarca ha sido alias como "líder". Como hemos aprendido, los campos monarca y primer_ministro serán combinados bajo el campo líder, aunque solo creamos un alias para el campo monarca.
#
# Nos limitaremos a los primeros 10 resultados que quepan en nuestra pantalla.
#
# <img src=".\img\310.png" width="300px" height="350px">
#
#
# <img src=".\img\311.png" width="300px" height="350px">
#
#
# Nuestra **`UNION`** devuelve los 10 principales monarcas, primeros ministros y sus países correspondientes.
#
# ¿Se destaca algo aquí?
#
# Recuerde que los monarcas de Omán y Brunei también son primeros ministros. **`UNION `** solo los enumera una vez cada uno, porque son la misma persona. Sin embargo, Noruega aparece dos veces, porque su monarca y primer ministro son personas diferentes.
#
#
# ## **`UNION ALL`** con los líderes
#
#
# Aquí es donde una **`UNION ALL`** es útil.
#
#
# Una **`UNION ALL`** nos dirá si hay monarcas que también ejerzan de primeros ministros.
#
# Se muestra la sintaxis para esto.
#
# <img src=".\img\312.png" width="300px" height="350px">
#
# <img src=".\img\313.png" width="300px" height="350px">
#
# Después de **`UNION ALL`**, Brunei y Omán ahora figuran dos veces.

# %% [markdown]
# #  **`INTERSECT`**
#
#
# ## Diagrama de Venn **`INTERSECT`**
#
# <img src=".\img\314.png" width="350px" height="350px">
#
#
# **`INTERSECT`**  toma dos tablas como entrada y devuelve solo los registros que existen en ambas tablas.
#
#
# ## Diagrama **`INTERSECT`**
#
# En el diagrama que se muestra, tenemos dos tablas **left_table** y **right_table**.
#
# <img src=".\img\315.png" width="350px" height="350px">
#
# El resultado de realizar **`INTERSECT`** en estas tablas son solo los registros comunes a ambas tablas: el primer registro.
#
# Todos los registros que no son de interés para la operación **`INTERSECT`** se desvanecen.
#
#
# ## Sintaxis **`INTERSECT`**
#
# La sintaxis de esta operación de conjunto es muy similar a la de **`UNION`** y **`UNION ALL`**.
#
# Realizamos una declaración **`SELECT`** en nuestra primera tabla, una declaración **`SELECT`** en nuestra segunda tabla, y especifique nuestro operador conjunto entre ellos.
#
#
# <img src=".\img\316.png" width="200px" height="350px">
#
#
#
# ## **`INTERSECT`** VS. **`INNER JOIN`** en dos columnas
#
# Comparemos **`INTERSECT`** con realizar un **`INNER JOIN`** en dos campos con nombres de campos idénticos.
#
# Similar a **`UNION`**, para que se devuelva un registro, **`INTERSECT`** requiere todos los campos para hacer coincidir, ya que en las operaciones de conjunto no especificamos ningún campo para hacer coincidir. Esta es también la razón por la que requiere que las tablas izquierda y derecha tengan el mismo número de columnas para poder comparar registros.
#
# <img src=".\img\317.png" width="750px" height="350px">
#
#
# En la figura que se muestra, solo se devuelven los registros en los que ambas columnas coinciden.
#
# En **`INNER JOIN`**, similar a **`INTERSECT`**, solo se devuelve los resultados donde ambos campos coinciden.
#
# **`INNER JOIN`** devolverá valores duplicados, mientras que **`INTERSECT`** solo devolverá registros comunes una vez.
#
#
# Como sabemos, **`INNER JOIN`** agregará más columnas al conjunto de resultados.
#
#
#
# ## Países con primeros ministros y presidentes
#
# Veamos cómo podemos usar **`INTERSECT`** para determinar todos los países que tienen un primer ministro y un presidente.
#
# Cada declaración **`SELECT`** en nuestra consulta tiene el mismo número de columnas, de tipos de datos idénticos, para que se realice la operación de ajuste.
#
#
# <img src=".\img\318.png" width="300px" height="350px">
#
#
# El resultado de la consulta son los cuatro países con un primer ministro y un presidente en nuestra base de datos de líderes.
#
#
# Al igual que con **`UNION`**, el conjunto de resultados utiliza los nombres de campo proporcionados para la tabla de la izquierda, ya sea como alias o sin ellos.
#
#
# ## **`INTERSECT`** en dos campos
#
#
# A continuación, pensemos en lo que sucedería si seleccionamos dos columnas, país y primer ministro, en lugar de solo país, como en nuestro ejemplo anterior.
#
# El código que se muestra hace precisamente eso.
#
#
# <img src=".\img\319.png" width="350px" height="350px">
#
# El resultado real es una tabla vacía.
#
# Como vimos en nuestro diagrama **`INTERSECT`**, **`INTERSECT`** requiere datos de ambos campos de la tabla de la izquierda para que coincidan con sus campos correspondientes en la tabla de la derecha.
#
# La búsqueda no encontró ningún país donde el primer ministro y el presidente compartan el mismo nombre.
#
#
#
# ## Países con primer ministro y monarcas
#
#
# Sin embargo, recuerda que hay monarcas en nuestra base de datos que también actúan como primeros ministros.
#
# En el ejemplo que se muestra, realizar un **`INTERSECT`** en primer_minister y las tablas de monarcas que usan el nombre del país y el líder no devuelven un resultado vacío.
#
#
# <img src=".\img\320.png" width="350px" height="350px">

# %% [markdown]
# # **`EXCEPT`**
#
# ## Diagrama de Venn **`EXCEPT`**
#
#
# **`EXCEPT`** nos permite identificar los registros que están presentes en una tabla, pero no en la otra.
#
# Más específicamente, conserva solo los registros de la tabla de izquierda que no están presentes en la tabla de la derecha.
#
# <img src=".\img\321.png" width="350px" height="350px">
#
#
# ## Diagrama **`EXCEPT`**
#
# El diagrama que se muestra ilustra el funcionamiento de la operación **`EXCEPT`**.
#
#
# <img src=".\img\322.png" width="350px" height="350px">
#
# Todos los registros que no son de interés para la operación **`EXCEPT`** se desvanecen.
#
# Solo se devuelven los dos últimos registros de **left_table**.
#
# Tenga en cuenta que si bien el **id 4** existe en la tabla de la derecha, todo el registro no coincide, razón por la cual el último registro de **left_table** no se desvanece.
#
#
# ## Sintaxis **`EXCEPT`**
#
# Vimos anteriormente que hay algunos monarcas que también actúan como primeros ministros en su país.
#
# Digamos que nos interesan los monarcas que NO ostentan también el título de primer ministro.
#
# La cláusula **`EXCEPT`** es realmente útil para esto.
#
# El código SQL que se muestra selecciona el monarca y el campo de país de los monarcas y luego busca los campos comunes. Entradas en los campos prime_minister y country en la tabla prime_ministers, buscando excluir esas entradas.
#
#
# <img src=".\img\323.png" width="350px" height="350px">
#
#
# En el resultado, vemos solo a los tres monarcas de nuestra base de datos de líderes que no cumplen también el papel de primer ministro.

# %% [markdown]
# # Sub consultas con semi-uniones y anti-uniones
#
#
# ## Convocatoria de todas las uniones
#
# Las seis uniones con las que hemos trabajado hasta ahora son todas "aditivas" en el sentido de que agregan columnas a la tabla "izquierda" original.
#
# El diagrama muestra un **`INNER JOIN`** en el campo **id**, que muestra una columna adicional que se agrega a la tabla izquierda original.
#
# <img src=".\img\324.png" width="550px" height="350px">
#
#
#
# ## Uniones aditivas
#
# Aquí hay una sintaxis familiar de **`INNER JOIN`** para esta combinación en el campo **id**.
#
# Profundicemos en lo que significa que esta combinación sea "aditiva".
#
# <img src=".\img\325.png" width="350px" height="350px">
#
# ---
#
# Los campos con nombre diferentes se agregan al conjunto de resultados con sus nombres originales.
#
# Los campos con el mismo nombre, como la fecha, se agregan también al conjunto de resultados, pero observe cómo ahora tenemos columnas de fecha duplicadas con el mismo nombre.
#
# <img src=".\img\326.png" width="650px" height="350px">
#
#
# Esto puede cambiar, sin embargo, con alias.
#
#
#
# ## Semi unión
#
# En esta lección, veremos formas de unir datos que no utilizan expresamente las palabras clave **`JOIN`** y no son aditivas de la misma manera.
#
# En lugar de usar operadores **`JOIN`** o set, podemos aprovechar la cláusula **`WHERE`** para especificar los registros que se incluirán.
#
# Usaremos las dos tablas, **left_table** y **right_table**, en el diagrama que se muestra.
#
# <img src=".\img\327.png" width="300px" height="350px">
#
#
# Una semi combinación elige registros en la primera tabla donde se cumple una condición en la segunda tabla.
#
# Más específicamente, la semi unión devolverá todos los valores de **left_table** donde los valores de **col1** están en una columna que especificamos, a saber, **col2** en la tabla derecha.
#
# <img src=".\img\328.png" width="300px" height="350px">
#
# Los registros que no son de interés para la unión semi se han desvanecido.
#
#
# El resultado final de nuestras semiunión son los registros correspondientes a los **Id 2 y 3**.
#
# <img src=".\img\329.png" width="450px" height="350px">
#
#
#
#
# ## Empezando nuestra semi unión
#
# Hagamos esto concreto con un ejemplo.
#
# Supongamos que estamos interesados en determinar los presidentes de los países que obtuvieron la independencia antes de 1800.
#
# Seleccionamos los campos país, contiene y presidente.
#
# <img src=".\img\330.png" width="450px" height="350px">
#
# ¿Cómo filtramos estos datos para el año de la independencia, que es un campo en la tabla de estados?. Usaremos la semi unión.
#
#
#
# ## Sobre la base de nuestra semiunión
#
# Antes de que supiéramos nada acerca de las uniones, sabíamos que podíamos aprovechar la cláusula **`WHERE`** para filtrar datos.
#
# Se muestra la consulta que devuelve países con indep_year antes de 1800.
#
# <img src=".\img\331.png" width="250px" height="350px">
#
# La consulta devuelve solo España y Portugal de nuestra base de datos.
#
#
# ## Finalizar la semi join (introducción a las sub consultas)
#
#
# Podemos usar esta lista de países como un filtro incrustándolo en otra cláusula **`WHERE`**.
#
# Esto se llama una sub consulta.
#
# <img src=".\img\332.png" width="350px" height="350px">
#
# Elige registros en la primera tabla donde el país coincide con la lista devuelta por nuestra sub consulta. Como España no tiene presidente, solo figura el presidente portugués.
#
# <img src=".\img\333.png" width="450px" height="350px">
#
#
#
# ## Anti Uniones
#
# Pasando a las anti uniones.
#
# La anti combinación elige registros en la primera tabla donde **col1** **NO** encuentra una coincidencia en **col2**.
#
# <img src=".\img\334.png" width="250px" height="350px">
#
# ---
#
# El resultado final de nuestra anti combinación son los registros correspondientes a los identificadores 1 y 4.
#
# <img src=".\img\335.png" width="450px" height="350px">
#
#
# Nuevamente, no se agregan nuevas columnas.
#
# ## Una anti unión con los presidentes
#
# ¿Cómo podríamos adaptar nuestra semi unión para determinar los países de las Américas fundados después de 1800?
#
# Para cambiar nuestra semi unión de antes a después de 1800, agregamos  **`NOT`** antes de la instrucción **`IN`**.
#
# A esto lo llamamos anti unión.
#
#
# <img src=".\img\336.png" width="350px" height="350px">
#
#
# Además, agregamos a nuestra primera cláusula **`WHERE`** para filtrar continentes a las Américas.
#
# <img src=".\img\337.png" width="350px" height="350px">
#
# El resultado muestra presidentes de países de las Américas que obtuvieron su independencia después de 1800.
#
# Solo devuelve Chile y Uruguay, no EE.UU., que se independizó antes de 1800.
#
# Tenga en cuenta que solo estamos usando los pocos países en nuestra base de datos por ilustración; Esta no es una lista completa de países en el mundo.

# %% [markdown]
# # Sub consultas dentro de WHERE y SELECT
#
#
# ## Sintaxis para sub consultas dentro de WHERE
#
# Las semi uniones y anti uniones que hemos visto hasta ahora involucran sub consultas dentro de **`WHERE`**.
#
# La cláusula **`WHERE`** es el lugar más común para las sub consultas, porque el filtrado de datos es una de las tareas de manipulación de datos más comunes.
#
# Revisemos esto con alguna sintaxis genérica y comprendamos los matices de este tipo de sub consulta.
#
# Echa un vistazo a la consulta que se muestra. Recuerde que la cláusula **`WHERE IN`** nos permite proporcionar una lista de valores para filtrar.
#
# <img src=".\img\338.png" width="350px" height="350px">
#
#
# ---
#
# Como hemos visto en la lección sobre semi uniones, los argumento del operador **`IN`** no se limitan a lista escrita por nosotros. Podemos incluir una sub consulta SQL como argumento para el operador **`IN`**, siempre que el resultado de la sub consulta es del mismo tipo de datos que el campo que estamos filtrando.
#
# <img src=".\img\339.png" width="350px" height="350px">
#
# ---
#
# La consulta que se muestra solo funcionará si **some_field** es del mismo tipo de datos que **some_numeric_field**, porque el resultado de la sub consulta será un campo numérico.
#
# La sub consulta dentro de **`WHERE`** pueden ser de la misma tabla o de una tabla diferente, y aquí, la sub consulta es de una tabla diferente.
#
# <img src=".\img\340.png" width="350px" height="350px">
#
#
# ## Sub consulta dentro de **`SELECT`**
#
#
# El segundo tipo de sub consulta más común está dentro de la cláusula **`SELECT`**.
#
# Digamos que queremos contar el número de monarcas que figuran en la tabla de monarcas para cada continente en la tabla de estados.
#
# Nuevamente, construyamos nuestra solución, paso a paso.
#
# La consulta que se muestra selecciona cada uno de los cinco continentes en la tabla de estados y se muestra el resultado.
#
# <img src=".\img\341.png" width="250px" height="350px">
#
# En cursos anteriores, hemos visto el uso de **`GROUP BY`** para contar datos por parte de un grupo. Sin embargo, dado que nuestros datos de monarcas viven en una tabla diferente a la tabla de estados, esto implicaría una unión cuidadosa antes de **`GROUP BY`**.
#
# Veamos cómo hacer esto con una sub consulta en su lugar. Nuestra sub consulta requiere dos cosas.
#
# Primero, necesitas **`COUNT()`** todos los monarcas.
#
# En segundo lugar, necesita una instrucción **`WHERE`** que coincida con los campos de continente en las dos tablas.
#
# Esta sub consulta sigue la selección de continentes **`DISTINCT`**, y por lo tanto, contará todos los monarcas dentro de ellos en la instrucción **`SELECT`**.
#
# Una sub consulta dentro de una declaración **`SELECT`** como esta requiere un alias, como **monarca_count** aquí.
#
# <img src=".\img\342.png" width="650px" height="350px">
#
# <img src=".\img\343.png" width="350px" height="350px">

# %% [markdown]
# # Sub consultas dentro **`FROM`**
#
#
# Digamos que estamos interesados en todos los continentes con monarcas, junto con el país más reciente en obtener la independencia en ese continente.
#
# Se muestra una consulta SQL inicial para extraer todos los años de independencia más recientes por continente. La consulta agrupa registros por continente y devuelve el año más reciente de independencia para cada grupo, usando la función **`MAX()`** **`AS`** **most_recent**.
#
#
# <img src=".\img\344.png" width="400px" height="350px">
#
# Se muestra el conjunto de resultados.
#
# Ahora, ¿cómo filtramos esto para continentes con monarcas?
#
# ## Centrarse en los registros dentro de los monarcas
#
#
# Todavía no hemos visto que podemos incluir varias tablas en una cláusula **`FROM`** agregando una como entre ellas.
#
# En la sintaxis SQL que se muestra, incluiremos dos tablas diferentes, **`lef_table`** y **right_table**, en nuestra cláusula **`FROM`**.
#
#
# <img src=".\img\345.png" width="400px" height="350px">
#
# El diagrama que se muestra ilustra que esta consulta devuelve duplicados para múltiples apariciones de id cuando coincide en ambas tablas.
#
#
# Podemos eliminar duplicados usando el comando **`DISTINCT`** en la consulta que se muestra.
#
#
# <img src=".\img\346.png" width="400px" height="350px">
#
#
# ## Finalización de la sub consulta
#
#
# Podemos anidar la sub consulta que escribimos inicialmente en una instrucción **`FROM`**, por lo que estamos seleccionando de ambos monarcas y nuestra sub consulta, alias como "sub".
#
# <img src=".\img\347.png" width="850px" height="350px">
#
# También usamos la cláusula **`WHERE`** como antes para identificar registros en ambas tablas que coinciden en el continente.
#
# Como vimos en la diapositiva anterior, debido a que los continentes de nuestra sub consulta encontrará múltiples coincidencias en monarcas, esta coincidencia devolverá duplicados.
#
# Como antes, en nuestra declaración **`SELECT`**, usamos el comando **`DISTINCT`** para eliminar duplicados.
#
# Seleccione **continent** y **sub.most_recent** para obtener el año de independencia más reciente para cada continente.
#
# Por último, ordenamos por continente.
#
# <img src=".\img\348.png" width="850px" height="350px">
#
# Echa un vistazo a nuestro conjunto de resultados. Ahí lo tenemos: los continentes con monarcas en nuestra base de datos, y el año más reciente de independencia en esos continentes.
#
# <img src=".\img\349.png" width="350px" height="350px">
#
# Así es como incluimos una sub consulta como una tabla temporal en nuestra cláusula **`FROM`** y luego **`SELECT`** en ella.
